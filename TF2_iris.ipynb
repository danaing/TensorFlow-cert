# %% [markdown]
# <a href="https://colab.research.google.com/github/danaing/TensorFlow-cert/blob/main/TF2_iris.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # TF2-iris-1

# %%
# ======================================================================
# There are 5 questions in this test with increasing difficulty from 1-5
# Please note that the weight of the grade for the question is relative
# to its difficulty. So your Category 1 question will score much less
# than your Category 5 question.
# ======================================================================
#
# Basic Datasets question
#
# For this task you will train a classifier for Iris flowers using the Iris dataset
# The final layer in your neural network should look like: tf.keras.layers.Dense(3, activation=tf.nn.softmax)
# The input layer will expect data in the shape (4,)
# We've given you some starter code for preprocessing the data
# You'll need to implement the preprocess function for data.map

# =========== 합격 기준 가이드라인 공유 ============= #
# val_loss 기준에 맞춰 주시는 것이 훨씬 더 중요 #
# val_loss 보다 조금 높아도 상관없음. (언저리까지 OK) #
# =================================================== #
# 문제명: Category 2 - iris
# val_loss: 0.14
# val_acc: 0.93
# =================================================== #
# =================================================== #


import tensorflow as tf
import tensorflow_datasets as tfds
import numpy as np
import tensorflow as tf
import tensorflow_datasets as tfds

from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import ModelCheckpoint

train_dataset = tfds.load('iris', split='train[:80%]')
valid_dataset = tfds.load('iris', split='train[80%:]')

def preprocess(data):
    # YOUR CODE HERE
    # Should return features and one-hot encoded labels
    x = data['features']
    y = data['label']
    y = tf.one_hot(y, 3)
    return x, y

def solution_model():
    batch_size = 10
    train_data = train_dataset.map(preprocess).batch(batch_size)
    valid_data = valid_dataset.map(preprocess).batch(batch_size)

    # YOUR CODE TO TRAIN A MODEL HERE
    model = tf.keras.models.Sequential([
        Dense(512, activation='relu', input_shape=(4,)),
        Dense(256, activation='relu'),
        Dense(128, activation='relu'),
        Dense(64, activation='relu'),
        Dense(32, activation='relu'),
        Dense(3, activation='softmax'),
    ])

    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['acc'])
    checkpoint_path = "my_checkpoint.ckpt"
    checkpoint = ModelCheckpoint(filepath=checkpoint_path, 
                                save_weights_only=True, 
                                save_best_only=True, 
                                monitor='val_loss', 
                                verbose=1)
    
    history = model.fit(train_data,
                    validation_data=(valid_data),
                    epochs=20,
                    callbacks=[checkpoint],
                   )
    model.load_weights(checkpoint_path)

    return model


# Note that you'll need to save your model as a .h5 like this
# This .h5 will be uploaded to the testing infrastructure
# and a score will be returned to you
if __name__ == '__main__':
    model = solution_model()
    model.save("mymodel.h5")
# Out:
# Epoch 1/20
# 12/12 [==============================] - 1s 17ms/step - loss: 0.9050 - acc: 0.6583 - val_loss: 0.6423 - val_acc: 0.6333
#
# Epoch 00001: val_loss improved from inf to 0.64228, saving model to my_checkpoint.ckpt
# Epoch 2/20
# 12/12 [==============================] - 0s 8ms/step - loss: 0.4720 - acc: 0.8250 - val_loss: 0.3917 - val_acc: 0.8333
#
# Epoch 00002: val_loss improved from 0.64228 to 0.39174, saving model to my_checkpoint.ckpt
# Epoch 3/20
# 12/12 [==============================] - 0s 8ms/step - loss: 0.2596 - acc: 0.9250 - val_loss: 0.2306 - val_acc: 0.9667
#
# Epoch 00003: val_loss improved from 0.39174 to 0.23062, saving model to my_checkpoint.ckpt
# Epoch 4/20
# 12/12 [==============================] - 0s 8ms/step - loss: 0.2375 - acc: 0.9000 - val_loss: 0.2415 - val_acc: 0.9000
#
# Epoch 00004: val_loss did not improve from 0.23062
# Epoch 5/20
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1223 - acc: 0.9500 - val_loss: 0.2365 - val_acc: 0.9000
#
# Epoch 00005: val_loss did not improve from 0.23062
# Epoch 6/20
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0933 - acc: 0.9667 - val_loss: 0.1719 - val_acc: 0.9000
#
# Epoch 00006: val_loss improved from 0.23062 to 0.17186, saving model to my_checkpoint.ckpt
# Epoch 7/20
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1115 - acc: 0.9583 - val_loss: 0.2021 - val_acc: 0.9000
#
# Epoch 00007: val_loss did not improve from 0.17186
# Epoch 8/20
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0629 - acc: 0.9917 - val_loss: 0.2002 - val_acc: 0.9000
#
# Epoch 00008: val_loss did not improve from 0.17186
# Epoch 9/20
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0941 - acc: 0.9583 - val_loss: 0.2009 - val_acc: 0.9000
#
# Epoch 00009: val_loss did not improve from 0.17186
# Epoch 10/20
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0588 - acc: 0.9750 - val_loss: 0.1971 - val_acc: 0.9000
#
# Epoch 00010: val_loss did not improve from 0.17186
# Epoch 11/20
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0796 - acc: 0.9583 - val_loss: 0.1934 - val_acc: 0.9000
#
# Epoch 00011: val_loss did not improve from 0.17186
# Epoch 12/20
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0612 - acc: 0.9667 - val_loss: 0.1816 - val_acc: 0.9333
#
# Epoch 00012: val_loss did not improve from 0.17186
# Epoch 13/20
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0761 - acc: 0.9583 - val_loss: 0.1750 - val_acc: 0.9333
#
# Epoch 00013: val_loss did not improve from 0.17186
# Epoch 14/20
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0652 - acc: 0.9667 - val_loss: 0.1569 - val_acc: 0.9667
#
# Epoch 00014: val_loss improved from 0.17186 to 0.15687, saving model to my_checkpoint.ckpt
# Epoch 15/20
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0835 - acc: 0.9583 - val_loss: 0.1478 - val_acc: 0.9667
#
# Epoch 00015: val_loss improved from 0.15687 to 0.14782, saving model to my_checkpoint.ckpt
# Epoch 16/20
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0745 - acc: 0.9667 - val_loss: 0.1357 - val_acc: 0.9333
#
# Epoch 00016: val_loss improved from 0.14782 to 0.13575, saving model to my_checkpoint.ckpt
# Epoch 17/20
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1025 - acc: 0.9583 - val_loss: 0.1356 - val_acc: 0.9333
#
# Epoch 00017: val_loss improved from 0.13575 to 0.13557, saving model to my_checkpoint.ckpt
# Epoch 18/20
# 12/12 [==============================] - 0s 8ms/step - loss: 0.1181 - acc: 0.9583 - val_loss: 0.1501 - val_acc: 0.9333
#
# Epoch 00018: val_loss did not improve from 0.13557
# Epoch 19/20
# 12/12 [==============================] - 0s 8ms/step - loss: 0.1792 - acc: 0.9333 - val_loss: 0.1624 - val_acc: 0.9000
#
# Epoch 00019: val_loss did not improve from 0.13557
# Epoch 20/20
# 12/12 [==============================] - 0s 7ms/step - loss: 0.2599 - acc: 0.8750 - val_loss: 0.1493 - val_acc: 0.9333
#
# Epoch 00020: val_loss did not improve from 0.13557

# %% [markdown]
# # TF2-iris-2

# %%
# ======================================================================
# There are 5 questions in this test with increasing difficulty from 1-5
# Please note that the weight of the grade for the question is relative
# to its difficulty. So your Category 1 question will score much less
# than your Category 5 question.
# ======================================================================
#
# Basic Datasets question
#
# For this task you will train a classifier for Iris flowers using the Iris dataset
# The final layer in your neural network should look like: tf.keras.layers.Dense(3, activation=tf.nn.softmax)
# The input layer will expect data in the shape (4,)
# We've given you some starter code for preprocessing the data
# You'll need to implement the preprocess function for data.map

# =========== 합격 기준 가이드라인 공유 ============= #
# val_loss 기준에 맞춰 주시는 것이 훨씬 더 중요 #
# val_loss 보다 조금 높아도 상관없음. (언저리까지 OK) #
# =================================================== #
# 문제명: Category 2 - iris
# val_loss: 0.14
# val_acc: 0.93
# =================================================== #
# =================================================== #


import tensorflow as tf
import tensorflow_datasets as tfds
import numpy as np
import tensorflow as tf
import tensorflow_datasets as tfds

from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import ModelCheckpoint

train_dataset = tfds.load('iris', split='train[:80%]')
valid_dataset = tfds.load('iris', split='train[80%:]')

def preprocess(data):
    # YOUR CODE HERE
    # Should return features and one-hot encoded labels
    x = data['features']
    y = data['label']
    y = tf.one_hot(y, 3)
    return x, y

def solution_model():
    batch_size = 10
    train_data = train_dataset.map(preprocess).batch(batch_size)
    valid_data = valid_dataset.map(preprocess).batch(batch_size)

    # YOUR CODE TO TRAIN A MODEL HERE
    model = tf.keras.models.Sequential([
        Dense(512, activation='relu', input_shape=(4,)),
        Dense(256, activation='relu'),
        Dense(128, activation='relu'),
        Dense(64, activation='relu'),
        Dense(32, activation='relu'),
        Dense(16, activation='relu'),
        Dense(3, activation='softmax'),
    ])

    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['acc'])
    checkpoint_path = "my_checkpoint.ckpt"
    checkpoint = ModelCheckpoint(filepath=checkpoint_path, 
                                save_weights_only=True, 
                                save_best_only=True, 
                                monitor='val_loss', 
                                verbose=1)
    
    history = model.fit(train_data,
                    validation_data=(valid_data),
                    epochs=20,
                    callbacks=[checkpoint],
                   )
    model.load_weights(checkpoint_path)

    return model


# Note that you'll need to save your model as a .h5 like this
# This .h5 will be uploaded to the testing infrastructure
# and a score will be returned to you
if __name__ == '__main__':
    model = solution_model()
    model.save("mymodel.h5")
# Out:
# Epoch 1/20
# 12/12 [==============================] - 1s 17ms/step - loss: 0.9531 - acc: 0.5500 - val_loss: 0.8068 - val_acc: 0.6333
#
# Epoch 00001: val_loss improved from inf to 0.80681, saving model to my_checkpoint.ckpt
# Epoch 2/20
# 12/12 [==============================] - 0s 8ms/step - loss: 0.6038 - acc: 0.7667 - val_loss: 0.5025 - val_acc: 0.9333
#
# Epoch 00002: val_loss improved from 0.80681 to 0.50251, saving model to my_checkpoint.ckpt
# Epoch 3/20
# 12/12 [==============================] - 0s 8ms/step - loss: 0.3330 - acc: 0.9167 - val_loss: 0.2851 - val_acc: 0.8667
#
# Epoch 00003: val_loss improved from 0.50251 to 0.28514, saving model to my_checkpoint.ckpt
# Epoch 4/20
# 12/12 [==============================] - 0s 8ms/step - loss: 0.3536 - acc: 0.8417 - val_loss: 0.2584 - val_acc: 0.9000
#
# Epoch 00004: val_loss improved from 0.28514 to 0.25837, saving model to my_checkpoint.ckpt
# Epoch 5/20
# 12/12 [==============================] - 0s 8ms/step - loss: 0.1885 - acc: 0.9250 - val_loss: 0.2406 - val_acc: 0.9000
#
# Epoch 00005: val_loss improved from 0.25837 to 0.24058, saving model to my_checkpoint.ckpt
# Epoch 6/20
# 12/12 [==============================] - 0s 8ms/step - loss: 0.1026 - acc: 0.9750 - val_loss: 0.2214 - val_acc: 0.9000
#
# Epoch 00006: val_loss improved from 0.24058 to 0.22138, saving model to my_checkpoint.ckpt
# Epoch 7/20
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0746 - acc: 0.9833 - val_loss: 0.1686 - val_acc: 0.9333
#
# Epoch 00007: val_loss improved from 0.22138 to 0.16859, saving model to my_checkpoint.ckpt
# Epoch 8/20
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1065 - acc: 0.9583 - val_loss: 0.1763 - val_acc: 0.9000
#
# Epoch 00008: val_loss did not improve from 0.16859
# Epoch 9/20
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0694 - acc: 0.9667 - val_loss: 0.1967 - val_acc: 0.9000
#
# Epoch 00009: val_loss did not improve from 0.16859
# Epoch 10/20
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0744 - acc: 0.9583 - val_loss: 0.2197 - val_acc: 0.9000
#
# Epoch 00010: val_loss did not improve from 0.16859
# Epoch 11/20
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0574 - acc: 0.9833 - val_loss: 0.1763 - val_acc: 0.9667
#
# Epoch 00011: val_loss did not improve from 0.16859
# Epoch 12/20
# 12/12 [==============================] - 0s 8ms/step - loss: 0.1263 - acc: 0.9333 - val_loss: 0.2149 - val_acc: 0.9000
#
# Epoch 00012: val_loss did not improve from 0.16859
# Epoch 13/20
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0489 - acc: 0.9917 - val_loss: 0.1946 - val_acc: 0.9333
#
# Epoch 00013: val_loss did not improve from 0.16859
# Epoch 14/20
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0845 - acc: 0.9667 - val_loss: 0.1597 - val_acc: 0.9667
#
# Epoch 00014: val_loss improved from 0.16859 to 0.15968, saving model to my_checkpoint.ckpt
# Epoch 15/20
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0942 - acc: 0.9500 - val_loss: 0.1510 - val_acc: 0.9667
#
# Epoch 00015: val_loss improved from 0.15968 to 0.15102, saving model to my_checkpoint.ckpt
# Epoch 16/20
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0814 - acc: 0.9750 - val_loss: 0.1404 - val_acc: 0.9333
#
# Epoch 00016: val_loss improved from 0.15102 to 0.14040, saving model to my_checkpoint.ckpt
# Epoch 17/20
# 12/12 [==============================] - 0s 8ms/step - loss: 0.1054 - acc: 0.9583 - val_loss: 0.1536 - val_acc: 0.9333
#
# Epoch 00017: val_loss did not improve from 0.14040
# Epoch 18/20
# 12/12 [==============================] - 0s 8ms/step - loss: 0.1593 - acc: 0.9417 - val_loss: 0.1814 - val_acc: 0.8667
#
# Epoch 00018: val_loss did not improve from 0.14040
# Epoch 19/20
# 12/12 [==============================] - 0s 8ms/step - loss: 0.2179 - acc: 0.9083 - val_loss: 0.1518 - val_acc: 0.9333
#
# Epoch 00019: val_loss did not improve from 0.14040
# Epoch 20/20
# 12/12 [==============================] - 0s 7ms/step - loss: 0.2265 - acc: 0.9000 - val_loss: 0.2293 - val_acc: 0.9000
#
# Epoch 00020: val_loss did not improve from 0.14040

# %% [markdown]
# #TF2-iris-3

# %%
# ======================================================================
# There are 5 questions in this test with increasing difficulty from 1-5
# Please note that the weight of the grade for the question is relative
# to its difficulty. So your Category 1 question will score much less
# than your Category 5 question.
# ======================================================================
#
# Basic Datasets question
#
# For this task you will train a classifier for Iris flowers using the Iris dataset
# The final layer in your neural network should look like: tf.keras.layers.Dense(3, activation=tf.nn.softmax)
# The input layer will expect data in the shape (4,)
# We've given you some starter code for preprocessing the data
# You'll need to implement the preprocess function for data.map

# =========== 합격 기준 가이드라인 공유 ============= #
# val_loss 기준에 맞춰 주시는 것이 훨씬 더 중요 #
# val_loss 보다 조금 높아도 상관없음. (언저리까지 OK) #
# =================================================== #
# 문제명: Category 2 - iris
# val_loss: 0.14
# val_acc: 0.93
# =================================================== #
# =================================================== #


import tensorflow as tf
import tensorflow_datasets as tfds
import numpy as np
import tensorflow as tf
import tensorflow_datasets as tfds

from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import ModelCheckpoint

train_dataset = tfds.load('iris', split='train[:80%]')
valid_dataset = tfds.load('iris', split='train[80%:]')

def preprocess(data):
    # YOUR CODE HERE
    # Should return features and one-hot encoded labels
    x = data['features']
    y = data['label']
    y = tf.one_hot(y, 3)
    return x, y

def solution_model():
    batch_size = 10
    train_data = train_dataset.map(preprocess).batch(batch_size)
    valid_data = valid_dataset.map(preprocess).batch(batch_size)

    # YOUR CODE TO TRAIN A MODEL HERE
    model = tf.keras.models.Sequential([
        Dense(1024, activation='relu', input_shape=(4,)),
        Dense(512, activation='relu'),
        Dense(256, activation='relu'),
        Dense(128, activation='relu'),
        Dense(64, activation='relu'),
        Dense(32, activation='relu'),
        Dense(16, activation='relu'),
        Dense(3, activation='softmax'),
    ])

    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['acc'])
    checkpoint_path = "my_checkpoint.ckpt"
    checkpoint = ModelCheckpoint(filepath=checkpoint_path, 
                                save_weights_only=True, 
                                save_best_only=True, 
                                monitor='val_loss', 
                                verbose=1)
    
    history = model.fit(train_data,
                    validation_data=(valid_data),
                    epochs=20,
                    callbacks=[checkpoint],
                   )
    model.load_weights(checkpoint_path)

    return model


# Note that you'll need to save your model as a .h5 like this
# This .h5 will be uploaded to the testing infrastructure
# and a score will be returned to you
if __name__ == '__main__':
    model = solution_model()
    model.save("mymodel.h5")
# Out:
# Epoch 1/20
# 12/12 [==============================] - 1s 26ms/step - loss: 0.9547 - acc: 0.3167 - val_loss: 0.8366 - val_acc: 0.3333
#
# Epoch 00001: val_loss improved from inf to 0.83664, saving model to my_checkpoint.ckpt
# Epoch 2/20
# 12/12 [==============================] - 0s 13ms/step - loss: 0.8217 - acc: 0.4417 - val_loss: 0.7537 - val_acc: 0.5000
#
# Epoch 00002: val_loss improved from 0.83664 to 0.75368, saving model to my_checkpoint.ckpt
# Epoch 3/20
# 12/12 [==============================] - 0s 13ms/step - loss: 0.7339 - acc: 0.4667 - val_loss: 0.7153 - val_acc: 0.4333
#
# Epoch 00003: val_loss improved from 0.75368 to 0.71526, saving model to my_checkpoint.ckpt
# Epoch 4/20
# 12/12 [==============================] - 0s 12ms/step - loss: 0.6169 - acc: 0.5833 - val_loss: 0.5574 - val_acc: 0.6333
#
# Epoch 00004: val_loss improved from 0.71526 to 0.55737, saving model to my_checkpoint.ckpt
# Epoch 5/20
# 12/12 [==============================] - 0s 12ms/step - loss: 0.5935 - acc: 0.5583 - val_loss: 0.7155 - val_acc: 0.5000
#
# Epoch 00005: val_loss did not improve from 0.55737
# Epoch 6/20
# 12/12 [==============================] - 0s 12ms/step - loss: 0.4836 - acc: 0.5917 - val_loss: 0.5177 - val_acc: 0.6000
#
# Epoch 00006: val_loss improved from 0.55737 to 0.51769, saving model to my_checkpoint.ckpt
# Epoch 7/20
# 12/12 [==============================] - 0s 11ms/step - loss: 0.4424 - acc: 0.6250 - val_loss: 0.5986 - val_acc: 0.6000
#
# Epoch 00007: val_loss did not improve from 0.51769
# Epoch 8/20
# 12/12 [==============================] - 0s 14ms/step - loss: 0.3820 - acc: 0.6083 - val_loss: 0.4965 - val_acc: 0.6000
#
# Epoch 00008: val_loss improved from 0.51769 to 0.49654, saving model to my_checkpoint.ckpt
# Epoch 9/20
# 12/12 [==============================] - 0s 13ms/step - loss: 0.4074 - acc: 0.7583 - val_loss: 0.4676 - val_acc: 0.9000
#
# Epoch 00009: val_loss improved from 0.49654 to 0.46759, saving model to my_checkpoint.ckpt
# Epoch 10/20
# 12/12 [==============================] - 0s 12ms/step - loss: 0.2787 - acc: 0.9917 - val_loss: 0.3673 - val_acc: 0.9333
#
# Epoch 00010: val_loss improved from 0.46759 to 0.36731, saving model to my_checkpoint.ckpt
# Epoch 11/20
# 12/12 [==============================] - 0s 12ms/step - loss: 0.3121 - acc: 0.9333 - val_loss: 0.3110 - val_acc: 0.9333
#
# Epoch 00011: val_loss improved from 0.36731 to 0.31104, saving model to my_checkpoint.ckpt
# Epoch 12/20
# 12/12 [==============================] - 0s 11ms/step - loss: 0.1211 - acc: 0.9833 - val_loss: 0.3352 - val_acc: 0.9000
#
# Epoch 00012: val_loss did not improve from 0.31104
# Epoch 13/20
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0644 - acc: 0.9833 - val_loss: 0.2065 - val_acc: 0.9333
#
# Epoch 00013: val_loss improved from 0.31104 to 0.20653, saving model to my_checkpoint.ckpt
# Epoch 14/20
# 12/12 [==============================] - 0s 12ms/step - loss: 0.1331 - acc: 0.9417 - val_loss: 0.2140 - val_acc: 0.9333
#
# Epoch 00014: val_loss did not improve from 0.20653
# Epoch 15/20
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0462 - acc: 0.9750 - val_loss: 0.2321 - val_acc: 0.9333
#
# Epoch 00015: val_loss did not improve from 0.20653
# Epoch 16/20
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0426 - acc: 0.9833 - val_loss: 0.1748 - val_acc: 0.9667
#
# Epoch 00016: val_loss improved from 0.20653 to 0.17477, saving model to my_checkpoint.ckpt
# Epoch 17/20
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0931 - acc: 0.9667 - val_loss: 0.1432 - val_acc: 0.9333
#
# Epoch 00017: val_loss improved from 0.17477 to 0.14323, saving model to my_checkpoint.ckpt
# Epoch 18/20
# 12/12 [==============================] - 0s 12ms/step - loss: 0.1313 - acc: 0.9500 - val_loss: 0.1507 - val_acc: 0.9333
#
# Epoch 00018: val_loss did not improve from 0.14323
# Epoch 19/20
# 12/12 [==============================] - 0s 12ms/step - loss: 0.1457 - acc: 0.9417 - val_loss: 0.1459 - val_acc: 0.9333
#
# Epoch 00019: val_loss did not improve from 0.14323
# Epoch 20/20
# 12/12 [==============================] - 0s 11ms/step - loss: 0.2634 - acc: 0.8917 - val_loss: 0.1854 - val_acc: 0.9000
#
# Epoch 00020: val_loss did not improve from 0.14323
