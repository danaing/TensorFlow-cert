# %% [markdown]
# <a href="https://colab.research.google.com/github/danaing/TensorFlow-cert/blob/main/TF3_horses_or_humans_type_A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #TF3-horsesorhumans-A-1-val-loss-0.0019

# %%
# ======================================================================
# There are 5 questions in this test with increasing difficulty from 1-5
# Please note that the weight of the grade for the question is relative
# to its difficulty. So your Category 1 question will score much less
# than your Category 5 question.
# ======================================================================
#
# Computer Vision with CNNs
#
# This task requires you to create a classifier for horses or humans using
# the provided dataset. 
#
# Please make sure your final layer has 2 neurons, activated by softmax 
# as shown. Do not change the provided output layer, or tests may fail.
#
# IMPORTANT: Please note that the test uses images that are 300x300 with 
# 3 bytes color depth so be sure to design your input layer to accept
# these, or the tests will fail.
#

# =========== 합격 기준 가이드라인 공유 ============= #
# val_loss 기준에 맞춰 주시는 것이 훨씬 더 중요 #
# val_loss 보다 조금 높아도 상관없음. (언저리까지 OK) #
# =================================================== #
# 문제명: Category 3 - Horses Or Humans type A
# val_loss: 0.028
# val_acc: 0.98
# =================================================== #
# =================================================== #


import tensorflow_datasets as tfds
import tensorflow as tf

from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import ModelCheckpoint


dataset_name = 'horses_or_humans'
train_dataset = tfds.load(name=dataset_name, split='train[:80%]')
valid_dataset = tfds.load(name=dataset_name, split='train[80%:]')

def preprocess(data):
    # YOUR CODE HERE
    x = data['image']
    y = data['label']
    x = tf.cast(x, tf.float32) / 255.0
    x = tf.image.resize(x, size=(300, 300))
    return x, y


def solution_model():
    batch_size=32
    train_data = train_dataset.map(preprocess).batch(batch_size)
    valid_data = valid_dataset.map(preprocess).batch(batch_size)

    model = Sequential([
        Conv2D(16, (3, 3), activation='relu', input_shape=(300, 300, 3)),
        MaxPooling2D(2, 2),
        Conv2D(32, (3, 3), activation='relu'),
        MaxPooling2D(2, 2),
        Conv2D(64, (3, 3), activation='relu'),
        MaxPooling2D(2, 2),
        Conv2D(64, (3, 3), activation='relu'),
        MaxPooling2D(2, 2),
        Conv2D(128, (3, 3), activation='relu'),
        MaxPooling2D(2, 2),
        Flatten(),
        Dropout(0.5),
        Dense(128, activation='relu'),
        Dense(32, activation='relu'),
    # YOUR CODE HERE, BUT MAKE SURE YOUR LAST LAYER HAS 2 NEURONS ACTIVATED BY SOFTMAX
        Dense(2, activation='softmax')
    ])

    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['acc'])

    checkpoint_path = "my_checkpoint.ckpt"
    checkpoint = ModelCheckpoint(filepath=checkpoint_path, 
                                save_weights_only=True, 
                                save_best_only=True, 
                                monitor='val_loss', 
                                verbose=1)
    model.fit(train_data,
                validation_data=(valid_data),
                epochs=20,
                callbacks=[checkpoint],
                )
    model.load_weights(checkpoint_path)

    return model


# Note that you'll need to save your model as a .h5 like this
# This .h5 will be uploaded to the testing infrastructure
# and a score will be returned to you
if __name__ == '__main__':
    model = solution_model()
    model.save("mymodel.h5")
# Out:
# Downloading and preparing dataset horses_or_humans/3.0.0 (download: 153.59 MiB, generated: Unknown size, total: 153.59 MiB) to /root/tensorflow_datasets/horses_or_humans/3.0.0...
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Dl Completed...', max=1.0, style=Progre…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Dl Size...', max=1.0, style=ProgressSty…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Shuffling and writing examples to /root/tensorflow_datasets/horses_or_humans/3.0.0.incompleteJ8G7Y9/horses_or_humans-train.tfrecord
# HBox(children=(FloatProgress(value=0.0, max=1027.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Shuffling and writing examples to /root/tensorflow_datasets/horses_or_humans/3.0.0.incompleteJ8G7Y9/horses_or_humans-test.tfrecord
# HBox(children=(FloatProgress(value=0.0, max=256.0), HTML(value='')))
# Dataset horses_or_humans downloaded and prepared to /root/tensorflow_datasets/horses_or_humans/3.0.0. Subsequent calls will reuse this data.
# Epoch 1/20
# 26/26 [==============================] - 19s 114ms/step - loss: 0.5414 - acc: 0.7238 - val_loss: 0.1862 - val_acc: 0.9463
#
# Epoch 00001: val_loss improved from inf to 0.18625, saving model to my_checkpoint.ckpt
# Epoch 2/20
# 26/26 [==============================] - 3s 94ms/step - loss: 0.1713 - acc: 0.9343 - val_loss: 0.1091 - val_acc: 0.9561
#
# Epoch 00002: val_loss improved from 0.18625 to 0.10915, saving model to my_checkpoint.ckpt
# Epoch 3/20
# 26/26 [==============================] - 2s 95ms/step - loss: 0.0853 - acc: 0.9659 - val_loss: 0.0287 - val_acc: 0.9854
#
# Epoch 00003: val_loss improved from 0.10915 to 0.02865, saving model to my_checkpoint.ckpt
# Epoch 4/20
# 26/26 [==============================] - 2s 93ms/step - loss: 0.0446 - acc: 0.9854 - val_loss: 0.0240 - val_acc: 0.9951
#
# Epoch 00004: val_loss improved from 0.02865 to 0.02398, saving model to my_checkpoint.ckpt
# Epoch 5/20
# 26/26 [==============================] - 3s 94ms/step - loss: 0.0812 - acc: 0.9708 - val_loss: 0.0833 - val_acc: 0.9707
#
# Epoch 00005: val_loss did not improve from 0.02398
# Epoch 6/20
# 26/26 [==============================] - 3s 95ms/step - loss: 0.0468 - acc: 0.9854 - val_loss: 0.0364 - val_acc: 0.9805
#
# Epoch 00006: val_loss did not improve from 0.02398
# Epoch 7/20
# 26/26 [==============================] - 3s 94ms/step - loss: 0.0618 - acc: 0.9781 - val_loss: 0.0210 - val_acc: 0.9951
#
# Epoch 00007: val_loss improved from 0.02398 to 0.02096, saving model to my_checkpoint.ckpt
# Epoch 8/20
# 26/26 [==============================] - 3s 94ms/step - loss: 0.0427 - acc: 0.9854 - val_loss: 0.0360 - val_acc: 0.9902
#
# Epoch 00008: val_loss did not improve from 0.02096
# Epoch 9/20
# 26/26 [==============================] - 2s 93ms/step - loss: 0.0261 - acc: 0.9915 - val_loss: 0.0054 - val_acc: 1.0000
#
# Epoch 00009: val_loss improved from 0.02096 to 0.00541, saving model to my_checkpoint.ckpt
# Epoch 10/20
# 26/26 [==============================] - 3s 94ms/step - loss: 0.0225 - acc: 0.9964 - val_loss: 0.0047 - val_acc: 1.0000
#
# Epoch 00010: val_loss improved from 0.00541 to 0.00466, saving model to my_checkpoint.ckpt
# Epoch 11/20
# 26/26 [==============================] - 3s 97ms/step - loss: 0.0090 - acc: 0.9988 - val_loss: 0.0019 - val_acc: 1.0000
#
# Epoch 00011: val_loss improved from 0.00466 to 0.00190, saving model to my_checkpoint.ckpt
# Epoch 12/20
# 26/26 [==============================] - 3s 95ms/step - loss: 0.0146 - acc: 0.9939 - val_loss: 0.0542 - val_acc: 0.9854
#
# Epoch 00012: val_loss did not improve from 0.00190
# Epoch 13/20
# 26/26 [==============================] - 3s 93ms/step - loss: 0.0277 - acc: 0.9939 - val_loss: 0.0118 - val_acc: 0.9951
#
# Epoch 00013: val_loss did not improve from 0.00190
# Epoch 14/20
# 26/26 [==============================] - 3s 96ms/step - loss: 0.0297 - acc: 0.9878 - val_loss: 0.1672 - val_acc: 0.9512
#
# Epoch 00014: val_loss did not improve from 0.00190
# Epoch 15/20
# 26/26 [==============================] - 2s 94ms/step - loss: 0.0454 - acc: 0.9842 - val_loss: 0.0207 - val_acc: 0.9951
#
# Epoch 00015: val_loss did not improve from 0.00190
# Epoch 16/20
# 26/26 [==============================] - 3s 95ms/step - loss: 0.0040 - acc: 0.9988 - val_loss: 0.0068 - val_acc: 0.9951
#
# Epoch 00016: val_loss did not improve from 0.00190
# Epoch 17/20
# 26/26 [==============================] - 3s 96ms/step - loss: 0.0284 - acc: 0.9939 - val_loss: 0.4943 - val_acc: 0.9122
#
# Epoch 00017: val_loss did not improve from 0.00190
# Epoch 18/20
# 26/26 [==============================] - 3s 96ms/step - loss: 0.0253 - acc: 0.9891 - val_loss: 0.0200 - val_acc: 0.9902
#
# Epoch 00018: val_loss did not improve from 0.00190
# Epoch 19/20
# 26/26 [==============================] - 3s 94ms/step - loss: 0.0515 - acc: 0.9854 - val_loss: 0.1118 - val_acc: 0.9463
#
# Epoch 00019: val_loss did not improve from 0.00190
# Epoch 20/20
# 26/26 [==============================] - 3s 97ms/step - loss: 0.0305 - acc: 0.9891 - val_loss: 0.0054 - val_acc: 1.0000
#
# Epoch 00020: val_loss did not improve from 0.00190

# %% [markdown]
# #TF3-horsesorhumans-A-2-val-loss-0.0277

# %%
# ======================================================================
# There are 5 questions in this test with increasing difficulty from 1-5
# Please note that the weight of the grade for the question is relative
# to its difficulty. So your Category 1 question will score much less
# than your Category 5 question.
# ======================================================================
#
# Computer Vision with CNNs
#
# This task requires you to create a classifier for horses or humans using
# the provided dataset. 
#
# Please make sure your final layer has 2 neurons, activated by softmax 
# as shown. Do not change the provided output layer, or tests may fail.
#
# IMPORTANT: Please note that the test uses images that are 300x300 with 
# 3 bytes color depth so be sure to design your input layer to accept
# these, or the tests will fail.
#

# =========== 합격 기준 가이드라인 공유 ============= #
# val_loss 기준에 맞춰 주시는 것이 훨씬 더 중요 #
# val_loss 보다 조금 높아도 상관없음. (언저리까지 OK) #
# =================================================== #
# 문제명: Category 3 - Horses Or Humans type A
# val_loss: 0.028
# val_acc: 0.98
# =================================================== #
# =================================================== #


import tensorflow_datasets as tfds
import tensorflow as tf

from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import ModelCheckpoint


dataset_name = 'horses_or_humans'
train_dataset = tfds.load(name=dataset_name, split='train[:80%]')
valid_dataset = tfds.load(name=dataset_name, split='train[80%:]')

def preprocess(data):
    # YOUR CODE HERE
    x = data['image']
    y = data['label']
    x = tf.cast(x, tf.float32) / 255.0
    x = tf.image.resize(x, size=(300, 300))
    return x, y


def solution_model():
    batch_size=32
    train_data = train_dataset.map(preprocess).batch(batch_size)
    valid_data = valid_dataset.map(preprocess).batch(batch_size)

    model = Sequential([
        Conv2D(16, (3, 3), activation='relu', input_shape=(300, 300, 3)),
        MaxPooling2D(2, 2),
        Conv2D(32, (3, 3), activation='relu'),
        MaxPooling2D(2, 2),
        Conv2D(64, (3, 3), activation='relu'),
        MaxPooling2D(2, 2),
        Conv2D(64, (3, 3), activation='relu'),
        MaxPooling2D(2, 2),
        Conv2D(128, (3, 3), activation='relu'),
        MaxPooling2D(2, 2),
        Flatten(),
        Dropout(0.5),
        Dense(128, activation='relu'),
    # YOUR CODE HERE, BUT MAKE SURE YOUR LAST LAYER HAS 2 NEURONS ACTIVATED BY SOFTMAX
        Dense(2, activation='softmax')
    ])

    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['acc'])

    checkpoint_path = "my_checkpoint.ckpt"
    checkpoint = ModelCheckpoint(filepath=checkpoint_path, 
                                save_weights_only=True, 
                                save_best_only=True, 
                                monitor='val_loss', 
                                verbose=1)
    model.fit(train_data,
                validation_data=(valid_data),
                epochs=20,
                callbacks=[checkpoint],
                )
    model.load_weights(checkpoint_path)

    return model


# Note that you'll need to save your model as a .h5 like this
# This .h5 will be uploaded to the testing infrastructure
# and a score will be returned to you
if __name__ == '__main__':
    model = solution_model()
    model.save("mymodel.h5")
# Out:
# Epoch 1/20
# 26/26 [==============================] - 3s 101ms/step - loss: 0.3993 - acc: 0.7956 - val_loss: 0.2901 - val_acc: 0.8634
#
# Epoch 00001: val_loss improved from inf to 0.29011, saving model to my_checkpoint.ckpt
# Epoch 2/20
# 26/26 [==============================] - 3s 95ms/step - loss: 0.1629 - acc: 0.9331 - val_loss: 0.1016 - val_acc: 0.9610
#
# Epoch 00002: val_loss improved from 0.29011 to 0.10159, saving model to my_checkpoint.ckpt
# Epoch 3/20
# 26/26 [==============================] - 3s 95ms/step - loss: 0.0880 - acc: 0.9684 - val_loss: 0.1875 - val_acc: 0.9171
#
# Epoch 00003: val_loss did not improve from 0.10159
# Epoch 4/20
# 26/26 [==============================] - 3s 93ms/step - loss: 0.0472 - acc: 0.9854 - val_loss: 0.0766 - val_acc: 0.9659
#
# Epoch 00004: val_loss improved from 0.10159 to 0.07658, saving model to my_checkpoint.ckpt
# Epoch 5/20
# 26/26 [==============================] - 2s 94ms/step - loss: 0.0434 - acc: 0.9878 - val_loss: 0.0837 - val_acc: 0.9659
#
# Epoch 00005: val_loss did not improve from 0.07658
# Epoch 6/20
# 26/26 [==============================] - 3s 98ms/step - loss: 0.0348 - acc: 0.9842 - val_loss: 0.1115 - val_acc: 0.9805
#
# Epoch 00006: val_loss did not improve from 0.07658
# Epoch 7/20
# 26/26 [==============================] - 3s 95ms/step - loss: 0.0547 - acc: 0.9854 - val_loss: 0.0370 - val_acc: 0.9902
#
# Epoch 00007: val_loss improved from 0.07658 to 0.03698, saving model to my_checkpoint.ckpt
# Epoch 8/20
# 26/26 [==============================] - 3s 93ms/step - loss: 0.0130 - acc: 0.9964 - val_loss: 0.0381 - val_acc: 0.9902
#
# Epoch 00008: val_loss did not improve from 0.03698
# Epoch 9/20
# 26/26 [==============================] - 3s 96ms/step - loss: 0.0435 - acc: 0.9793 - val_loss: 0.0278 - val_acc: 0.9902
#
# Epoch 00009: val_loss improved from 0.03698 to 0.02779, saving model to my_checkpoint.ckpt
# Epoch 10/20
# 26/26 [==============================] - 3s 95ms/step - loss: 0.0894 - acc: 0.9745 - val_loss: 0.1308 - val_acc: 0.9512
#
# Epoch 00010: val_loss did not improve from 0.02779
# Epoch 11/20
# 26/26 [==============================] - 3s 94ms/step - loss: 0.0394 - acc: 0.9903 - val_loss: 0.0149 - val_acc: 0.9902
#
# Epoch 00011: val_loss improved from 0.02779 to 0.01485, saving model to my_checkpoint.ckpt
# Epoch 12/20
# 26/26 [==============================] - 2s 93ms/step - loss: 0.0160 - acc: 0.9915 - val_loss: 0.0277 - val_acc: 0.9902
#
# Epoch 00012: val_loss did not improve from 0.01485
# Epoch 13/20
# 26/26 [==============================] - 3s 98ms/step - loss: 0.0089 - acc: 0.9964 - val_loss: 0.0540 - val_acc: 0.9902
#
# Epoch 00013: val_loss did not improve from 0.01485
# Epoch 14/20
# 26/26 [==============================] - 3s 96ms/step - loss: 0.0042 - acc: 0.9988 - val_loss: 0.0922 - val_acc: 0.9756
#
# Epoch 00014: val_loss did not improve from 0.01485
# Epoch 15/20
# 26/26 [==============================] - 3s 94ms/step - loss: 0.0335 - acc: 0.9891 - val_loss: 0.0317 - val_acc: 0.9805
#
# Epoch 00015: val_loss did not improve from 0.01485
# Epoch 16/20
# 26/26 [==============================] - 2s 94ms/step - loss: 0.0161 - acc: 0.9927 - val_loss: 0.0626 - val_acc: 0.9854
#
# Epoch 00016: val_loss did not improve from 0.01485
# Epoch 17/20
# 26/26 [==============================] - 2s 93ms/step - loss: 0.0043 - acc: 0.9988 - val_loss: 0.0923 - val_acc: 0.9854
#
# Epoch 00017: val_loss did not improve from 0.01485
# Epoch 18/20
# 26/26 [==============================] - 2s 93ms/step - loss: 0.0036 - acc: 0.9988 - val_loss: 0.0365 - val_acc: 0.9902
#
# Epoch 00018: val_loss did not improve from 0.01485
# Epoch 19/20
# 26/26 [==============================] - 2s 94ms/step - loss: 0.0013 - acc: 1.0000 - val_loss: 0.0326 - val_acc: 0.9902
#
# Epoch 00019: val_loss did not improve from 0.01485
# Epoch 20/20
# 26/26 [==============================] - 3s 95ms/step - loss: 1.9710e-04 - acc: 1.0000 - val_loss: 0.0252 - val_acc: 0.9902
#
# Epoch 00020: val_loss did not improve from 0.01485

# %% [markdown]
# #TF3-horsesorhumans-A-3-val-loss-0.0006

# %%
# ======================================================================
# There are 5 questions in this test with increasing difficulty from 1-5
# Please note that the weight of the grade for the question is relative
# to its difficulty. So your Category 1 question will score much less
# than your Category 5 question.
# ======================================================================
#
# Computer Vision with CNNs
#
# This task requires you to create a classifier for horses or humans using
# the provided dataset. 
#
# Please make sure your final layer has 2 neurons, activated by softmax 
# as shown. Do not change the provided output layer, or tests may fail.
#
# IMPORTANT: Please note that the test uses images that are 300x300 with 
# 3 bytes color depth so be sure to design your input layer to accept
# these, or the tests will fail.
#

# =========== 합격 기준 가이드라인 공유 ============= #
# val_loss 기준에 맞춰 주시는 것이 훨씬 더 중요 #
# val_loss 보다 조금 높아도 상관없음. (언저리까지 OK) #
# =================================================== #
# 문제명: Category 3 - Horses Or Humans type A
# val_loss: 0.028
# val_acc: 0.98
# =================================================== #
# =================================================== #


import tensorflow_datasets as tfds
import tensorflow as tf

from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import ModelCheckpoint


dataset_name = 'horses_or_humans'
train_dataset = tfds.load(name=dataset_name, split='train[:80%]')
valid_dataset = tfds.load(name=dataset_name, split='train[80%:]')

def preprocess(data):
    # YOUR CODE HERE
    x = data['image']
    y = data['label']
    x = tf.cast(x, tf.float32) / 255.0
    x = tf.image.resize(x, size=(300, 300))
    return x, y


def solution_model():
    batch_size=32
    train_data = train_dataset.map(preprocess).batch(batch_size)
    valid_data = valid_dataset.map(preprocess).batch(batch_size)

    model = Sequential([
        Conv2D(16, (3, 3), activation='relu', input_shape=(300, 300, 3)),
        MaxPooling2D(2, 2),
        Conv2D(32, (3, 3), activation='relu'),
        MaxPooling2D(2, 2),
        Conv2D(64, (3, 3), activation='relu'),
        MaxPooling2D(2, 2),
        Conv2D(64, (3, 3), activation='relu'),
        MaxPooling2D(2, 2),
        Conv2D(128, (3, 3), activation='relu'),
        MaxPooling2D(2, 2),
        Flatten(),
        Dropout(0.5),
        Dense(64, activation='relu'),
    # YOUR CODE HERE, BUT MAKE SURE YOUR LAST LAYER HAS 2 NEURONS ACTIVATED BY SOFTMAX
        Dense(2, activation='softmax')
    ])

    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['acc'])

    checkpoint_path = "my_checkpoint.ckpt"
    checkpoint = ModelCheckpoint(filepath=checkpoint_path, 
                                save_weights_only=True, 
                                save_best_only=True, 
                                monitor='val_loss', 
                                verbose=1)
    model.fit(train_data,
                validation_data=(valid_data),
                epochs=30,
                callbacks=[checkpoint],
                )
    model.load_weights(checkpoint_path)

    return model


# Note that you'll need to save your model as a .h5 like this
# This .h5 will be uploaded to the testing infrastructure
# and a score will be returned to you
if __name__ == '__main__':
    model = solution_model()
    model.save("mymodel.h5")
# Out:
# Epoch 1/30
# 26/26 [==============================] - 3s 101ms/step - loss: 0.4207 - acc: 0.8005 - val_loss: 0.1428 - val_acc: 0.9512
#
# Epoch 00001: val_loss improved from inf to 0.14277, saving model to my_checkpoint.ckpt
# Epoch 2/30
# 26/26 [==============================] - 2s 92ms/step - loss: 0.1522 - acc: 0.9319 - val_loss: 0.1387 - val_acc: 0.9512
#
# Epoch 00002: val_loss improved from 0.14277 to 0.13872, saving model to my_checkpoint.ckpt
# Epoch 3/30
# 26/26 [==============================] - 3s 94ms/step - loss: 0.1187 - acc: 0.9586 - val_loss: 0.1031 - val_acc: 0.9561
#
# Epoch 00003: val_loss improved from 0.13872 to 0.10307, saving model to my_checkpoint.ckpt
# Epoch 4/30
# 26/26 [==============================] - 3s 97ms/step - loss: 0.0843 - acc: 0.9635 - val_loss: 0.0900 - val_acc: 0.9707
#
# Epoch 00004: val_loss improved from 0.10307 to 0.09003, saving model to my_checkpoint.ckpt
# Epoch 5/30
# 26/26 [==============================] - 2s 92ms/step - loss: 0.0603 - acc: 0.9745 - val_loss: 0.2486 - val_acc: 0.9073
#
# Epoch 00005: val_loss did not improve from 0.09003
# Epoch 6/30
# 26/26 [==============================] - 2s 92ms/step - loss: 0.0908 - acc: 0.9623 - val_loss: 0.0441 - val_acc: 0.9854
#
# Epoch 00006: val_loss improved from 0.09003 to 0.04406, saving model to my_checkpoint.ckpt
# Epoch 7/30
# 26/26 [==============================] - 2s 93ms/step - loss: 0.0514 - acc: 0.9830 - val_loss: 0.0153 - val_acc: 1.0000
#
# Epoch 00007: val_loss improved from 0.04406 to 0.01529, saving model to my_checkpoint.ckpt
# Epoch 8/30
# 26/26 [==============================] - 2s 93ms/step - loss: 0.0542 - acc: 0.9781 - val_loss: 0.0289 - val_acc: 0.9902
#
# Epoch 00008: val_loss did not improve from 0.01529
# Epoch 9/30
# 26/26 [==============================] - 3s 95ms/step - loss: 0.0457 - acc: 0.9903 - val_loss: 0.1058 - val_acc: 0.9366
#
# Epoch 00009: val_loss did not improve from 0.01529
# Epoch 10/30
# 26/26 [==============================] - 2s 93ms/step - loss: 0.0128 - acc: 0.9976 - val_loss: 0.0217 - val_acc: 0.9951
#
# Epoch 00010: val_loss did not improve from 0.01529
# Epoch 11/30
# 26/26 [==============================] - 2s 91ms/step - loss: 0.0036 - acc: 1.0000 - val_loss: 0.0056 - val_acc: 0.9951
#
# Epoch 00011: val_loss improved from 0.01529 to 0.00563, saving model to my_checkpoint.ckpt
# Epoch 12/30
# 26/26 [==============================] - 3s 95ms/step - loss: 0.0268 - acc: 0.9927 - val_loss: 0.0362 - val_acc: 0.9854
#
# Epoch 00012: val_loss did not improve from 0.00563
# Epoch 13/30
# 26/26 [==============================] - 3s 96ms/step - loss: 0.0213 - acc: 0.9927 - val_loss: 0.0212 - val_acc: 0.9951
#
# Epoch 00013: val_loss did not improve from 0.00563
# Epoch 14/30
# 26/26 [==============================] - 2s 92ms/step - loss: 0.0125 - acc: 0.9964 - val_loss: 0.0132 - val_acc: 1.0000
#
# Epoch 00014: val_loss did not improve from 0.00563
# Epoch 15/30
# 26/26 [==============================] - 2s 92ms/step - loss: 0.0026 - acc: 1.0000 - val_loss: 0.0137 - val_acc: 0.9902
#
# Epoch 00015: val_loss did not improve from 0.00563
# Epoch 16/30
# 26/26 [==============================] - 2s 93ms/step - loss: 0.0010 - acc: 1.0000 - val_loss: 8.4484e-04 - val_acc: 1.0000
#
# Epoch 00016: val_loss improved from 0.00563 to 0.00084, saving model to my_checkpoint.ckpt
# Epoch 17/30
# 26/26 [==============================] - 3s 94ms/step - loss: 3.2646e-04 - acc: 1.0000 - val_loss: 8.5798e-04 - val_acc: 1.0000
#
# Epoch 00017: val_loss did not improve from 0.00084
# Epoch 18/30
# 26/26 [==============================] - 3s 95ms/step - loss: 5.1379e-04 - acc: 1.0000 - val_loss: 9.6920e-04 - val_acc: 1.0000
#
# Epoch 00018: val_loss did not improve from 0.00084
# Epoch 19/30
# 26/26 [==============================] - 2s 92ms/step - loss: 2.2599e-04 - acc: 1.0000 - val_loss: 0.0013 - val_acc: 1.0000
#
# Epoch 00019: val_loss did not improve from 0.00084
# Epoch 20/30
# 26/26 [==============================] - 2s 94ms/step - loss: 2.2922e-04 - acc: 1.0000 - val_loss: 0.0020 - val_acc: 1.0000
#
# Epoch 00020: val_loss did not improve from 0.00084
# Epoch 21/30
# 26/26 [==============================] - 2s 92ms/step - loss: 2.0013e-04 - acc: 1.0000 - val_loss: 0.0086 - val_acc: 0.9951
#
# Epoch 00021: val_loss did not improve from 0.00084
# Epoch 22/30
# 26/26 [==============================] - 3s 94ms/step - loss: 4.6320e-04 - acc: 1.0000 - val_loss: 0.0013 - val_acc: 1.0000
#
# Epoch 00022: val_loss did not improve from 0.00084
# Epoch 23/30
# 26/26 [==============================] - 2s 92ms/step - loss: 1.2223e-04 - acc: 1.0000 - val_loss: 0.0029 - val_acc: 1.0000
#
# Epoch 00023: val_loss did not improve from 0.00084
# Epoch 24/30
# 26/26 [==============================] - 3s 95ms/step - loss: 8.8966e-05 - acc: 1.0000 - val_loss: 0.0020 - val_acc: 1.0000
#
# Epoch 00024: val_loss did not improve from 0.00084
# Epoch 25/30
# 26/26 [==============================] - 2s 93ms/step - loss: 1.4093e-04 - acc: 1.0000 - val_loss: 0.0049 - val_acc: 0.9951
#
# Epoch 00025: val_loss did not improve from 0.00084
# Epoch 26/30
# 26/26 [==============================] - 2s 94ms/step - loss: 1.3620e-04 - acc: 1.0000 - val_loss: 0.0101 - val_acc: 0.9951
#
# Epoch 00026: val_loss did not improve from 0.00084
# Epoch 27/30
# 26/26 [==============================] - 3s 94ms/step - loss: 1.3341e-04 - acc: 1.0000 - val_loss: 6.5546e-04 - val_acc: 1.0000
#
# Epoch 00027: val_loss improved from 0.00084 to 0.00066, saving model to my_checkpoint.ckpt
# Epoch 28/30
# 26/26 [==============================] - 2s 94ms/step - loss: 6.2649e-05 - acc: 1.0000 - val_loss: 0.0011 - val_acc: 1.0000
#
# Epoch 00028: val_loss did not improve from 0.00066
# Epoch 29/30
# 26/26 [==============================] - 3s 96ms/step - loss: 3.4561e-05 - acc: 1.0000 - val_loss: 0.0015 - val_acc: 1.0000
#
# Epoch 00029: val_loss did not improve from 0.00066
# Epoch 30/30
# 26/26 [==============================] - 3s 95ms/step - loss: 5.9050e-05 - acc: 1.0000 - val_loss: 0.0026 - val_acc: 1.0000
#
# Epoch 00030: val_loss did not improve from 0.00066

# %% [markdown]
# #TF3-horsesorhumans-A-4-val-loss-0.000004

# %%
# ======================================================================
# There are 5 questions in this test with increasing difficulty from 1-5
# Please note that the weight of the grade for the question is relative
# to its difficulty. So your Category 1 question will score much less
# than your Category 5 question.
# ======================================================================
#
# Computer Vision with CNNs
#
# This task requires you to create a classifier for horses or humans using
# the provided dataset. 
#
# Please make sure your final layer has 2 neurons, activated by softmax 
# as shown. Do not change the provided output layer, or tests may fail.
#
# IMPORTANT: Please note that the test uses images that are 300x300 with 
# 3 bytes color depth so be sure to design your input layer to accept
# these, or the tests will fail.
#

# =========== 합격 기준 가이드라인 공유 ============= #
# val_loss 기준에 맞춰 주시는 것이 훨씬 더 중요 #
# val_loss 보다 조금 높아도 상관없음. (언저리까지 OK) #
# =================================================== #
# 문제명: Category 3 - Horses Or Humans type A
# val_loss: 0.028
# val_acc: 0.98
# =================================================== #
# =================================================== #


import tensorflow_datasets as tfds
import tensorflow as tf

from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import ModelCheckpoint


dataset_name = 'horses_or_humans'
train_dataset = tfds.load(name=dataset_name, split='train[:80%]')
valid_dataset = tfds.load(name=dataset_name, split='train[80%:]')

def preprocess(data):
    # YOUR CODE HERE
    x = data['image']
    y = data['label']
    x = tf.cast(x, tf.float32) / 255.0
    x = tf.image.resize(x, size=(300, 300))
    return x, y


def solution_model():
    batch_size=32
    train_data = train_dataset.map(preprocess).batch(batch_size)
    valid_data = valid_dataset.map(preprocess).batch(batch_size)

    model = Sequential([
        Conv2D(16, (3, 3), activation='relu', input_shape=(300, 300, 3)),
        MaxPooling2D(2, 2),
        Conv2D(32, (3, 3), activation='relu'),
        MaxPooling2D(2, 2),
        Conv2D(64, (3, 3), activation='relu'),
        MaxPooling2D(2, 2),
        Conv2D(64, (3, 3), activation='relu'),
        MaxPooling2D(2, 2),
        Conv2D(128, (3, 3), activation='relu'),
        MaxPooling2D(2, 2),
        Flatten(),
        Dropout(0.5),
        Dense(128, activation='relu'),
    # YOUR CODE HERE, BUT MAKE SURE YOUR LAST LAYER HAS 2 NEURONS ACTIVATED BY SOFTMAX
        Dense(2, activation='softmax')
    ])

    model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy', metrics=['acc'])

    checkpoint_path = "my_checkpoint.ckpt"
    checkpoint = ModelCheckpoint(filepath=checkpoint_path, 
                                save_weights_only=True, 
                                save_best_only=True, 
                                monitor='val_loss', 
                                verbose=1)
    model.fit(train_data,
                validation_data=(valid_data),
                epochs=30,
                callbacks=[checkpoint],
                )
    model.load_weights(checkpoint_path)

    return model


# Note that you'll need to save your model as a .h5 like this
# This .h5 will be uploaded to the testing infrastructure
# and a score will be returned to you
if __name__ == '__main__':
    model = solution_model()
    model.save("mymodel.h5")
# Out:
# Epoch 1/30
# 26/26 [==============================] - 3s 97ms/step - loss: 0.8584 - acc: 0.5657 - val_loss: 0.5785 - val_acc: 0.8976
#
# Epoch 00001: val_loss improved from inf to 0.57849, saving model to my_checkpoint.ckpt
# Epoch 2/30
# 26/26 [==============================] - 2s 94ms/step - loss: 0.5527 - acc: 0.7859 - val_loss: 0.4021 - val_acc: 0.9561
#
# Epoch 00002: val_loss improved from 0.57849 to 0.40209, saving model to my_checkpoint.ckpt
# Epoch 3/30
# 26/26 [==============================] - 2s 94ms/step - loss: 0.2555 - acc: 0.9136 - val_loss: 12.4260 - val_acc: 0.5659
#
# Epoch 00003: val_loss did not improve from 0.40209
# Epoch 4/30
# 26/26 [==============================] - 2s 93ms/step - loss: 0.7725 - acc: 0.9209 - val_loss: 0.0442 - val_acc: 0.9805
#
# Epoch 00004: val_loss improved from 0.40209 to 0.04423, saving model to my_checkpoint.ckpt
# Epoch 5/30
# 26/26 [==============================] - 2s 92ms/step - loss: 0.1290 - acc: 0.9562 - val_loss: 0.0302 - val_acc: 0.9854
#
# Epoch 00005: val_loss improved from 0.04423 to 0.03021, saving model to my_checkpoint.ckpt
# Epoch 6/30
# 26/26 [==============================] - 2s 91ms/step - loss: 0.1328 - acc: 0.9611 - val_loss: 1.1551 - val_acc: 0.8390
#
# Epoch 00006: val_loss did not improve from 0.03021
# Epoch 7/30
# 26/26 [==============================] - 2s 93ms/step - loss: 0.0971 - acc: 0.9745 - val_loss: 0.0137 - val_acc: 1.0000
#
# Epoch 00007: val_loss improved from 0.03021 to 0.01373, saving model to my_checkpoint.ckpt
# Epoch 8/30
# 26/26 [==============================] - 3s 96ms/step - loss: 0.0874 - acc: 0.9769 - val_loss: 0.0136 - val_acc: 0.9902
#
# Epoch 00008: val_loss improved from 0.01373 to 0.01364, saving model to my_checkpoint.ckpt
# Epoch 9/30
# 26/26 [==============================] - 3s 98ms/step - loss: 0.1198 - acc: 0.9708 - val_loss: 0.0436 - val_acc: 0.9854
#
# Epoch 00009: val_loss did not improve from 0.01364
# Epoch 10/30
# 26/26 [==============================] - 3s 94ms/step - loss: 0.0162 - acc: 0.9951 - val_loss: 0.0062 - val_acc: 1.0000
#
# Epoch 00010: val_loss improved from 0.01364 to 0.00622, saving model to my_checkpoint.ckpt
# Epoch 11/30
# 26/26 [==============================] - 2s 91ms/step - loss: 0.1016 - acc: 0.9696 - val_loss: 0.0403 - val_acc: 0.9854
#
# Epoch 00011: val_loss did not improve from 0.00622
# Epoch 12/30
# 26/26 [==============================] - 2s 91ms/step - loss: 0.1756 - acc: 0.9635 - val_loss: 0.0113 - val_acc: 1.0000
#
# Epoch 00012: val_loss did not improve from 0.00622
# Epoch 13/30
# 26/26 [==============================] - 2s 92ms/step - loss: 0.0352 - acc: 0.9891 - val_loss: 0.0104 - val_acc: 0.9951
#
# Epoch 00013: val_loss did not improve from 0.00622
# Epoch 14/30
# 26/26 [==============================] - 2s 93ms/step - loss: 0.0073 - acc: 0.9951 - val_loss: 0.1118 - val_acc: 0.9756
#
# Epoch 00014: val_loss did not improve from 0.00622
# Epoch 15/30
# 26/26 [==============================] - 2s 92ms/step - loss: 0.9977 - acc: 0.9696 - val_loss: 0.0066 - val_acc: 0.9951
#
# Epoch 00015: val_loss did not improve from 0.00622
# Epoch 16/30
# 26/26 [==============================] - 3s 94ms/step - loss: 6.9723e-04 - acc: 1.0000 - val_loss: 8.2567e-04 - val_acc: 1.0000
#
# Epoch 00016: val_loss improved from 0.00622 to 0.00083, saving model to my_checkpoint.ckpt
# Epoch 17/30
# 26/26 [==============================] - 2s 91ms/step - loss: 1.3651e-04 - acc: 1.0000 - val_loss: 4.3641e-04 - val_acc: 1.0000
#
# Epoch 00017: val_loss improved from 0.00083 to 0.00044, saving model to my_checkpoint.ckpt
# Epoch 18/30
# 26/26 [==============================] - 2s 93ms/step - loss: 0.0975 - acc: 0.9891 - val_loss: 0.0042 - val_acc: 1.0000
#
# Epoch 00018: val_loss did not improve from 0.00044
# Epoch 19/30
# 26/26 [==============================] - 2s 91ms/step - loss: 1.3438e-04 - acc: 1.0000 - val_loss: 3.7505e-04 - val_acc: 1.0000
#
# Epoch 00019: val_loss improved from 0.00044 to 0.00038, saving model to my_checkpoint.ckpt
# Epoch 20/30
# 26/26 [==============================] - 2s 93ms/step - loss: 4.4012e-05 - acc: 1.0000 - val_loss: 0.0096 - val_acc: 0.9951
#
# Epoch 00020: val_loss did not improve from 0.00038
# Epoch 21/30
# 26/26 [==============================] - 3s 95ms/step - loss: 1.1518 - acc: 0.9453 - val_loss: 0.0083 - val_acc: 0.9902
#
# Epoch 00021: val_loss did not improve from 0.00038
# Epoch 22/30
# 26/26 [==============================] - 2s 94ms/step - loss: 4.7581e-04 - acc: 1.0000 - val_loss: 3.9127e-04 - val_acc: 1.0000
#
# Epoch 00022: val_loss did not improve from 0.00038
# Epoch 23/30
# 26/26 [==============================] - 2s 93ms/step - loss: 9.2297e-05 - acc: 1.0000 - val_loss: 0.0013 - val_acc: 1.0000
#
# Epoch 00023: val_loss did not improve from 0.00038
# Epoch 24/30
# 26/26 [==============================] - 3s 95ms/step - loss: 8.7356e-05 - acc: 1.0000 - val_loss: 1.0914e-04 - val_acc: 1.0000
#
# Epoch 00024: val_loss improved from 0.00038 to 0.00011, saving model to my_checkpoint.ckpt
# Epoch 25/30
# 26/26 [==============================] - 3s 96ms/step - loss: 0.1913 - acc: 0.9854 - val_loss: 0.0091 - val_acc: 0.9951
#
# Epoch 00025: val_loss did not improve from 0.00011
# Epoch 26/30
# 26/26 [==============================] - 3s 95ms/step - loss: 0.0076 - acc: 0.9976 - val_loss: 7.9091e-04 - val_acc: 1.0000
#
# Epoch 00026: val_loss did not improve from 0.00011
# Epoch 27/30
# 26/26 [==============================] - 3s 95ms/step - loss: 1.4390e-04 - acc: 1.0000 - val_loss: 0.0011 - val_acc: 1.0000
#
# Epoch 00027: val_loss did not improve from 0.00011
# Epoch 28/30
# 26/26 [==============================] - 2s 95ms/step - loss: 1.4312e-05 - acc: 1.0000 - val_loss: 0.0036 - val_acc: 1.0000
#
# Epoch 00028: val_loss did not improve from 0.00011
# Epoch 29/30
# 26/26 [==============================] - 2s 94ms/step - loss: 1.0329e-05 - acc: 1.0000 - val_loss: 0.0016 - val_acc: 1.0000
#
# Epoch 00029: val_loss did not improve from 0.00011
# Epoch 30/30
# 26/26 [==============================] - 3s 106ms/step - loss: 1.6296e-06 - acc: 1.0000 - val_loss: 4.1612e-06 - val_acc: 1.0000
#
# Epoch 00030: val_loss improved from 0.00011 to 0.00000, saving model to my_checkpoint.ckpt

# %% [markdown]
# #TF3-horsesorhumans-A-5-val-loss-0.00027

# %%
# ======================================================================
# There are 5 questions in this test with increasing difficulty from 1-5
# Please note that the weight of the grade for the question is relative
# to its difficulty. So your Category 1 question will score much less
# than your Category 5 question.
# ======================================================================
#
# Computer Vision with CNNs
#
# This task requires you to create a classifier for horses or humans using
# the provided dataset. 
#
# Please make sure your final layer has 2 neurons, activated by softmax 
# as shown. Do not change the provided output layer, or tests may fail.
#
# IMPORTANT: Please note that the test uses images that are 300x300 with 
# 3 bytes color depth so be sure to design your input layer to accept
# these, or the tests will fail.
#

# =========== 합격 기준 가이드라인 공유 ============= #
# val_loss 기준에 맞춰 주시는 것이 훨씬 더 중요 #
# val_loss 보다 조금 높아도 상관없음. (언저리까지 OK) #
# =================================================== #
# 문제명: Category 3 - Horses Or Humans type A
# val_loss: 0.028
# val_acc: 0.98
# =================================================== #
# =================================================== #


import tensorflow_datasets as tfds
import tensorflow as tf

from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import ModelCheckpoint
from keras.optimizers import RMSprop


dataset_name = 'horses_or_humans'
train_dataset = tfds.load(name=dataset_name, split='train[:80%]')
valid_dataset = tfds.load(name=dataset_name, split='train[80%:]')

def preprocess(data):
    # YOUR CODE HERE
    x = data['image']
    y = data['label']
    x = tf.cast(x, tf.float32) / 255.0
    x = tf.image.resize(x, size=(300, 300))
    return x, y


def solution_model():
    batch_size=32
    train_data = train_dataset.map(preprocess).batch(batch_size)
    valid_data = valid_dataset.map(preprocess).batch(batch_size)

    model = Sequential([
        Conv2D(16, (3, 3), activation='relu', input_shape=(300, 300, 3)),
        MaxPooling2D(2, 2),
        Conv2D(32, (3, 3), activation='relu'),
        MaxPooling2D(2, 2),
        Conv2D(64, (3, 3), activation='relu'),
        MaxPooling2D(2, 2),
        Conv2D(64, (3, 3), activation='relu'),
        MaxPooling2D(2, 2),
        Conv2D(128, (3, 3), activation='relu'),
        MaxPooling2D(2, 2),
        Flatten(),
        Dropout(0.5),
        Dense(128, activation='relu'),
    # YOUR CODE HERE, BUT MAKE SURE YOUR LAST LAYER HAS 2 NEURONS ACTIVATED BY SOFTMAX
        Dense(2, activation='softmax')
    ])

    model.compile(optimizer=RMSprop(lr=0.001), loss='sparse_categorical_crossentropy', metrics=['acc'])

    checkpoint_path = "my_checkpoint.ckpt"
    checkpoint = ModelCheckpoint(filepath=checkpoint_path, 
                                save_weights_only=True, 
                                save_best_only=True, 
                                monitor='val_loss', 
                                verbose=1)
    model.fit(train_data,
                validation_data=(valid_data),
                epochs=30,
                callbacks=[checkpoint],
                )
    model.load_weights(checkpoint_path)

    return model


# Note that you'll need to save your model as a .h5 like this
# This .h5 will be uploaded to the testing infrastructure
# and a score will be returned to you
if __name__ == '__main__':
    model = solution_model()
    model.save("mymodel.h5")
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# Epoch 1/30
# 26/26 [==============================] - 4s 103ms/step - loss: 0.7483 - acc: 0.6533 - val_loss: 0.2985 - val_acc: 0.8878
#
# Epoch 00001: val_loss improved from inf to 0.29849, saving model to my_checkpoint.ckpt
# Epoch 2/30
# 26/26 [==============================] - 3s 94ms/step - loss: 0.2820 - acc: 0.8881 - val_loss: 0.1493 - val_acc: 0.9415
#
# Epoch 00002: val_loss improved from 0.29849 to 0.14930, saving model to my_checkpoint.ckpt
# Epoch 3/30
# 26/26 [==============================] - 3s 95ms/step - loss: 0.1744 - acc: 0.9416 - val_loss: 0.1282 - val_acc: 0.9317
#
# Epoch 00003: val_loss improved from 0.14930 to 0.12825, saving model to my_checkpoint.ckpt
# Epoch 4/30
# 26/26 [==============================] - 3s 96ms/step - loss: 0.1341 - acc: 0.9453 - val_loss: 0.0789 - val_acc: 0.9659
#
# Epoch 00004: val_loss improved from 0.12825 to 0.07892, saving model to my_checkpoint.ckpt
# Epoch 5/30
# 26/26 [==============================] - 2s 92ms/step - loss: 0.0980 - acc: 0.9708 - val_loss: 0.1134 - val_acc: 0.9610
#
# Epoch 00005: val_loss did not improve from 0.07892
# Epoch 6/30
# 26/26 [==============================] - 3s 94ms/step - loss: 0.0866 - acc: 0.9769 - val_loss: 0.1584 - val_acc: 0.9512
#
# Epoch 00006: val_loss did not improve from 0.07892
# Epoch 7/30
# 26/26 [==============================] - 3s 94ms/step - loss: 0.0509 - acc: 0.9818 - val_loss: 0.0573 - val_acc: 0.9805
#
# Epoch 00007: val_loss improved from 0.07892 to 0.05725, saving model to my_checkpoint.ckpt
# Epoch 8/30
# 26/26 [==============================] - 3s 95ms/step - loss: 0.2257 - acc: 0.9635 - val_loss: 0.0056 - val_acc: 1.0000
#
# Epoch 00008: val_loss improved from 0.05725 to 0.00555, saving model to my_checkpoint.ckpt
# Epoch 9/30
# 26/26 [==============================] - 3s 95ms/step - loss: 0.0050 - acc: 0.9988 - val_loss: 0.0055 - val_acc: 1.0000
#
# Epoch 00009: val_loss improved from 0.00555 to 0.00546, saving model to my_checkpoint.ckpt
# Epoch 10/30
# 26/26 [==============================] - 3s 98ms/step - loss: 0.0811 - acc: 0.9818 - val_loss: 0.0671 - val_acc: 0.9854
#
# Epoch 00010: val_loss did not improve from 0.00546
# Epoch 11/30
# 26/26 [==============================] - 3s 94ms/step - loss: 0.0206 - acc: 0.9964 - val_loss: 0.0046 - val_acc: 1.0000
#
# Epoch 00011: val_loss improved from 0.00546 to 0.00465, saving model to my_checkpoint.ckpt
# Epoch 12/30
# 26/26 [==============================] - 3s 95ms/step - loss: 0.0445 - acc: 0.9842 - val_loss: 0.0034 - val_acc: 1.0000
#
# Epoch 00012: val_loss improved from 0.00465 to 0.00339, saving model to my_checkpoint.ckpt
# Epoch 13/30
# 26/26 [==============================] - 2s 93ms/step - loss: 5.6008e-04 - acc: 1.0000 - val_loss: 0.0045 - val_acc: 0.9951
#
# Epoch 00013: val_loss did not improve from 0.00339
# Epoch 14/30
# 26/26 [==============================] - 2s 94ms/step - loss: 3.6269e-05 - acc: 1.0000 - val_loss: 0.0034 - val_acc: 1.0000
#
# Epoch 00014: val_loss did not improve from 0.00339
# Epoch 15/30
# 26/26 [==============================] - 3s 96ms/step - loss: 0.1864 - acc: 0.9781 - val_loss: 0.0394 - val_acc: 0.9902
#
# Epoch 00015: val_loss did not improve from 0.00339
# Epoch 16/30
# 26/26 [==============================] - 3s 99ms/step - loss: 0.1533 - acc: 0.9757 - val_loss: 0.0106 - val_acc: 0.9951
#
# Epoch 00016: val_loss did not improve from 0.00339
# Epoch 17/30
# 26/26 [==============================] - 3s 95ms/step - loss: 0.0040 - acc: 0.9988 - val_loss: 0.0251 - val_acc: 0.9902
#
# Epoch 00017: val_loss did not improve from 0.00339
# Epoch 18/30
# 26/26 [==============================] - 3s 94ms/step - loss: 3.0322e-04 - acc: 1.0000 - val_loss: 0.0047 - val_acc: 0.9951
#
# Epoch 00018: val_loss did not improve from 0.00339
# Epoch 19/30
# 26/26 [==============================] - 3s 95ms/step - loss: 0.0892 - acc: 0.9891 - val_loss: 0.0156 - val_acc: 0.9951
#
# Epoch 00019: val_loss did not improve from 0.00339
# Epoch 20/30
# 26/26 [==============================] - 2s 95ms/step - loss: 3.3640e-04 - acc: 1.0000 - val_loss: 0.0036 - val_acc: 1.0000
#
# Epoch 00020: val_loss did not improve from 0.00339
# Epoch 21/30
# 26/26 [==============================] - 3s 94ms/step - loss: 0.0605 - acc: 0.9891 - val_loss: 0.0189 - val_acc: 0.9902
#
# Epoch 00021: val_loss did not improve from 0.00339
# Epoch 22/30
# 26/26 [==============================] - 2s 94ms/step - loss: 0.0222 - acc: 0.9939 - val_loss: 0.0228 - val_acc: 0.9951
#
# Epoch 00022: val_loss did not improve from 0.00339
# Epoch 23/30
# 26/26 [==============================] - 3s 94ms/step - loss: 3.2382e-04 - acc: 1.0000 - val_loss: 0.0158 - val_acc: 0.9951
#
# Epoch 00023: val_loss did not improve from 0.00339
# Epoch 24/30
# 26/26 [==============================] - 2s 94ms/step - loss: 6.9578e-04 - acc: 1.0000 - val_loss: 0.3271 - val_acc: 0.9659
#
# Epoch 00024: val_loss did not improve from 0.00339
# Epoch 25/30
# 26/26 [==============================] - 2s 94ms/step - loss: 0.3739 - acc: 0.9672 - val_loss: 0.0081 - val_acc: 0.9951
#
# Epoch 00025: val_loss did not improve from 0.00339
# Epoch 26/30
# 26/26 [==============================] - 3s 95ms/step - loss: 6.7593e-04 - acc: 1.0000 - val_loss: 0.0093 - val_acc: 0.9951
#
# Epoch 00026: val_loss did not improve from 0.00339
# Epoch 27/30
# 26/26 [==============================] - 2s 94ms/step - loss: 6.6493e-04 - acc: 1.0000 - val_loss: 0.2406 - val_acc: 0.9707
#
# Epoch 00027: val_loss did not improve from 0.00339
# Epoch 28/30
# 26/26 [==============================] - 3s 95ms/step - loss: 0.0913 - acc: 0.9793 - val_loss: 0.0022 - val_acc: 1.0000
#
# Epoch 00028: val_loss improved from 0.00339 to 0.00219, saving model to my_checkpoint.ckpt
# Epoch 29/30
# 26/26 [==============================] - 2s 94ms/step - loss: 2.7412e-04 - acc: 1.0000 - val_loss: 2.7212e-04 - val_acc: 1.0000
#
# Epoch 00029: val_loss improved from 0.00219 to 0.00027, saving model to my_checkpoint.ckpt
# Epoch 30/30
# 26/26 [==============================] - 3s 96ms/step - loss: 1.7666e-04 - acc: 1.0000 - val_loss: 0.0130 - val_acc: 0.9951
#
# Epoch 00030: val_loss did not improve from 0.00027
