# %% [markdown]
# <a href="https://colab.research.google.com/github/danaing/TensorFlow-cert/blob/main/TF5_sunspots_type_B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# QUESTION
#
# For this task you will need to train a neural network
# to predict sunspot activity using the Sunspots.csv dataset.
# Your neural network must  have an MAE
# of 0.12 or less on the normalized dataset for top marks.
# Code for normalizing the data is provided and should not be changed.
# At the bottom of this file, we provide  some testing
# code should you want to check your model.

# Note: Do not use lambda layers in your model, they are not supported
# on the grading infrastructure.

# =========== 합격 기준 가이드라인 공유 ============= #
# val_loss 기준에 맞춰 주시는 것이 훨씬 더 중요 #
# val_loss 보다 조금 높아도 상관없음. (언저리까지 OK) #
# =================================================== #
# 문제명: Category 5 - sunspots type B (NO Lambda)
# val_loss: 상관없음
# val_mae: 0.1121
# =================================================== #
# =================================================== #


import csv
import tensorflow as tf
import numpy as np
import urllib

from tensorflow.keras.layers import Dense, LSTM, Lambda, Conv1D
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.losses import Huber




# DO NOT CHANGE THIS CODE
def windowed_dataset(series, window_size, batch_size, shuffle_buffer):
    series = tf.expand_dims(series, axis=-1)
    ds = tf.data.Dataset.from_tensor_slices(series)
    ds = ds.window(window_size + 1, shift=1, drop_remainder=True)
    ds = ds.flat_map(lambda w: w.batch(window_size + 1))
    ds = ds.shuffle(shuffle_buffer)
    ds = ds.map(lambda w: (w[:-1], w[1:]))
    return ds.batch(batch_size).prefetch(1)


def solution_model():
    url = 'https://storage.googleapis.com/download.tensorflow.org/data/Sunspots.csv'
    urllib.request.urlretrieve(url, 'sunspots.csv')

    time_step = []
    sunspots = []

    with open('sunspots.csv') as csvfile:
      reader = csv.reader(csvfile, delimiter=',')
      next(reader)
      for row in reader:
        sunspots.append(float(row[2]))
        time_step.append(int(row[0]))

    series = np.array(sunspots)

    # DO NOT CHANGE THIS CODE
    # This is the normalization function
    min = np.min(series)
    max = np.max(series)
    series -= min
    series /= max
    time = np.array(time_step)

    # The data should be split into training and validation sets at time step 3000
    # DO NOT CHANGE THIS CODE
    split_time = 3000

    time_train = time[:split_time]
    time_valid = time[split_time:]

    x_train = series[:split_time]
    x_valid = series[split_time:]

    # DO NOT CHANGE THIS CODE
    window_size = 30
    batch_size = 32
    shuffle_buffer_size = 1000


    train_set = windowed_dataset(x_train, 
                                 window_size=window_size, 
                                 batch_size=batch_size, 
                                 shuffle_buffer=shuffle_buffer_size)
    validation_set = windowed_dataset(x_valid, 
                                      window_size=window_size,
                                      batch_size=batch_size,
                                      shuffle_buffer=shuffle_buffer_size)

    model = tf.keras.models.Sequential([
      # YOUR CODE HERE. Whatever your first layer is, the input shape will be [None,1] when using the Windowed_dataset above, depending on the layer type chosen
        tf.keras.layers.Conv1D(60, kernel_size=5,
                            padding="causal",
                            activation="relu",
                            input_shape=[None, 1]),
        tf.keras.layers.LSTM(60, return_sequences=True),
        tf.keras.layers.LSTM(60, return_sequences=True),
        tf.keras.layers.Dense(30, activation="relu"),
        tf.keras.layers.Dense(10, activation="relu"),
        tf.keras.layers.Dense(1)
    ])

    # YOUR CODE HERE TO COMPILE AND TRAIN THE MODEL
    optimizer = SGD(learning_rate=1e-5, momentum=0.9)
    loss= Huber()
    model.compile(loss=loss,
                  optimizer=optimizer,
                  metrics=["mae"])
    
    checkpoint_path = 'tmp_checkpoint.ckpt'
    checkpoint = ModelCheckpoint(checkpoint_path, 
                                save_weights_only=True, 
                                save_best_only=True, 
                                monitor='val_mae',
                                verbose=1)
    epochs=100
    history = model.fit(train_set, 
                        validation_data=(validation_set), 
                        epochs=epochs, 
                        callbacks=[checkpoint],
                      )
    model.load_weights(checkpoint_path)


    return model


# Note that you'll need to save your model as a .h5 like this.
# When you press the Submit and Test button, this .h5 model will be
# sent to the testing infrastructure for scoring.

# You must use the Submit and Test button to submit your model
# at least once in each category before you finally submit your exam.

if __name__ == '__main__':
    model = solution_model()
    model.save("TF5-sunspots-type-B.h5")



# THIS CODE IS USED IN THE TESTER FOR FORECASTING. IF YOU WANT TO TEST YOUR MODEL
# BEFORE UPLOADING YOU CAN DO IT WITH THIS
#def model_forecast(model, series, window_size):
#    ds = tf.data.Dataset.from_tensor_slices(series)
#    ds = ds.window(window_size, shift=1, drop_remainder=True)
#    ds = ds.flat_map(lambda w: w.batch(window_size))
#    ds = ds.batch(32).prefetch(1)
#    forecast = model.predict(ds)
#    return forecast


#window_size = # YOUR CODE HERE
#rnn_forecast = model_forecast(model, series[..., np.newaxis], window_size)
#rnn_forecast = rnn_forecast[split_time - window_size:-1, -1, 0]

#result = tf.keras.metrics.mean_absolute_error(x_valid, rnn_forecast).numpy()

## To get the maximum score, your model must have an MAE OF .12 or less.
## When you Submit and Test your model, the grading infrastructure
## converts the MAE of your model to a score from 0 to 5 as follows:

#test_val = 100 * result
#score = math.ceil(17 - test_val)
#if score > 5:
#    score = 5

#print(score)
# Out:
# Epoch 1/100
# 93/93 [==============================] - 4s 16ms/step - loss: 0.0404 - mae: 0.2196 - val_loss: 0.0282 - val_mae: 0.1865
#
# Epoch 00001: val_mae improved from inf to 0.18653, saving model to tmp_checkpoint.ckpt
# Epoch 2/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0390 - mae: 0.2141 - val_loss: 0.0272 - val_mae: 0.1816
#
# Epoch 00002: val_mae improved from 0.18653 to 0.18162, saving model to tmp_checkpoint.ckpt
# Epoch 3/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0379 - mae: 0.2095 - val_loss: 0.0263 - val_mae: 0.1775
#
# Epoch 00003: val_mae improved from 0.18162 to 0.17749, saving model to tmp_checkpoint.ckpt
# Epoch 4/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0368 - mae: 0.2056 - val_loss: 0.0254 - val_mae: 0.1739
#
# Epoch 00004: val_mae improved from 0.17749 to 0.17388, saving model to tmp_checkpoint.ckpt
# Epoch 5/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0359 - mae: 0.2021 - val_loss: 0.0247 - val_mae: 0.1707
#
# Epoch 00005: val_mae improved from 0.17388 to 0.17071, saving model to tmp_checkpoint.ckpt
# Epoch 6/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0351 - mae: 0.1990 - val_loss: 0.0241 - val_mae: 0.1679
#
# Epoch 00006: val_mae improved from 0.17071 to 0.16795, saving model to tmp_checkpoint.ckpt
# Epoch 7/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0343 - mae: 0.1962 - val_loss: 0.0235 - val_mae: 0.1655
#
# Epoch 00007: val_mae improved from 0.16795 to 0.16550, saving model to tmp_checkpoint.ckpt
# Epoch 8/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0336 - mae: 0.1936 - val_loss: 0.0230 - val_mae: 0.1633
#
# Epoch 00008: val_mae improved from 0.16550 to 0.16326, saving model to tmp_checkpoint.ckpt
# Epoch 9/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0330 - mae: 0.1912 - val_loss: 0.0225 - val_mae: 0.1612
#
# Epoch 00009: val_mae improved from 0.16326 to 0.16119, saving model to tmp_checkpoint.ckpt
# Epoch 10/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0324 - mae: 0.1890 - val_loss: 0.0220 - val_mae: 0.1592
#
# Epoch 00010: val_mae improved from 0.16119 to 0.15922, saving model to tmp_checkpoint.ckpt
# Epoch 11/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0319 - mae: 0.1868 - val_loss: 0.0216 - val_mae: 0.1573
#
# Epoch 00011: val_mae improved from 0.15922 to 0.15730, saving model to tmp_checkpoint.ckpt
# Epoch 12/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0313 - mae: 0.1847 - val_loss: 0.0212 - val_mae: 0.1554
#
# Epoch 00012: val_mae improved from 0.15730 to 0.15542, saving model to tmp_checkpoint.ckpt
# Epoch 13/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0308 - mae: 0.1827 - val_loss: 0.0207 - val_mae: 0.1537
#
# Epoch 00013: val_mae improved from 0.15542 to 0.15366, saving model to tmp_checkpoint.ckpt
# Epoch 14/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0303 - mae: 0.1808 - val_loss: 0.0204 - val_mae: 0.1520
#
# Epoch 00014: val_mae improved from 0.15366 to 0.15196, saving model to tmp_checkpoint.ckpt
# Epoch 15/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0298 - mae: 0.1791 - val_loss: 0.0200 - val_mae: 0.1503
#
# Epoch 00015: val_mae improved from 0.15196 to 0.15033, saving model to tmp_checkpoint.ckpt
# Epoch 16/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0294 - mae: 0.1774 - val_loss: 0.0197 - val_mae: 0.1488
#
# Epoch 00016: val_mae improved from 0.15033 to 0.14881, saving model to tmp_checkpoint.ckpt
# Epoch 17/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0290 - mae: 0.1758 - val_loss: 0.0193 - val_mae: 0.1473
#
# Epoch 00017: val_mae improved from 0.14881 to 0.14733, saving model to tmp_checkpoint.ckpt
# Epoch 18/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0286 - mae: 0.1743 - val_loss: 0.0190 - val_mae: 0.1459
#
# Epoch 00018: val_mae improved from 0.14733 to 0.14594, saving model to tmp_checkpoint.ckpt
# Epoch 19/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0282 - mae: 0.1728 - val_loss: 0.0187 - val_mae: 0.1446
#
# Epoch 00019: val_mae improved from 0.14594 to 0.14459, saving model to tmp_checkpoint.ckpt
# Epoch 20/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0278 - mae: 0.1714 - val_loss: 0.0185 - val_mae: 0.1433
#
# Epoch 00020: val_mae improved from 0.14459 to 0.14330, saving model to tmp_checkpoint.ckpt
# Epoch 21/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0275 - mae: 0.1701 - val_loss: 0.0182 - val_mae: 0.1421
#
# Epoch 00021: val_mae improved from 0.14330 to 0.14210, saving model to tmp_checkpoint.ckpt
# Epoch 22/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0271 - mae: 0.1688 - val_loss: 0.0179 - val_mae: 0.1409
#
# Epoch 00022: val_mae improved from 0.14210 to 0.14094, saving model to tmp_checkpoint.ckpt
# Epoch 23/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0268 - mae: 0.1676 - val_loss: 0.0177 - val_mae: 0.1398
#
# Epoch 00023: val_mae improved from 0.14094 to 0.13984, saving model to tmp_checkpoint.ckpt
# Epoch 24/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0265 - mae: 0.1664 - val_loss: 0.0174 - val_mae: 0.1388
#
# Epoch 00024: val_mae improved from 0.13984 to 0.13880, saving model to tmp_checkpoint.ckpt
# Epoch 25/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0262 - mae: 0.1653 - val_loss: 0.0172 - val_mae: 0.1378
#
# Epoch 00025: val_mae improved from 0.13880 to 0.13780, saving model to tmp_checkpoint.ckpt
# Epoch 26/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0259 - mae: 0.1642 - val_loss: 0.0170 - val_mae: 0.1368
#
# Epoch 00026: val_mae improved from 0.13780 to 0.13684, saving model to tmp_checkpoint.ckpt
# Epoch 27/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0256 - mae: 0.1632 - val_loss: 0.0167 - val_mae: 0.1359
#
# Epoch 00027: val_mae improved from 0.13684 to 0.13593, saving model to tmp_checkpoint.ckpt
# Epoch 28/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0253 - mae: 0.1622 - val_loss: 0.0165 - val_mae: 0.1350
#
# Epoch 00028: val_mae improved from 0.13593 to 0.13505, saving model to tmp_checkpoint.ckpt
# Epoch 29/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0250 - mae: 0.1612 - val_loss: 0.0163 - val_mae: 0.1342
#
# Epoch 00029: val_mae improved from 0.13505 to 0.13419, saving model to tmp_checkpoint.ckpt
# Epoch 30/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0247 - mae: 0.1603 - val_loss: 0.0161 - val_mae: 0.1334
#
# Epoch 00030: val_mae improved from 0.13419 to 0.13335, saving model to tmp_checkpoint.ckpt
# Epoch 31/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0245 - mae: 0.1593 - val_loss: 0.0159 - val_mae: 0.1325
#
# Epoch 00031: val_mae improved from 0.13335 to 0.13255, saving model to tmp_checkpoint.ckpt
# Epoch 32/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0242 - mae: 0.1585 - val_loss: 0.0157 - val_mae: 0.1318
#
# Epoch 00032: val_mae improved from 0.13255 to 0.13178, saving model to tmp_checkpoint.ckpt
# Epoch 33/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0240 - mae: 0.1576 - val_loss: 0.0155 - val_mae: 0.1310
#
# Epoch 00033: val_mae improved from 0.13178 to 0.13105, saving model to tmp_checkpoint.ckpt
# Epoch 34/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0237 - mae: 0.1568 - val_loss: 0.0153 - val_mae: 0.1304
#
# Epoch 00034: val_mae improved from 0.13105 to 0.13035, saving model to tmp_checkpoint.ckpt
# Epoch 35/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0235 - mae: 0.1560 - val_loss: 0.0151 - val_mae: 0.1297
#
# Epoch 00035: val_mae improved from 0.13035 to 0.12967, saving model to tmp_checkpoint.ckpt
# Epoch 36/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0233 - mae: 0.1552 - val_loss: 0.0150 - val_mae: 0.1290
#
# Epoch 00036: val_mae improved from 0.12967 to 0.12902, saving model to tmp_checkpoint.ckpt
# Epoch 37/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0230 - mae: 0.1544 - val_loss: 0.0148 - val_mae: 0.1284
#
# Epoch 00037: val_mae improved from 0.12902 to 0.12837, saving model to tmp_checkpoint.ckpt
# Epoch 38/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0228 - mae: 0.1537 - val_loss: 0.0146 - val_mae: 0.1277
#
# Epoch 00038: val_mae improved from 0.12837 to 0.12774, saving model to tmp_checkpoint.ckpt
# Epoch 39/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0226 - mae: 0.1529 - val_loss: 0.0145 - val_mae: 0.1271
#
# Epoch 00039: val_mae improved from 0.12774 to 0.12714, saving model to tmp_checkpoint.ckpt
# Epoch 40/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0224 - mae: 0.1522 - val_loss: 0.0143 - val_mae: 0.1266
#
# Epoch 00040: val_mae improved from 0.12714 to 0.12656, saving model to tmp_checkpoint.ckpt
# Epoch 41/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0222 - mae: 0.1515 - val_loss: 0.0142 - val_mae: 0.1260
#
# Epoch 00041: val_mae improved from 0.12656 to 0.12600, saving model to tmp_checkpoint.ckpt
# Epoch 42/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0220 - mae: 0.1509 - val_loss: 0.0140 - val_mae: 0.1255
#
# Epoch 00042: val_mae improved from 0.12600 to 0.12545, saving model to tmp_checkpoint.ckpt
# Epoch 43/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0218 - mae: 0.1502 - val_loss: 0.0139 - val_mae: 0.1249
#
# Epoch 00043: val_mae improved from 0.12545 to 0.12492, saving model to tmp_checkpoint.ckpt
# Epoch 44/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0216 - mae: 0.1496 - val_loss: 0.0137 - val_mae: 0.1244
#
# Epoch 00044: val_mae improved from 0.12492 to 0.12441, saving model to tmp_checkpoint.ckpt
# Epoch 45/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0214 - mae: 0.1490 - val_loss: 0.0136 - val_mae: 0.1239
#
# Epoch 00045: val_mae improved from 0.12441 to 0.12391, saving model to tmp_checkpoint.ckpt
# Epoch 46/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0213 - mae: 0.1484 - val_loss: 0.0135 - val_mae: 0.1234
#
# Epoch 00046: val_mae improved from 0.12391 to 0.12341, saving model to tmp_checkpoint.ckpt
# Epoch 47/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0211 - mae: 0.1478 - val_loss: 0.0133 - val_mae: 0.1229
#
# Epoch 00047: val_mae improved from 0.12341 to 0.12293, saving model to tmp_checkpoint.ckpt
# Epoch 48/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0209 - mae: 0.1473 - val_loss: 0.0132 - val_mae: 0.1225
#
# Epoch 00048: val_mae improved from 0.12293 to 0.12247, saving model to tmp_checkpoint.ckpt
# Epoch 49/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0207 - mae: 0.1467 - val_loss: 0.0131 - val_mae: 0.1220
#
# Epoch 00049: val_mae improved from 0.12247 to 0.12201, saving model to tmp_checkpoint.ckpt
# Epoch 50/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0206 - mae: 0.1462 - val_loss: 0.0130 - val_mae: 0.1216
#
# Epoch 00050: val_mae improved from 0.12201 to 0.12158, saving model to tmp_checkpoint.ckpt
# Epoch 51/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0204 - mae: 0.1457 - val_loss: 0.0129 - val_mae: 0.1212
#
# Epoch 00051: val_mae improved from 0.12158 to 0.12117, saving model to tmp_checkpoint.ckpt
# Epoch 52/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0203 - mae: 0.1452 - val_loss: 0.0127 - val_mae: 0.1208
#
# Epoch 00052: val_mae improved from 0.12117 to 0.12078, saving model to tmp_checkpoint.ckpt
# Epoch 53/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0201 - mae: 0.1447 - val_loss: 0.0126 - val_mae: 0.1204
#
# Epoch 00053: val_mae improved from 0.12078 to 0.12041, saving model to tmp_checkpoint.ckpt
# Epoch 54/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0199 - mae: 0.1443 - val_loss: 0.0125 - val_mae: 0.1201
#
# Epoch 00054: val_mae improved from 0.12041 to 0.12005, saving model to tmp_checkpoint.ckpt
# Epoch 55/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0198 - mae: 0.1438 - val_loss: 0.0124 - val_mae: 0.1197
#
# Epoch 00055: val_mae improved from 0.12005 to 0.11971, saving model to tmp_checkpoint.ckpt
# Epoch 56/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0197 - mae: 0.1434 - val_loss: 0.0123 - val_mae: 0.1194
#
# Epoch 00056: val_mae improved from 0.11971 to 0.11937, saving model to tmp_checkpoint.ckpt
# Epoch 57/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0195 - mae: 0.1430 - val_loss: 0.0122 - val_mae: 0.1190
#
# Epoch 00057: val_mae improved from 0.11937 to 0.11903, saving model to tmp_checkpoint.ckpt
# Epoch 58/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0194 - mae: 0.1425 - val_loss: 0.0121 - val_mae: 0.1187
#
# Epoch 00058: val_mae improved from 0.11903 to 0.11870, saving model to tmp_checkpoint.ckpt
# Epoch 59/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0193 - mae: 0.1421 - val_loss: 0.0120 - val_mae: 0.1184
#
# Epoch 00059: val_mae improved from 0.11870 to 0.11838, saving model to tmp_checkpoint.ckpt
# Epoch 60/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0191 - mae: 0.1417 - val_loss: 0.0119 - val_mae: 0.1181
#
# Epoch 00060: val_mae improved from 0.11838 to 0.11806, saving model to tmp_checkpoint.ckpt
# Epoch 61/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0190 - mae: 0.1414 - val_loss: 0.0119 - val_mae: 0.1178
#
# Epoch 00061: val_mae improved from 0.11806 to 0.11775, saving model to tmp_checkpoint.ckpt
# Epoch 62/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0189 - mae: 0.1410 - val_loss: 0.0118 - val_mae: 0.1175
#
# Epoch 00062: val_mae improved from 0.11775 to 0.11745, saving model to tmp_checkpoint.ckpt
# Epoch 63/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0187 - mae: 0.1406 - val_loss: 0.0117 - val_mae: 0.1172
#
# Epoch 00063: val_mae improved from 0.11745 to 0.11716, saving model to tmp_checkpoint.ckpt
# Epoch 64/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0186 - mae: 0.1403 - val_loss: 0.0116 - val_mae: 0.1169
#
# Epoch 00064: val_mae improved from 0.11716 to 0.11686, saving model to tmp_checkpoint.ckpt
# Epoch 65/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0185 - mae: 0.1400 - val_loss: 0.0115 - val_mae: 0.1166
#
# Epoch 00065: val_mae improved from 0.11686 to 0.11658, saving model to tmp_checkpoint.ckpt
# Epoch 66/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0184 - mae: 0.1396 - val_loss: 0.0115 - val_mae: 0.1163
#
# Epoch 00066: val_mae improved from 0.11658 to 0.11630, saving model to tmp_checkpoint.ckpt
# Epoch 67/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0183 - mae: 0.1393 - val_loss: 0.0114 - val_mae: 0.1160
#
# Epoch 00067: val_mae improved from 0.11630 to 0.11603, saving model to tmp_checkpoint.ckpt
# Epoch 68/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0182 - mae: 0.1390 - val_loss: 0.0113 - val_mae: 0.1158
#
# Epoch 00068: val_mae improved from 0.11603 to 0.11576, saving model to tmp_checkpoint.ckpt
# Epoch 69/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0181 - mae: 0.1387 - val_loss: 0.0112 - val_mae: 0.1155
#
# Epoch 00069: val_mae improved from 0.11576 to 0.11550, saving model to tmp_checkpoint.ckpt
# Epoch 70/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0180 - mae: 0.1384 - val_loss: 0.0112 - val_mae: 0.1153
#
# Epoch 00070: val_mae improved from 0.11550 to 0.11525, saving model to tmp_checkpoint.ckpt
# Epoch 71/100
# 93/93 [==============================] - 1s 10ms/step - loss: 0.0179 - mae: 0.1382 - val_loss: 0.0111 - val_mae: 0.1150
#
# Epoch 00071: val_mae improved from 0.11525 to 0.11501, saving model to tmp_checkpoint.ckpt
# Epoch 72/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0178 - mae: 0.1379 - val_loss: 0.0110 - val_mae: 0.1148
#
# Epoch 00072: val_mae improved from 0.11501 to 0.11478, saving model to tmp_checkpoint.ckpt
# Epoch 73/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0177 - mae: 0.1377 - val_loss: 0.0110 - val_mae: 0.1145
#
# Epoch 00073: val_mae improved from 0.11478 to 0.11455, saving model to tmp_checkpoint.ckpt
# Epoch 74/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0176 - mae: 0.1374 - val_loss: 0.0109 - val_mae: 0.1143
#
# Epoch 00074: val_mae improved from 0.11455 to 0.11432, saving model to tmp_checkpoint.ckpt
# Epoch 75/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0175 - mae: 0.1372 - val_loss: 0.0109 - val_mae: 0.1141
#
# Epoch 00075: val_mae improved from 0.11432 to 0.11410, saving model to tmp_checkpoint.ckpt
# Epoch 76/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0174 - mae: 0.1370 - val_loss: 0.0108 - val_mae: 0.1139
#
# Epoch 00076: val_mae improved from 0.11410 to 0.11388, saving model to tmp_checkpoint.ckpt
# Epoch 77/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0173 - mae: 0.1367 - val_loss: 0.0108 - val_mae: 0.1137
#
# Epoch 00077: val_mae improved from 0.11388 to 0.11367, saving model to tmp_checkpoint.ckpt
# Epoch 78/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0172 - mae: 0.1365 - val_loss: 0.0107 - val_mae: 0.1135
#
# Epoch 00078: val_mae improved from 0.11367 to 0.11347, saving model to tmp_checkpoint.ckpt
# Epoch 79/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0172 - mae: 0.1363 - val_loss: 0.0106 - val_mae: 0.1133
#
# Epoch 00079: val_mae improved from 0.11347 to 0.11327, saving model to tmp_checkpoint.ckpt
# Epoch 80/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0171 - mae: 0.1361 - val_loss: 0.0106 - val_mae: 0.1131
#
# Epoch 00080: val_mae improved from 0.11327 to 0.11308, saving model to tmp_checkpoint.ckpt
# Epoch 81/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0170 - mae: 0.1359 - val_loss: 0.0105 - val_mae: 0.1129
#
# Epoch 00081: val_mae improved from 0.11308 to 0.11291, saving model to tmp_checkpoint.ckpt
# Epoch 82/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0169 - mae: 0.1357 - val_loss: 0.0105 - val_mae: 0.1127
#
# Epoch 00082: val_mae improved from 0.11291 to 0.11274, saving model to tmp_checkpoint.ckpt
# Epoch 83/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0168 - mae: 0.1356 - val_loss: 0.0105 - val_mae: 0.1126
#
# Epoch 00083: val_mae improved from 0.11274 to 0.11258, saving model to tmp_checkpoint.ckpt
# Epoch 84/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0168 - mae: 0.1354 - val_loss: 0.0104 - val_mae: 0.1124
#
# Epoch 00084: val_mae improved from 0.11258 to 0.11242, saving model to tmp_checkpoint.ckpt
# Epoch 85/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0167 - mae: 0.1352 - val_loss: 0.0104 - val_mae: 0.1123
#
# Epoch 00085: val_mae improved from 0.11242 to 0.11227, saving model to tmp_checkpoint.ckpt
# Epoch 86/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0166 - mae: 0.1350 - val_loss: 0.0103 - val_mae: 0.1121
#
# Epoch 00086: val_mae improved from 0.11227 to 0.11212, saving model to tmp_checkpoint.ckpt
# Epoch 87/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0166 - mae: 0.1349 - val_loss: 0.0103 - val_mae: 0.1120
#
# Epoch 00087: val_mae improved from 0.11212 to 0.11198, saving model to tmp_checkpoint.ckpt
# Epoch 88/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0165 - mae: 0.1347 - val_loss: 0.0102 - val_mae: 0.1118
#
# Epoch 00088: val_mae improved from 0.11198 to 0.11184, saving model to tmp_checkpoint.ckpt
# Epoch 89/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0164 - mae: 0.1346 - val_loss: 0.0102 - val_mae: 0.1117
#
# Epoch 00089: val_mae improved from 0.11184 to 0.11171, saving model to tmp_checkpoint.ckpt
# Epoch 90/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0164 - mae: 0.1345 - val_loss: 0.0102 - val_mae: 0.1116
#
# Epoch 00090: val_mae improved from 0.11171 to 0.11158, saving model to tmp_checkpoint.ckpt
# Epoch 91/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0163 - mae: 0.1343 - val_loss: 0.0101 - val_mae: 0.1115
#
# Epoch 00091: val_mae improved from 0.11158 to 0.11145, saving model to tmp_checkpoint.ckpt
# Epoch 92/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0162 - mae: 0.1342 - val_loss: 0.0101 - val_mae: 0.1113
#
# Epoch 00092: val_mae improved from 0.11145 to 0.11133, saving model to tmp_checkpoint.ckpt
# Epoch 93/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0162 - mae: 0.1341 - val_loss: 0.0101 - val_mae: 0.1112
#
# Epoch 00093: val_mae improved from 0.11133 to 0.11122, saving model to tmp_checkpoint.ckpt
# Epoch 94/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0161 - mae: 0.1339 - val_loss: 0.0100 - val_mae: 0.1111
#
# Epoch 00094: val_mae improved from 0.11122 to 0.11111, saving model to tmp_checkpoint.ckpt
# Epoch 95/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0161 - mae: 0.1338 - val_loss: 0.0100 - val_mae: 0.1110
#
# Epoch 00095: val_mae improved from 0.11111 to 0.11099, saving model to tmp_checkpoint.ckpt
# Epoch 96/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0160 - mae: 0.1337 - val_loss: 0.0100 - val_mae: 0.1109
#
# Epoch 00096: val_mae improved from 0.11099 to 0.11090, saving model to tmp_checkpoint.ckpt
# Epoch 97/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0160 - mae: 0.1336 - val_loss: 0.0099 - val_mae: 0.1108
#
# Epoch 00097: val_mae improved from 0.11090 to 0.11081, saving model to tmp_checkpoint.ckpt
# Epoch 98/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0159 - mae: 0.1335 - val_loss: 0.0099 - val_mae: 0.1107
#
# Epoch 00098: val_mae improved from 0.11081 to 0.11073, saving model to tmp_checkpoint.ckpt
# Epoch 99/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0159 - mae: 0.1334 - val_loss: 0.0099 - val_mae: 0.1106
#
# Epoch 00099: val_mae improved from 0.11073 to 0.11065, saving model to tmp_checkpoint.ckpt
# Epoch 100/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0158 - mae: 0.1333 - val_loss: 0.0099 - val_mae: 0.1106
#
# Epoch 00100: val_mae improved from 0.11065 to 0.11057, saving model to tmp_checkpoint.ckpt
