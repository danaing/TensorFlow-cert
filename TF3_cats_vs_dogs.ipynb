# %% [markdown]
# <a href="https://colab.research.google.com/github/danaing/TensorFlow-cert/blob/main/TF3_cats_vs_dogs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #TF3-cats-vs-dogs-1

# %%
# ======================================================================
# There are 5 questions in this test with increasing difficulty from 1-5
# Please note that the weight of the grade for the question is relative
# to its difficulty. So your Category 1 question will score much less
# than your Category 5 question.
# ======================================================================
#
# Computer Vision with CNNs
#
# For this exercise you will build a cats v dogs classifier
# using the Cats v Dogs dataset from TFDS.
# Be sure to use the final layer as shown 
#     (Dense, 2 neurons, softmax activation)
#
# The testing infrastructre will resize all images to 224x224 
# with 3 bytes of color depth. Make sure your input layer trains
# images to that specification, or the tests will fail.
#
# Make sure your output layer is exactly as specified here, or the 
# tests will fail.

# =========== 합격 기준 가이드라인 공유 ============= #
# val_loss 기준에 맞춰 주시는 것이 훨씬 더 중요 #
# val_loss 보다 조금 높아도 상관없음. (언저리까지 OK) #
# =================================================== #
# 문제명: Category 3 - cats vs dogs
# val_loss: 0.3158
# val_acc: 0.8665
# =================================================== #
# =================================================== #


import tensorflow_datasets as tfds
import tensorflow as tf

from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import ModelCheckpoint

dataset_name = 'cats_vs_dogs'
train_dataset = tfds.load(name=dataset_name, split='train[:80%]')
valid_dataset = tfds.load(name=dataset_name, split='train[80%:]')

def preprocess(data):
    # x, y 데이터를 정의합니다.
    x = data['image']
    y = data['label']
    # image 정규화(Normalization)
    x = tf.cast(x, tf.float32) / 255.0
    # 사이즈를 (224, 224)로 변환합니다.
    x = tf.image.resize(x, size=(224, 224))
    # x, y  데이터를 return 합니다.
    return x, y


def solution_model():
    batch_size=32
    train_data = train_dataset.map(preprocess).batch(batch_size)
    valid_data = valid_dataset.map(preprocess).batch(batch_size)

    model = Sequential([
        Conv2D(64, (3, 3), input_shape=(224, 224, 3), activation='relu'),
        MaxPooling2D(2, 2),
        Conv2D(64, (3, 3), activation='relu'),
        MaxPooling2D(2, 2),
        Conv2D(128, (3, 3), activation='relu'),
        MaxPooling2D(2, 2),
        Conv2D(128, (3, 3), activation='relu'),
        MaxPooling2D(2, 2),
        Conv2D(256, (3, 3), activation='relu'),
        MaxPooling2D(2, 2), 
        Flatten(),
        Dropout(0.5),
        Dense(512, activation='relu'),
        Dense(128, activation='relu'),
        Dense(2, activation='softmax'),
    ])

    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['acc'])

    checkpoint_path = "my_checkpoint.ckpt"
    checkpoint = ModelCheckpoint(filepath=checkpoint_path, 
                                save_weights_only=True, 
                                save_best_only=True, 
                                monitor='val_loss', 
                                verbose=1)
    model.fit(train_data,
                validation_data=(valid_data),
                epochs=20,
                callbacks=[checkpoint],
                )
    model.load_weights(checkpoint_path)

    return model


# Note that you'll need to save your model as a .h5 like this
# This .h5 will be uploaded to the testing infrastructure
# and a score will be returned to you
if __name__ == '__main__':
    model = solution_model()
    model.save("mymodel.h5")
# Out:
# Downloading and preparing dataset cats_vs_dogs/4.0.0 (download: 786.68 MiB, generated: Unknown size, total: 786.68 MiB) to /root/tensorflow_datasets/cats_vs_dogs/4.0.0...
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Dl Completed...', max=1.0, style=Progre…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Dl Size...', max=1.0, style=ProgressSty…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# WARNING:absl:1738 images were corrupted and were skipped
# Shuffling and writing examples to /root/tensorflow_datasets/cats_vs_dogs/4.0.0.incompleteDMX3BE/cats_vs_dogs-train.tfrecord
# HBox(children=(FloatProgress(value=0.0, max=23262.0), HTML(value='')))
# Dataset cats_vs_dogs downloaded and prepared to /root/tensorflow_datasets/cats_vs_dogs/4.0.0. Subsequent calls will reuse this data.
# Epoch 1/20
# 582/582 [==============================] - 58s 71ms/step - loss: 0.6835 - acc: 0.5472 - val_loss: 0.6597 - val_acc: 0.6230
#
# Epoch 00001: val_loss improved from inf to 0.65968, saving model to my_checkpoint.ckpt
# Epoch 2/20
# 582/582 [==============================] - 42s 72ms/step - loss: 0.6301 - acc: 0.6450 - val_loss: 0.5903 - val_acc: 0.6922
#
# Epoch 00002: val_loss improved from 0.65968 to 0.59027, saving model to my_checkpoint.ckpt
# Epoch 3/20
# 582/582 [==============================] - 42s 72ms/step - loss: 0.5578 - acc: 0.7164 - val_loss: 0.5297 - val_acc: 0.7330
#
# Epoch 00003: val_loss improved from 0.59027 to 0.52971, saving model to my_checkpoint.ckpt
# Epoch 4/20
# 582/582 [==============================] - 42s 72ms/step - loss: 0.4888 - acc: 0.7620 - val_loss: 0.4754 - val_acc: 0.7711
#
# Epoch 00004: val_loss improved from 0.52971 to 0.47543, saving model to my_checkpoint.ckpt
# Epoch 5/20
# 582/582 [==============================] - 41s 71ms/step - loss: 0.4208 - acc: 0.8068 - val_loss: 0.4918 - val_acc: 0.7693
#
# Epoch 00005: val_loss did not improve from 0.47543
# Epoch 6/20
# 582/582 [==============================] - 41s 71ms/step - loss: 0.3610 - acc: 0.8424 - val_loss: 0.4081 - val_acc: 0.8186
#
# Epoch 00006: val_loss improved from 0.47543 to 0.40811, saving model to my_checkpoint.ckpt
# Epoch 7/20
# 582/582 [==============================] - 41s 70ms/step - loss: 0.3145 - acc: 0.8628 - val_loss: 0.3564 - val_acc: 0.8399
#
# Epoch 00007: val_loss improved from 0.40811 to 0.35635, saving model to my_checkpoint.ckpt
# Epoch 8/20
# 582/582 [==============================] - 41s 71ms/step - loss: 0.2733 - acc: 0.8841 - val_loss: 0.3501 - val_acc: 0.8502
#
# Epoch 00008: val_loss improved from 0.35635 to 0.35005, saving model to my_checkpoint.ckpt
# Epoch 9/20
# 582/582 [==============================] - 41s 71ms/step - loss: 0.2409 - acc: 0.8988 - val_loss: 0.3658 - val_acc: 0.8362
#
# Epoch 00009: val_loss did not improve from 0.35005
# Epoch 10/20
# 582/582 [==============================] - 41s 71ms/step - loss: 0.2081 - acc: 0.9154 - val_loss: 0.3426 - val_acc: 0.8564
#
# Epoch 00010: val_loss improved from 0.35005 to 0.34259, saving model to my_checkpoint.ckpt
# Epoch 11/20
# 582/582 [==============================] - 42s 71ms/step - loss: 0.1906 - acc: 0.9208 - val_loss: 0.3186 - val_acc: 0.8755
#
# Epoch 00011: val_loss improved from 0.34259 to 0.31860, saving model to my_checkpoint.ckpt
# Epoch 12/20
# 582/582 [==============================] - 41s 71ms/step - loss: 0.1690 - acc: 0.9292 - val_loss: 0.4705 - val_acc: 0.8407
#
# Epoch 00012: val_loss did not improve from 0.31860
# Epoch 13/20
# 582/582 [==============================] - 41s 71ms/step - loss: 0.1482 - acc: 0.9390 - val_loss: 0.3329 - val_acc: 0.8828
#
# Epoch 00013: val_loss did not improve from 0.31860
# Epoch 14/20
# 582/582 [==============================] - 41s 71ms/step - loss: 0.1368 - acc: 0.9454 - val_loss: 0.4535 - val_acc: 0.8549
#
# Epoch 00014: val_loss did not improve from 0.31860
# Epoch 15/20
# 582/582 [==============================] - 41s 70ms/step - loss: 0.1141 - acc: 0.9543 - val_loss: 0.3639 - val_acc: 0.8884
#
# Epoch 00015: val_loss did not improve from 0.31860
# Epoch 16/20
# 582/582 [==============================] - 41s 71ms/step - loss: 0.1070 - acc: 0.9586 - val_loss: 0.4678 - val_acc: 0.8848
#
# Epoch 00016: val_loss did not improve from 0.31860
# Epoch 17/20
# 582/582 [==============================] - 41s 71ms/step - loss: 0.0947 - acc: 0.9623 - val_loss: 0.3470 - val_acc: 0.8912
#
# Epoch 00017: val_loss did not improve from 0.31860
# Epoch 18/20
# 582/582 [==============================] - 41s 71ms/step - loss: 0.0835 - acc: 0.9692 - val_loss: 0.5157 - val_acc: 0.8764
#
# Epoch 00018: val_loss did not improve from 0.31860
# Epoch 19/20
# 582/582 [==============================] - 41s 70ms/step - loss: 0.0839 - acc: 0.9682 - val_loss: 0.3745 - val_acc: 0.8854
#
# Epoch 00019: val_loss did not improve from 0.31860
# Epoch 20/20
# 582/582 [==============================] - 41s 71ms/step - loss: 0.0760 - acc: 0.9708 - val_loss: 0.3848 - val_acc: 0.8674
#
# Epoch 00020: val_loss did not improve from 0.31860

# %% [markdown]
# #TF3-cats-vs-dogs-2

# %%
# ======================================================================
# There are 5 questions in this test with increasing difficulty from 1-5
# Please note that the weight of the grade for the question is relative
# to its difficulty. So your Category 1 question will score much less
# than your Category 5 question.
# ======================================================================
#
# Computer Vision with CNNs
#
# For this exercise you will build a cats v dogs classifier
# using the Cats v Dogs dataset from TFDS.
# Be sure to use the final layer as shown 
#     (Dense, 2 neurons, softmax activation)
#
# The testing infrastructre will resize all images to 224x224 
# with 3 bytes of color depth. Make sure your input layer trains
# images to that specification, or the tests will fail.
#
# Make sure your output layer is exactly as specified here, or the 
# tests will fail.

# =========== 합격 기준 가이드라인 공유 ============= #
# val_loss 기준에 맞춰 주시는 것이 훨씬 더 중요 #
# val_loss 보다 조금 높아도 상관없음. (언저리까지 OK) #
# =================================================== #
# 문제명: Category 3 - cats vs dogs
# val_loss: 0.3158
# val_acc: 0.8665
# =================================================== #
# =================================================== #


import tensorflow_datasets as tfds
import tensorflow as tf

from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import ModelCheckpoint

dataset_name = 'cats_vs_dogs'
train_dataset = tfds.load(name=dataset_name, split='train[:80%]')
valid_dataset = tfds.load(name=dataset_name, split='train[80%:]')

def preprocess(data):
    # x, y 데이터를 정의합니다.
    x = data['image']
    y = data['label']
    # image 정규화(Normalization)
    x = tf.cast(x, tf.float32) / 255.0
    # 사이즈를 (224, 224)로 변환합니다.
    x = tf.image.resize(x, size=(224, 224))
    # x, y  데이터를 return 합니다.
    return x, y


def solution_model():
    batch_size=32
    train_data = train_dataset.map(preprocess).batch(batch_size)
    valid_data = valid_dataset.map(preprocess).batch(batch_size)

    model = Sequential([
        Conv2D(64, (3, 3), input_shape=(224, 224, 3), activation='relu'),
        MaxPooling2D(2, 2),
        Conv2D(64, (3, 3), activation='relu'),
        MaxPooling2D(2, 2),
        Conv2D(128, (3, 3), activation='relu'),
        MaxPooling2D(2, 2),
        Conv2D(128, (3, 3), activation='relu'),
        MaxPooling2D(2, 2),
        Conv2D(256, (3, 3), activation='relu'),
        MaxPooling2D(2, 2), 
        Flatten(),
        Dropout(0.5),
        Dense(512, activation='relu'),
        Dense(256, activation='relu'),
        Dense(128, activation='relu'),
        Dense(2, activation='softmax'),
    ])

    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['acc'])

    checkpoint_path = "my_checkpoint.ckpt"
    checkpoint = ModelCheckpoint(filepath=checkpoint_path, 
                                save_weights_only=True, 
                                save_best_only=True, 
                                monitor='val_loss', 
                                verbose=1)
    model.fit(train_data,
                validation_data=(valid_data),
                epochs=20,
                callbacks=[checkpoint],
                )
    model.load_weights(checkpoint_path)

    return model


# Note that you'll need to save your model as a .h5 like this
# This .h5 will be uploaded to the testing infrastructure
# and a score will be returned to you
if __name__ == '__main__':
    model = solution_model()
    model.save("mymodel.h5")
# Out:
# Epoch 1/20
# 582/582 [==============================] - 60s 69ms/step - loss: 0.6882 - acc: 0.5356 - val_loss: 0.6695 - val_acc: 0.6002
#
# Epoch 00001: val_loss improved from inf to 0.66946, saving model to my_checkpoint.ckpt
# Epoch 2/20
# 582/582 [==============================] - 40s 69ms/step - loss: 0.6576 - acc: 0.6098 - val_loss: 0.6503 - val_acc: 0.6217
#
# Epoch 00002: val_loss improved from 0.66946 to 0.65031, saving model to my_checkpoint.ckpt
# Epoch 3/20
# 582/582 [==============================] - 40s 69ms/step - loss: 0.6035 - acc: 0.6726 - val_loss: 0.5650 - val_acc: 0.7208
#
# Epoch 00003: val_loss improved from 0.65031 to 0.56503, saving model to my_checkpoint.ckpt
# Epoch 4/20
# 582/582 [==============================] - 40s 69ms/step - loss: 0.5325 - acc: 0.7361 - val_loss: 0.4915 - val_acc: 0.7674
#
# Epoch 00004: val_loss improved from 0.56503 to 0.49149, saving model to my_checkpoint.ckpt
# Epoch 5/20
# 582/582 [==============================] - 40s 69ms/step - loss: 0.4737 - acc: 0.7765 - val_loss: 0.4426 - val_acc: 0.8014
#
# Epoch 00005: val_loss improved from 0.49149 to 0.44260, saving model to my_checkpoint.ckpt
# Epoch 6/20
# 582/582 [==============================] - 40s 69ms/step - loss: 0.4153 - acc: 0.8121 - val_loss: 0.4047 - val_acc: 0.8194
#
# Epoch 00006: val_loss improved from 0.44260 to 0.40466, saving model to my_checkpoint.ckpt
# Epoch 7/20
# 582/582 [==============================] - 40s 69ms/step - loss: 0.3687 - acc: 0.8351 - val_loss: 0.3632 - val_acc: 0.8437
#
# Epoch 00007: val_loss improved from 0.40466 to 0.36318, saving model to my_checkpoint.ckpt
# Epoch 8/20
# 582/582 [==============================] - 40s 69ms/step - loss: 0.3213 - acc: 0.8592 - val_loss: 0.3787 - val_acc: 0.8362
#
# Epoch 00008: val_loss did not improve from 0.36318
# Epoch 9/20
# 582/582 [==============================] - 40s 69ms/step - loss: 0.2921 - acc: 0.8768 - val_loss: 0.3366 - val_acc: 0.8560
#
# Epoch 00009: val_loss improved from 0.36318 to 0.33662, saving model to my_checkpoint.ckpt
# Epoch 10/20
# 582/582 [==============================] - 40s 69ms/step - loss: 0.2561 - acc: 0.8918 - val_loss: 0.3547 - val_acc: 0.8517
#
# Epoch 00010: val_loss did not improve from 0.33662
# Epoch 11/20
# 582/582 [==============================] - 40s 69ms/step - loss: 0.2302 - acc: 0.9031 - val_loss: 0.3436 - val_acc: 0.8631
#
# Epoch 00011: val_loss did not improve from 0.33662
# Epoch 12/20
# 582/582 [==============================] - 41s 70ms/step - loss: 0.2047 - acc: 0.9148 - val_loss: 0.4222 - val_acc: 0.8472
#
# Epoch 00012: val_loss did not improve from 0.33662
# Epoch 13/20
# 582/582 [==============================] - 41s 70ms/step - loss: 0.1827 - acc: 0.9246 - val_loss: 0.2992 - val_acc: 0.8796
#
# Epoch 00013: val_loss improved from 0.33662 to 0.29918, saving model to my_checkpoint.ckpt
# Epoch 14/20
# 582/582 [==============================] - 41s 70ms/step - loss: 0.1582 - acc: 0.9348 - val_loss: 0.3518 - val_acc: 0.8762
#
# Epoch 00014: val_loss did not improve from 0.29918
# Epoch 15/20
# 582/582 [==============================] - 40s 69ms/step - loss: 0.1403 - acc: 0.9430 - val_loss: 0.3799 - val_acc: 0.8624
#
# Epoch 00015: val_loss did not improve from 0.29918
# Epoch 16/20
# 582/582 [==============================] - 40s 69ms/step - loss: 0.1236 - acc: 0.9512 - val_loss: 0.3630 - val_acc: 0.8601
#
# Epoch 00016: val_loss did not improve from 0.29918
# Epoch 17/20
# 582/582 [==============================] - 40s 69ms/step - loss: 0.1222 - acc: 0.9534 - val_loss: 0.3421 - val_acc: 0.8719
#
# Epoch 00017: val_loss did not improve from 0.29918
# Epoch 18/20
# 582/582 [==============================] - 40s 69ms/step - loss: 0.1123 - acc: 0.9571 - val_loss: 0.4015 - val_acc: 0.8659
#
# Epoch 00018: val_loss did not improve from 0.29918
# Epoch 19/20
# 582/582 [==============================] - 40s 69ms/step - loss: 0.1035 - acc: 0.9600 - val_loss: 0.4229 - val_acc: 0.8730
#
# Epoch 00019: val_loss did not improve from 0.29918
# Epoch 20/20
# 582/582 [==============================] - 41s 70ms/step - loss: 0.0907 - acc: 0.9653 - val_loss: 0.4379 - val_acc: 0.8742
#
# Epoch 00020: val_loss did not improve from 0.29918

# %% [markdown]
# #TF3-cats-vs-dogs-3

# %%
# ======================================================================
# There are 5 questions in this test with increasing difficulty from 1-5
# Please note that the weight of the grade for the question is relative
# to its difficulty. So your Category 1 question will score much less
# than your Category 5 question.
# ======================================================================
#
# Computer Vision with CNNs
#
# For this exercise you will build a cats v dogs classifier
# using the Cats v Dogs dataset from TFDS.
# Be sure to use the final layer as shown 
#     (Dense, 2 neurons, softmax activation)
#
# The testing infrastructre will resize all images to 224x224 
# with 3 bytes of color depth. Make sure your input layer trains
# images to that specification, or the tests will fail.
#
# Make sure your output layer is exactly as specified here, or the 
# tests will fail.

# =========== 합격 기준 가이드라인 공유 ============= #
# val_loss 기준에 맞춰 주시는 것이 훨씬 더 중요 #
# val_loss 보다 조금 높아도 상관없음. (언저리까지 OK) #
# =================================================== #
# 문제명: Category 3 - cats vs dogs
# val_loss: 0.3158
# val_acc: 0.8665
# =================================================== #
# =================================================== #


import tensorflow_datasets as tfds
import tensorflow as tf

from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import ModelCheckpoint

dataset_name = 'cats_vs_dogs'
train_dataset = tfds.load(name=dataset_name, split='train[:80%]')
valid_dataset = tfds.load(name=dataset_name, split='train[80%:]')

def preprocess(data):
    # x, y 데이터를 정의합니다.
    x = data['image']
    y = data['label']
    # image 정규화(Normalization)
    x = tf.cast(x, tf.float32) / 255.0
    # 사이즈를 (224, 224)로 변환합니다.
    x = tf.image.resize(x, size=(224, 224))
    # x, y  데이터를 return 합니다.
    return x, y


def solution_model():
    batch_size=32
    train_data = train_dataset.map(preprocess).batch(batch_size)
    valid_data = valid_dataset.map(preprocess).batch(batch_size)

    model = Sequential([
        Conv2D(16, (3, 3), input_shape=(224, 224, 3), activation='relu'),
        MaxPooling2D(2, 2),
        Conv2D(32, (3, 3), activation='relu'),
        MaxPooling2D(2, 2),
        Conv2D(64, (3, 3), activation='relu'),
        MaxPooling2D(2, 2),
        Conv2D(64, (3, 3), activation='relu'),
        MaxPooling2D(2, 2),
        Conv2D(64, (3, 3), activation='relu'),
        MaxPooling2D(2, 2), 
        Flatten(),
        Dropout(0.5),
        Dense(512, activation='relu'),
        Dense(256, activation='relu'),
        Dense(128, activation='relu'),
        Dense(2, activation='softmax'),
    ])

    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['acc'])

    checkpoint_path = "my_checkpoint.ckpt"
    checkpoint = ModelCheckpoint(filepath=checkpoint_path, 
                                save_weights_only=True, 
                                save_best_only=True, 
                                monitor='val_loss', 
                                verbose=1)
    model.fit(train_data,
                validation_data=(valid_data),
                epochs=20,
                callbacks=[checkpoint],
                )
    model.load_weights(checkpoint_path)

    return model


# Note that you'll need to save your model as a .h5 like this
# This .h5 will be uploaded to the testing infrastructure
# and a score will be returned to you
if __name__ == '__main__':
    model = solution_model()
    model.save("mymodel.h5")
# Out:
# Epoch 1/20
# 582/582 [==============================] - 39s 66ms/step - loss: 0.6904 - acc: 0.5243 - val_loss: 0.6625 - val_acc: 0.6012
#
# Epoch 00001: val_loss improved from inf to 0.66253, saving model to my_checkpoint.ckpt
# Epoch 2/20
# 582/582 [==============================] - 38s 66ms/step - loss: 0.6400 - acc: 0.6277 - val_loss: 0.6201 - val_acc: 0.6531
#
# Epoch 00002: val_loss improved from 0.66253 to 0.62005, saving model to my_checkpoint.ckpt
# Epoch 3/20
# 582/582 [==============================] - 39s 66ms/step - loss: 0.5497 - acc: 0.7197 - val_loss: 0.5541 - val_acc: 0.7094
#
# Epoch 00003: val_loss improved from 0.62005 to 0.55411, saving model to my_checkpoint.ckpt
# Epoch 4/20
# 582/582 [==============================] - 38s 66ms/step - loss: 0.4929 - acc: 0.7669 - val_loss: 0.4756 - val_acc: 0.7771
#
# Epoch 00004: val_loss improved from 0.55411 to 0.47561, saving model to my_checkpoint.ckpt
# Epoch 5/20
# 582/582 [==============================] - 39s 66ms/step - loss: 0.4353 - acc: 0.7977 - val_loss: 0.4485 - val_acc: 0.7767
#
# Epoch 00005: val_loss improved from 0.47561 to 0.44849, saving model to my_checkpoint.ckpt
# Epoch 6/20
# 582/582 [==============================] - 38s 65ms/step - loss: 0.3855 - acc: 0.8269 - val_loss: 0.4011 - val_acc: 0.8067
#
# Epoch 00006: val_loss improved from 0.44849 to 0.40110, saving model to my_checkpoint.ckpt
# Epoch 7/20
# 582/582 [==============================] - 39s 66ms/step - loss: 0.3414 - acc: 0.8504 - val_loss: 0.3578 - val_acc: 0.8508
#
# Epoch 00007: val_loss improved from 0.40110 to 0.35781, saving model to my_checkpoint.ckpt
# Epoch 8/20
# 582/582 [==============================] - 39s 67ms/step - loss: 0.3038 - acc: 0.8670 - val_loss: 0.3603 - val_acc: 0.8310
#
# Epoch 00008: val_loss did not improve from 0.35781
# Epoch 9/20
# 582/582 [==============================] - 38s 66ms/step - loss: 0.2693 - acc: 0.8858 - val_loss: 0.3095 - val_acc: 0.8644
#
# Epoch 00009: val_loss improved from 0.35781 to 0.30947, saving model to my_checkpoint.ckpt
# Epoch 10/20
# 582/582 [==============================] - 38s 65ms/step - loss: 0.2463 - acc: 0.8962 - val_loss: 0.3046 - val_acc: 0.8674
#
# Epoch 00010: val_loss improved from 0.30947 to 0.30461, saving model to my_checkpoint.ckpt
# Epoch 11/20
# 582/582 [==============================] - 38s 65ms/step - loss: 0.2207 - acc: 0.9060 - val_loss: 0.2583 - val_acc: 0.8893
#
# Epoch 00011: val_loss improved from 0.30461 to 0.25826, saving model to my_checkpoint.ckpt
# Epoch 12/20
# 582/582 [==============================] - 38s 66ms/step - loss: 0.2034 - acc: 0.9146 - val_loss: 0.2763 - val_acc: 0.8818
#
# Epoch 00012: val_loss did not improve from 0.25826
# Epoch 13/20
# 582/582 [==============================] - 39s 66ms/step - loss: 0.1930 - acc: 0.9191 - val_loss: 0.2394 - val_acc: 0.8947
#
# Epoch 00013: val_loss improved from 0.25826 to 0.23944, saving model to my_checkpoint.ckpt
# Epoch 14/20
# 582/582 [==============================] - 40s 68ms/step - loss: 0.1740 - acc: 0.9292 - val_loss: 0.2709 - val_acc: 0.8859
#
# Epoch 00014: val_loss did not improve from 0.23944
# Epoch 15/20
# 582/582 [==============================] - 38s 66ms/step - loss: 0.1561 - acc: 0.9355 - val_loss: 0.3053 - val_acc: 0.8876
#
# Epoch 00015: val_loss did not improve from 0.23944
# Epoch 16/20
# 582/582 [==============================] - 38s 66ms/step - loss: 0.1445 - acc: 0.9409 - val_loss: 0.3456 - val_acc: 0.8667
#
# Epoch 00016: val_loss did not improve from 0.23944
# Epoch 17/20
# 582/582 [==============================] - 38s 66ms/step - loss: 0.1345 - acc: 0.9452 - val_loss: 0.2873 - val_acc: 0.8897
#
# Epoch 00017: val_loss did not improve from 0.23944
# Epoch 18/20
# 582/582 [==============================] - 39s 66ms/step - loss: 0.1280 - acc: 0.9482 - val_loss: 0.2947 - val_acc: 0.8895
#
# Epoch 00018: val_loss did not improve from 0.23944
# Epoch 19/20
# 582/582 [==============================] - 39s 66ms/step - loss: 0.1128 - acc: 0.9547 - val_loss: 0.2722 - val_acc: 0.9009
#
# Epoch 00019: val_loss did not improve from 0.23944
# Epoch 20/20
# 582/582 [==============================] - 39s 66ms/step - loss: 0.1112 - acc: 0.9581 - val_loss: 0.2920 - val_acc: 0.8953
#
# Epoch 00020: val_loss did not improve from 0.23944

# %% [markdown]
# #TF3-cats-vs-dogs-4

# %%
# ======================================================================
# There are 5 questions in this test with increasing difficulty from 1-5
# Please note that the weight of the grade for the question is relative
# to its difficulty. So your Category 1 question will score much less
# than your Category 5 question.
# ======================================================================
#
# Computer Vision with CNNs
#
# For this exercise you will build a cats v dogs classifier
# using the Cats v Dogs dataset from TFDS.
# Be sure to use the final layer as shown 
#     (Dense, 2 neurons, softmax activation)
#
# The testing infrastructre will resize all images to 224x224 
# with 3 bytes of color depth. Make sure your input layer trains
# images to that specification, or the tests will fail.
#
# Make sure your output layer is exactly as specified here, or the 
# tests will fail.

# =========== 합격 기준 가이드라인 공유 ============= #
# val_loss 기준에 맞춰 주시는 것이 훨씬 더 중요 #
# val_loss 보다 조금 높아도 상관없음. (언저리까지 OK) #
# =================================================== #
# 문제명: Category 3 - cats vs dogs
# val_loss: 0.3158
# val_acc: 0.8665
# =================================================== #
# =================================================== #


import tensorflow_datasets as tfds
import tensorflow as tf

from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import ModelCheckpoint

dataset_name = 'cats_vs_dogs'
train_dataset = tfds.load(name=dataset_name, split='train[:80%]')
valid_dataset = tfds.load(name=dataset_name, split='train[80%:]')

def preprocess(data):
    # x, y 데이터를 정의합니다.
    x = data['image']
    y = data['label']
    # image 정규화(Normalization)
    x = tf.cast(x, tf.float32) / 255.0
    # 사이즈를 (224, 224)로 변환합니다.
    x = tf.image.resize(x, size=(224, 224))
    # x, y  데이터를 return 합니다.
    return x, y


def solution_model():
    batch_size=32
    train_data = train_dataset.map(preprocess).batch(batch_size)
    valid_data = valid_dataset.map(preprocess).batch(batch_size)

    model = Sequential([
        Conv2D(16, (3, 3), input_shape=(224, 224, 3), activation='relu'),
        MaxPooling2D(2, 2),
        Conv2D(32, (3, 3), activation='relu'),
        MaxPooling2D(2, 2),
        Conv2D(64, (3, 3), activation='relu'),
        MaxPooling2D(2, 2),
        Conv2D(64, (3, 3), activation='relu'),
        MaxPooling2D(2, 2),
        Conv2D(64, (3, 3), activation='relu'),
        MaxPooling2D(2, 2), 
        Conv2D(64, (3, 3), activation='relu'),
        MaxPooling2D(2, 2), 
        Flatten(),
        Dropout(0.5),
        Dense(512, activation='relu'),
        Dense(256, activation='relu'),
        Dense(128, activation='relu'),
        Dense(2, activation='softmax'),
    ])

    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['acc'])

    checkpoint_path = "my_checkpoint.ckpt"
    checkpoint = ModelCheckpoint(filepath=checkpoint_path, 
                                save_weights_only=True, 
                                save_best_only=True, 
                                monitor='val_loss', 
                                verbose=1)
    model.fit(train_data,
                validation_data=(valid_data),
                epochs=50,
                callbacks=[checkpoint],
                )
    model.load_weights(checkpoint_path)

    return model


# Note that you'll need to save your model as a .h5 like this
# This .h5 will be uploaded to the testing infrastructure
# and a score will be returned to you
if __name__ == '__main__':
    model = solution_model()
    model.save("mymodel.h5")
# Out:
# Epoch 1/50
# 582/582 [==============================] - 38s 65ms/step - loss: 0.6889 - acc: 0.5308 - val_loss: 0.6802 - val_acc: 0.6118
#
# Epoch 00001: val_loss improved from inf to 0.68018, saving model to my_checkpoint.ckpt
# Epoch 2/50
# 582/582 [==============================] - 39s 66ms/step - loss: 0.6745 - acc: 0.5714 - val_loss: 0.6192 - val_acc: 0.6758
#
# Epoch 00002: val_loss improved from 0.68018 to 0.61922, saving model to my_checkpoint.ckpt
# Epoch 3/50
# 582/582 [==============================] - 39s 66ms/step - loss: 0.6053 - acc: 0.6818 - val_loss: 0.5822 - val_acc: 0.6926
#
# Epoch 00003: val_loss improved from 0.61922 to 0.58219, saving model to my_checkpoint.ckpt
# Epoch 4/50
# 582/582 [==============================] - 39s 66ms/step - loss: 0.5298 - acc: 0.7439 - val_loss: 0.5514 - val_acc: 0.7124
#
# Epoch 00004: val_loss improved from 0.58219 to 0.55140, saving model to my_checkpoint.ckpt
# Epoch 5/50
# 582/582 [==============================] - 38s 65ms/step - loss: 0.4485 - acc: 0.7955 - val_loss: 0.4643 - val_acc: 0.7700
#
# Epoch 00005: val_loss improved from 0.55140 to 0.46427, saving model to my_checkpoint.ckpt
# Epoch 6/50
# 582/582 [==============================] - 38s 65ms/step - loss: 0.3931 - acc: 0.8241 - val_loss: 0.3922 - val_acc: 0.8222
#
# Epoch 00006: val_loss improved from 0.46427 to 0.39224, saving model to my_checkpoint.ckpt
# Epoch 7/50
# 582/582 [==============================] - 38s 66ms/step - loss: 0.3440 - acc: 0.8483 - val_loss: 0.3947 - val_acc: 0.8169
#
# Epoch 00007: val_loss did not improve from 0.39224
# Epoch 8/50
# 582/582 [==============================] - 39s 67ms/step - loss: 0.3103 - acc: 0.8673 - val_loss: 0.3522 - val_acc: 0.8383
#
# Epoch 00008: val_loss improved from 0.39224 to 0.35215, saving model to my_checkpoint.ckpt
# Epoch 9/50
# 582/582 [==============================] - 39s 67ms/step - loss: 0.2803 - acc: 0.8819 - val_loss: 0.3536 - val_acc: 0.8433
#
# Epoch 00009: val_loss did not improve from 0.35215
# Epoch 10/50
# 582/582 [==============================] - 39s 67ms/step - loss: 0.2562 - acc: 0.8919 - val_loss: 0.3213 - val_acc: 0.8633
#
# Epoch 00010: val_loss improved from 0.35215 to 0.32126, saving model to my_checkpoint.ckpt
# Epoch 11/50
# 582/582 [==============================] - 38s 66ms/step - loss: 0.2268 - acc: 0.9059 - val_loss: 0.3146 - val_acc: 0.8678
#
# Epoch 00011: val_loss improved from 0.32126 to 0.31457, saving model to my_checkpoint.ckpt
# Epoch 12/50
# 582/582 [==============================] - 39s 66ms/step - loss: 0.2044 - acc: 0.9140 - val_loss: 0.3113 - val_acc: 0.8644
#
# Epoch 00012: val_loss improved from 0.31457 to 0.31133, saving model to my_checkpoint.ckpt
# Epoch 13/50
# 582/582 [==============================] - 39s 66ms/step - loss: 0.1900 - acc: 0.9221 - val_loss: 0.2947 - val_acc: 0.8758
#
# Epoch 00013: val_loss improved from 0.31133 to 0.29473, saving model to my_checkpoint.ckpt
# Epoch 14/50
# 582/582 [==============================] - 39s 67ms/step - loss: 0.1691 - acc: 0.9316 - val_loss: 0.2873 - val_acc: 0.8773
#
# Epoch 00014: val_loss improved from 0.29473 to 0.28726, saving model to my_checkpoint.ckpt
# Epoch 15/50
# 582/582 [==============================] - 38s 66ms/step - loss: 0.1557 - acc: 0.9370 - val_loss: 0.2978 - val_acc: 0.8738
#
# Epoch 00015: val_loss did not improve from 0.28726
# Epoch 16/50
# 582/582 [==============================] - 39s 67ms/step - loss: 0.1389 - acc: 0.9442 - val_loss: 0.2890 - val_acc: 0.8796
#
# Epoch 00016: val_loss did not improve from 0.28726
# Epoch 17/50
# 582/582 [==============================] - 39s 67ms/step - loss: 0.1290 - acc: 0.9473 - val_loss: 0.3106 - val_acc: 0.8820
#
# Epoch 00017: val_loss did not improve from 0.28726
# Epoch 18/50
# 582/582 [==============================] - 39s 67ms/step - loss: 0.1233 - acc: 0.9510 - val_loss: 0.3358 - val_acc: 0.8663
#
# Epoch 00018: val_loss did not improve from 0.28726
# Epoch 19/50
# 582/582 [==============================] - 39s 66ms/step - loss: 0.1182 - acc: 0.9534 - val_loss: 0.4319 - val_acc: 0.8551
#
# Epoch 00019: val_loss did not improve from 0.28726
# Epoch 20/50
# 582/582 [==============================] - 39s 67ms/step - loss: 0.1018 - acc: 0.9603 - val_loss: 0.3800 - val_acc: 0.8691
#
# Epoch 00020: val_loss did not improve from 0.28726
# Epoch 21/50
# 582/582 [==============================] - 39s 67ms/step - loss: 0.0990 - acc: 0.9621 - val_loss: 0.3983 - val_acc: 0.8717
#
# Epoch 00021: val_loss did not improve from 0.28726
# Epoch 22/50
# 582/582 [==============================] - 40s 68ms/step - loss: 0.0875 - acc: 0.9649 - val_loss: 0.3927 - val_acc: 0.8833
#
# Epoch 00022: val_loss did not improve from 0.28726
# Epoch 23/50
# 582/582 [==============================] - 40s 68ms/step - loss: 0.0955 - acc: 0.9630 - val_loss: 0.4012 - val_acc: 0.8826
#
# Epoch 00023: val_loss did not improve from 0.28726
# Epoch 24/50
# 582/582 [==============================] - 39s 67ms/step - loss: 0.0846 - acc: 0.9658 - val_loss: 0.3732 - val_acc: 0.8929
#
# Epoch 00024: val_loss did not improve from 0.28726
# Epoch 25/50
# 582/582 [==============================] - 39s 67ms/step - loss: 0.0817 - acc: 0.9674 - val_loss: 0.4041 - val_acc: 0.8820
#
# Epoch 00025: val_loss did not improve from 0.28726
# Epoch 26/50
# 582/582 [==============================] - 39s 68ms/step - loss: 0.0759 - acc: 0.9719 - val_loss: 0.3802 - val_acc: 0.8760
#
# Epoch 00026: val_loss did not improve from 0.28726
# Epoch 27/50
# 582/582 [==============================] - 39s 68ms/step - loss: 0.0738 - acc: 0.9718 - val_loss: 0.3840 - val_acc: 0.8889
#
# Epoch 00027: val_loss did not improve from 0.28726
# Epoch 28/50
# 582/582 [==============================] - 39s 68ms/step - loss: 0.0730 - acc: 0.9722 - val_loss: 0.3519 - val_acc: 0.8906
#
# Epoch 00028: val_loss did not improve from 0.28726
# Epoch 29/50
# 582/582 [==============================] - 39s 66ms/step - loss: 0.0700 - acc: 0.9735 - val_loss: 0.3816 - val_acc: 0.8914
#
# Epoch 00029: val_loss did not improve from 0.28726
# Epoch 30/50
# 582/582 [==============================] - 39s 68ms/step - loss: 0.0631 - acc: 0.9765 - val_loss: 0.3796 - val_acc: 0.8889
#
# Epoch 00030: val_loss did not improve from 0.28726
# Epoch 31/50
# 582/582 [==============================] - 39s 66ms/step - loss: 0.0594 - acc: 0.9765 - val_loss: 0.6401 - val_acc: 0.8603
#
# Epoch 00031: val_loss did not improve from 0.28726
# Epoch 32/50
# 582/582 [==============================] - 40s 69ms/step - loss: 0.0621 - acc: 0.9772 - val_loss: 0.4305 - val_acc: 0.8854
#
# Epoch 00032: val_loss did not improve from 0.28726
# Epoch 33/50
# 582/582 [==============================] - 39s 68ms/step - loss: 0.0464 - acc: 0.9823 - val_loss: 0.4871 - val_acc: 0.8689
#
# Epoch 00033: val_loss did not improve from 0.28726
# Epoch 34/50
# 582/582 [==============================] - 39s 68ms/step - loss: 0.0563 - acc: 0.9805 - val_loss: 0.4240 - val_acc: 0.8820
#
# Epoch 00034: val_loss did not improve from 0.28726
# Epoch 35/50
# 582/582 [==============================] - 38s 66ms/step - loss: 0.0506 - acc: 0.9812 - val_loss: 0.5495 - val_acc: 0.8521
#
# Epoch 00035: val_loss did not improve from 0.28726
# Epoch 36/50
# 582/582 [==============================] - 40s 68ms/step - loss: 0.0515 - acc: 0.9814 - val_loss: 0.4619 - val_acc: 0.8904
#
# Epoch 00036: val_loss did not improve from 0.28726
# Epoch 37/50
# 582/582 [==============================] - 40s 68ms/step - loss: 0.0476 - acc: 0.9841 - val_loss: 0.4055 - val_acc: 0.8887
#
# Epoch 00037: val_loss did not improve from 0.28726
# Epoch 38/50
# 582/582 [==============================] - 39s 68ms/step - loss: 0.0559 - acc: 0.9803 - val_loss: 0.4519 - val_acc: 0.8889
#
# Epoch 00038: val_loss did not improve from 0.28726
# Epoch 39/50
# 582/582 [==============================] - 38s 65ms/step - loss: 0.0432 - acc: 0.9843 - val_loss: 0.3898 - val_acc: 0.8927
#
# Epoch 00039: val_loss did not improve from 0.28726
# Epoch 40/50
# 582/582 [==============================] - 38s 65ms/step - loss: 0.0387 - acc: 0.9865 - val_loss: 0.4382 - val_acc: 0.8893
#
# Epoch 00040: val_loss did not improve from 0.28726
# Epoch 41/50
# 582/582 [==============================] - 38s 66ms/step - loss: 0.0478 - acc: 0.9832 - val_loss: 0.3933 - val_acc: 0.8882
#
# Epoch 00041: val_loss did not improve from 0.28726
# Epoch 42/50
# 582/582 [==============================] - 38s 65ms/step - loss: 0.0437 - acc: 0.9847 - val_loss: 0.3795 - val_acc: 0.8981
#
# Epoch 00042: val_loss did not improve from 0.28726
# Epoch 43/50
# 582/582 [==============================] - 38s 65ms/step - loss: 0.0437 - acc: 0.9850 - val_loss: 0.4096 - val_acc: 0.8904
#
# Epoch 00043: val_loss did not improve from 0.28726
# Epoch 44/50
# 582/582 [==============================] - 38s 66ms/step - loss: 0.0392 - acc: 0.9862 - val_loss: 0.5018 - val_acc: 0.8878
#
# Epoch 00044: val_loss did not improve from 0.28726
# Epoch 45/50
# 582/582 [==============================] - 38s 66ms/step - loss: 0.0434 - acc: 0.9848 - val_loss: 0.5243 - val_acc: 0.8934
#
# Epoch 00045: val_loss did not improve from 0.28726
# Epoch 46/50
# 582/582 [==============================] - 38s 65ms/step - loss: 0.0410 - acc: 0.9860 - val_loss: 0.5138 - val_acc: 0.9031
#
# Epoch 00046: val_loss did not improve from 0.28726
# Epoch 47/50
# 582/582 [==============================] - 38s 65ms/step - loss: 0.0309 - acc: 0.9883 - val_loss: 0.8194 - val_acc: 0.8874
#
# Epoch 00047: val_loss did not improve from 0.28726
# Epoch 48/50
# 582/582 [==============================] - 38s 66ms/step - loss: 0.0553 - acc: 0.9812 - val_loss: 0.3518 - val_acc: 0.8852
#
# Epoch 00048: val_loss did not improve from 0.28726
# Epoch 49/50
# 582/582 [==============================] - 38s 65ms/step - loss: 0.0382 - acc: 0.9860 - val_loss: 0.5027 - val_acc: 0.8889
#
# Epoch 00049: val_loss did not improve from 0.28726
# Epoch 50/50
# 582/582 [==============================] - 38s 66ms/step - loss: 0.0369 - acc: 0.9879 - val_loss: 0.4043 - val_acc: 0.8990
#
# Epoch 00050: val_loss did not improve from 0.28726

# %% [markdown]
# #TF3-cats-vs-dogs-5

# %%
# ======================================================================
# There are 5 questions in this test with increasing difficulty from 1-5
# Please note that the weight of the grade for the question is relative
# to its difficulty. So your Category 1 question will score much less
# than your Category 5 question.
# ======================================================================
#
# Computer Vision with CNNs
#
# For this exercise you will build a cats v dogs classifier
# using the Cats v Dogs dataset from TFDS.
# Be sure to use the final layer as shown 
#     (Dense, 2 neurons, softmax activation)
#
# The testing infrastructre will resize all images to 224x224 
# with 3 bytes of color depth. Make sure your input layer trains
# images to that specification, or the tests will fail.
#
# Make sure your output layer is exactly as specified here, or the 
# tests will fail.

# =========== 합격 기준 가이드라인 공유 ============= #
# val_loss 기준에 맞춰 주시는 것이 훨씬 더 중요 #
# val_loss 보다 조금 높아도 상관없음. (언저리까지 OK) #
# =================================================== #
# 문제명: Category 3 - cats vs dogs
# val_loss: 0.3158
# val_acc: 0.8665
# =================================================== #
# =================================================== #


import tensorflow_datasets as tfds
import tensorflow as tf

from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import ModelCheckpoint

dataset_name = 'cats_vs_dogs'
train_dataset = tfds.load(name=dataset_name, split='train[:80%]')
valid_dataset = tfds.load(name=dataset_name, split='train[80%:]')

def preprocess(data):
    # x, y 데이터를 정의합니다.
    x = data['image']
    y = data['label']
    # image 정규화(Normalization)
    x = tf.cast(x, tf.float32) / 255.0
    # 사이즈를 (224, 224)로 변환합니다.
    x = tf.image.resize(x, size=(224, 224))
    # x, y  데이터를 return 합니다.
    return x, y


def solution_model():
    batch_size=32
    train_data = train_dataset.map(preprocess).batch(batch_size)
    valid_data = valid_dataset.map(preprocess).batch(batch_size)

    model = Sequential([
        Conv2D(16, (3, 3), input_shape=(224, 224, 3), activation='relu'),
        MaxPooling2D(2, 2),
        Conv2D(32, (3, 3), activation='relu'),
        MaxPooling2D(2, 2),
        Conv2D(64, (3, 3), activation='relu'),
        MaxPooling2D(2, 2),
        Conv2D(64, (3, 3), activation='relu'),
        MaxPooling2D(2, 2),
        Conv2D(64, (3, 3), activation='relu'),
        MaxPooling2D(2, 2), 
        Conv2D(64, (3, 3), activation='relu'),
        MaxPooling2D(2, 2), 
        Flatten(),
        Dropout(0.5),
        Dense(256, activation='relu'),
        Dense(128, activation='relu'),
        Dense(64, activation='relu'),
        Dense(2, activation='softmax'),
    ])

    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['acc'])

    checkpoint_path = "my_checkpoint.ckpt"
    checkpoint = ModelCheckpoint(filepath=checkpoint_path, 
                                save_weights_only=True, 
                                save_best_only=True, 
                                monitor='val_loss', 
                                verbose=1)
    model.fit(train_data,
                validation_data=(valid_data),
                epochs=30,
                callbacks=[checkpoint],
                )
    model.load_weights(checkpoint_path)

    return model


# Note that you'll need to save your model as a .h5 like this
# This .h5 will be uploaded to the testing infrastructure
# and a score will be returned to you
if __name__ == '__main__':
    model = solution_model()
    model.save("mymodel.h5")
# Out:
# Epoch 1/30
# 582/582 [==============================] - 41s 67ms/step - loss: 0.6407 - acc: 0.6249 - val_loss: 0.6002 - val_acc: 0.6672
#
# Epoch 00001: val_loss improved from inf to 0.60018, saving model to my_checkpoint.ckpt
# Epoch 2/30
# 582/582 [==============================] - 39s 67ms/step - loss: 0.5399 - acc: 0.7329 - val_loss: 0.4736 - val_acc: 0.7941
#
# Epoch 00002: val_loss improved from 0.60018 to 0.47357, saving model to my_checkpoint.ckpt
# Epoch 3/30
# 582/582 [==============================] - 39s 66ms/step - loss: 0.4437 - acc: 0.7964 - val_loss: 0.3990 - val_acc: 0.8295
#
# Epoch 00003: val_loss improved from 0.47357 to 0.39896, saving model to my_checkpoint.ckpt
# Epoch 4/30
# 582/582 [==============================] - 39s 66ms/step - loss: 0.3737 - acc: 0.8332 - val_loss: 0.3838 - val_acc: 0.8293
#
# Epoch 00004: val_loss improved from 0.39896 to 0.38380, saving model to my_checkpoint.ckpt
# Epoch 5/30
# 582/582 [==============================] - 39s 66ms/step - loss: 0.3133 - acc: 0.8660 - val_loss: 0.3147 - val_acc: 0.8641
#
# Epoch 00005: val_loss improved from 0.38380 to 0.31467, saving model to my_checkpoint.ckpt
# Epoch 6/30
# 582/582 [==============================] - 39s 66ms/step - loss: 0.2677 - acc: 0.8870 - val_loss: 0.2902 - val_acc: 0.8762
#
# Epoch 00006: val_loss improved from 0.31467 to 0.29022, saving model to my_checkpoint.ckpt
# Epoch 7/30
# 582/582 [==============================] - 39s 66ms/step - loss: 0.2318 - acc: 0.9023 - val_loss: 0.2824 - val_acc: 0.8785
#
# Epoch 00007: val_loss improved from 0.29022 to 0.28237, saving model to my_checkpoint.ckpt
# Epoch 8/30
# 582/582 [==============================] - 39s 66ms/step - loss: 0.2074 - acc: 0.9132 - val_loss: 0.2614 - val_acc: 0.8876
#
# Epoch 00008: val_loss improved from 0.28237 to 0.26136, saving model to my_checkpoint.ckpt
# Epoch 9/30
# 582/582 [==============================] - 39s 66ms/step - loss: 0.1884 - acc: 0.9203 - val_loss: 0.2607 - val_acc: 0.8893
#
# Epoch 00009: val_loss improved from 0.26136 to 0.26071, saving model to my_checkpoint.ckpt
# Epoch 10/30
# 582/582 [==============================] - 39s 67ms/step - loss: 0.1685 - acc: 0.9314 - val_loss: 0.3029 - val_acc: 0.8809
#
# Epoch 00010: val_loss did not improve from 0.26071
# Epoch 11/30
# 582/582 [==============================] - 39s 68ms/step - loss: 0.1499 - acc: 0.9380 - val_loss: 0.3179 - val_acc: 0.8846
#
# Epoch 00011: val_loss did not improve from 0.26071
# Epoch 12/30
# 582/582 [==============================] - 40s 68ms/step - loss: 0.1385 - acc: 0.9433 - val_loss: 0.2909 - val_acc: 0.8902
#
# Epoch 00012: val_loss did not improve from 0.26071
# Epoch 13/30
# 582/582 [==============================] - 39s 67ms/step - loss: 0.1331 - acc: 0.9474 - val_loss: 0.2645 - val_acc: 0.8880
#
# Epoch 00013: val_loss did not improve from 0.26071
# Epoch 14/30
# 582/582 [==============================] - 39s 68ms/step - loss: 0.1165 - acc: 0.9534 - val_loss: 0.2815 - val_acc: 0.8908
#
# Epoch 00014: val_loss did not improve from 0.26071
# Epoch 15/30
# 582/582 [==============================] - 39s 67ms/step - loss: 0.1066 - acc: 0.9559 - val_loss: 0.3034 - val_acc: 0.8936
#
# Epoch 00015: val_loss did not improve from 0.26071
# Epoch 16/30
# 582/582 [==============================] - 40s 69ms/step - loss: 0.1068 - acc: 0.9589 - val_loss: 0.2772 - val_acc: 0.8947
#
# Epoch 00016: val_loss did not improve from 0.26071
# Epoch 17/30
# 582/582 [==============================] - 40s 68ms/step - loss: 0.0924 - acc: 0.9618 - val_loss: 0.2564 - val_acc: 0.8932
#
# Epoch 00017: val_loss improved from 0.26071 to 0.25645, saving model to my_checkpoint.ckpt
# Epoch 18/30
# 582/582 [==============================] - 40s 68ms/step - loss: 0.0855 - acc: 0.9657 - val_loss: 0.3171 - val_acc: 0.8917
#
# Epoch 00018: val_loss did not improve from 0.25645
# Epoch 19/30
# 582/582 [==============================] - 40s 68ms/step - loss: 0.0778 - acc: 0.9696 - val_loss: 0.2947 - val_acc: 0.8996
#
# Epoch 00019: val_loss did not improve from 0.25645
# Epoch 20/30
# 582/582 [==============================] - 40s 69ms/step - loss: 0.0694 - acc: 0.9740 - val_loss: 0.2911 - val_acc: 0.8983
#
# Epoch 00020: val_loss did not improve from 0.25645
# Epoch 21/30
# 582/582 [==============================] - 40s 68ms/step - loss: 0.0806 - acc: 0.9687 - val_loss: 0.2994 - val_acc: 0.8876
#
# Epoch 00021: val_loss did not improve from 0.25645
# Epoch 22/30
# 582/582 [==============================] - 40s 69ms/step - loss: 0.0715 - acc: 0.9731 - val_loss: 0.3150 - val_acc: 0.8988
#
# Epoch 00022: val_loss did not improve from 0.25645
# Epoch 23/30
# 582/582 [==============================] - 40s 69ms/step - loss: 0.0683 - acc: 0.9738 - val_loss: 0.3192 - val_acc: 0.9084
#
# Epoch 00023: val_loss did not improve from 0.25645
# Epoch 24/30
# 582/582 [==============================] - 40s 69ms/step - loss: 0.0638 - acc: 0.9747 - val_loss: 0.3476 - val_acc: 0.8994
#
# Epoch 00024: val_loss did not improve from 0.25645
# Epoch 25/30
# 582/582 [==============================] - 40s 69ms/step - loss: 0.0629 - acc: 0.9766 - val_loss: 0.3291 - val_acc: 0.9039
#
# Epoch 00025: val_loss did not improve from 0.25645
# Epoch 26/30
# 582/582 [==============================] - 40s 68ms/step - loss: 0.0588 - acc: 0.9781 - val_loss: 0.3028 - val_acc: 0.8972
#
# Epoch 00026: val_loss did not improve from 0.25645
# Epoch 27/30
# 582/582 [==============================] - 40s 68ms/step - loss: 0.0522 - acc: 0.9808 - val_loss: 0.3564 - val_acc: 0.9041
#
# Epoch 00027: val_loss did not improve from 0.25645
# Epoch 28/30
# 582/582 [==============================] - 40s 69ms/step - loss: 0.0539 - acc: 0.9807 - val_loss: 0.3021 - val_acc: 0.8869
#
# Epoch 00028: val_loss did not improve from 0.25645
# Epoch 29/30
# 582/582 [==============================] - 40s 68ms/step - loss: 0.0564 - acc: 0.9790 - val_loss: 0.3438 - val_acc: 0.9067
#
# Epoch 00029: val_loss did not improve from 0.25645
# Epoch 30/30
# 582/582 [==============================] - 39s 68ms/step - loss: 0.0461 - acc: 0.9827 - val_loss: 0.3303 - val_acc: 0.8996
#
# Epoch 00030: val_loss did not improve from 0.25645
