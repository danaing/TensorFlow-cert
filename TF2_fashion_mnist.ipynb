# %% [markdown]
# <a href="https://colab.research.google.com/github/danaing/TensorFlow-cert/blob/main/TF2_fashion_mnist.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #TF2-fashion-mnist-1

# %%
# ======================================================================
# There are 5 questions in this test with increasing difficulty from 1-5
# Please note that the weight of the grade for the question is relative
# to its difficulty. So your Category 1 question will score much less
# than your Category 5 question.
# ======================================================================
#
# Basic Datasets Question
#
# Create a classifier for the Fashion MNIST dataset
# Note that the test will expect it to classify 10 classes and that the 
# input shape should be the native size of the Fashion MNIST dataset which is 
# 28x28 monochrome. Do not resize the data. YOur input layer should accept
# (28,28) as the input shape only. If you amend this, the tests will fail.
#

# =========== 합격 기준 가이드라인 공유 ============= #
# val_loss 기준에 맞춰 주시는 것이 훨씬 더 중요 #
# val_loss 보다 조금 높아도 상관없음. (언저리까지 OK) #
# =================================================== #
# 문제명: Category 2 - fashion mnist
# val_loss: 0.33
# val_acc: 0.89
# =================================================== #
# =================================================== #



import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import ModelCheckpoint


def solution_model():
    fashion_mnist = tf.keras.datasets.fashion_mnist
    (x_train, y_train), (x_valid, y_valid) = fashion_mnist.load_data()
    x_train = x_train / 255.0
    x_valid = x_valid / 255.0

    model = Sequential([
        # Flatten으로 shape 펼치기
        Flatten(input_shape=(28, 28)),
        # Dense Layer
        Dense(1024, activation='relu'),
        Dense(512, activation='relu'),
        Dense(256, activation='relu'),
        Dense(128, activation='relu'),
        Dense(64, activation='relu'),
        # Classification을 위한 Softmax 
        Dense(10, activation='softmax'),
    ])
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['acc'])
    checkpoint_path = "my_checkpoint.ckpt"
    checkpoint = ModelCheckpoint(filepath=checkpoint_path, 
                                save_weights_only=True, 
                                save_best_only=True, 
                                monitor='val_loss', 
                                verbose=1)
    
    history = model.fit(x_train, y_train,
                        validation_data=(x_valid, y_valid),
                        epochs=30,
                        callbacks=[checkpoint],
                      )
    model.load_weights(checkpoint_path)

    return model


# Note that you'll need to save your model as a .h5 like this
# This .h5 will be uploaded to the testing infrastructure
# and a score will be returned to you
if __name__ == '__main__':
    model = solution_model()
    model.save("mymodel.h5")
# Out:
# Epoch 1/30
# 1875/1875 [==============================] - 6s 2ms/step - loss: 0.5052 - acc: 0.8164 - val_loss: 0.4133 - val_acc: 0.8550
#
# Epoch 00001: val_loss improved from inf to 0.41327, saving model to my_checkpoint.ckpt
# Epoch 2/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3806 - acc: 0.8618 - val_loss: 0.4839 - val_acc: 0.8298
#
# Epoch 00002: val_loss did not improve from 0.41327
# Epoch 3/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3402 - acc: 0.8760 - val_loss: 0.4292 - val_acc: 0.8513
#
# Epoch 00003: val_loss did not improve from 0.41327
# Epoch 4/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3153 - acc: 0.8849 - val_loss: 0.3483 - val_acc: 0.8740
#
# Epoch 00004: val_loss improved from 0.41327 to 0.34827, saving model to my_checkpoint.ckpt
# Epoch 5/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2957 - acc: 0.8919 - val_loss: 0.3423 - val_acc: 0.8799
#
# Epoch 00005: val_loss improved from 0.34827 to 0.34235, saving model to my_checkpoint.ckpt
# Epoch 6/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2807 - acc: 0.8970 - val_loss: 0.3416 - val_acc: 0.8783
#
# Epoch 00006: val_loss improved from 0.34235 to 0.34156, saving model to my_checkpoint.ckpt
# Epoch 7/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2670 - acc: 0.9013 - val_loss: 0.3555 - val_acc: 0.8793
#
# Epoch 00007: val_loss did not improve from 0.34156
# Epoch 8/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2555 - acc: 0.9049 - val_loss: 0.3449 - val_acc: 0.8802
#
# Epoch 00008: val_loss did not improve from 0.34156
# Epoch 9/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2485 - acc: 0.9059 - val_loss: 0.3213 - val_acc: 0.8869
#
# Epoch 00009: val_loss improved from 0.34156 to 0.32126, saving model to my_checkpoint.ckpt
# Epoch 10/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2370 - acc: 0.9102 - val_loss: 0.3489 - val_acc: 0.8862
#
# Epoch 00010: val_loss did not improve from 0.32126
# Epoch 11/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2277 - acc: 0.9146 - val_loss: 0.3993 - val_acc: 0.8728
#
# Epoch 00011: val_loss did not improve from 0.32126
# Epoch 12/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2225 - acc: 0.9173 - val_loss: 0.3296 - val_acc: 0.8874
#
# Epoch 00012: val_loss did not improve from 0.32126
# Epoch 13/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2172 - acc: 0.9177 - val_loss: 0.3633 - val_acc: 0.8883
#
# Epoch 00013: val_loss did not improve from 0.32126
# Epoch 14/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2071 - acc: 0.9226 - val_loss: 0.3568 - val_acc: 0.8871
#
# Epoch 00014: val_loss did not improve from 0.32126
# Epoch 15/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2064 - acc: 0.9224 - val_loss: 0.3822 - val_acc: 0.8764
#
# Epoch 00015: val_loss did not improve from 0.32126
# Epoch 16/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1928 - acc: 0.9261 - val_loss: 0.3575 - val_acc: 0.8869
#
# Epoch 00016: val_loss did not improve from 0.32126
# Epoch 17/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1920 - acc: 0.9276 - val_loss: 0.3747 - val_acc: 0.8877
#
# Epoch 00017: val_loss did not improve from 0.32126
# Epoch 18/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1885 - acc: 0.9291 - val_loss: 0.3629 - val_acc: 0.8921
#
# Epoch 00018: val_loss did not improve from 0.32126
# Epoch 19/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1793 - acc: 0.9319 - val_loss: 0.4148 - val_acc: 0.8909
#
# Epoch 00019: val_loss did not improve from 0.32126
# Epoch 20/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1797 - acc: 0.9326 - val_loss: 0.3661 - val_acc: 0.8899
#
# Epoch 00020: val_loss did not improve from 0.32126
# Epoch 21/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1740 - acc: 0.9351 - val_loss: 0.3691 - val_acc: 0.8934
#
# Epoch 00021: val_loss did not improve from 0.32126
# Epoch 22/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1701 - acc: 0.9364 - val_loss: 0.3877 - val_acc: 0.8937
#
# Epoch 00022: val_loss did not improve from 0.32126
# Epoch 23/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1678 - acc: 0.9369 - val_loss: 0.3843 - val_acc: 0.8921
#
# Epoch 00023: val_loss did not improve from 0.32126
# Epoch 24/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1575 - acc: 0.9401 - val_loss: 0.4030 - val_acc: 0.8964
#
# Epoch 00024: val_loss did not improve from 0.32126
# Epoch 25/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1609 - acc: 0.9403 - val_loss: 0.3878 - val_acc: 0.8997
#
# Epoch 00025: val_loss did not improve from 0.32126
# Epoch 26/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1502 - acc: 0.9436 - val_loss: 0.3991 - val_acc: 0.8980
#
# Epoch 00026: val_loss did not improve from 0.32126
# Epoch 27/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1443 - acc: 0.9443 - val_loss: 0.4581 - val_acc: 0.8921
#
# Epoch 00027: val_loss did not improve from 0.32126
# Epoch 28/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1461 - acc: 0.9459 - val_loss: 0.4191 - val_acc: 0.8943
#
# Epoch 00028: val_loss did not improve from 0.32126
# Epoch 29/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1460 - acc: 0.9454 - val_loss: 0.4951 - val_acc: 0.8857
#
# Epoch 00029: val_loss did not improve from 0.32126
# Epoch 30/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1460 - acc: 0.9454 - val_loss: 0.4615 - val_acc: 0.8805
#
# Epoch 00030: val_loss did not improve from 0.32126

# %% [markdown]
# #TF2-fashion-mnist-2

# %%
# ======================================================================
# There are 5 questions in this test with increasing difficulty from 1-5
# Please note that the weight of the grade for the question is relative
# to its difficulty. So your Category 1 question will score much less
# than your Category 5 question.
# ======================================================================
#
# Basic Datasets Question
#
# Create a classifier for the Fashion MNIST dataset
# Note that the test will expect it to classify 10 classes and that the 
# input shape should be the native size of the Fashion MNIST dataset which is 
# 28x28 monochrome. Do not resize the data. YOur input layer should accept
# (28,28) as the input shape only. If you amend this, the tests will fail.
#

# =========== 합격 기준 가이드라인 공유 ============= #
# val_loss 기준에 맞춰 주시는 것이 훨씬 더 중요 #
# val_loss 보다 조금 높아도 상관없음. (언저리까지 OK) #
# =================================================== #
# 문제명: Category 2 - fashion mnist
# val_loss: 0.33
# val_acc: 0.89
# =================================================== #
# =================================================== #



import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import ModelCheckpoint


def solution_model():
    fashion_mnist = tf.keras.datasets.fashion_mnist
    (x_train, y_train), (x_valid, y_valid) = fashion_mnist.load_data()
    x_train = x_train / 255.0
    x_valid = x_valid / 255.0

    model = Sequential([
        # Flatten으로 shape 펼치기
        Flatten(input_shape=(28, 28)),
        # Dense Layer
        Dense(1024, activation='relu'),
        Dense(512, activation='relu'),
        Dense(256, activation='relu'),
        Dense(128, activation='relu'),
        Dense(64, activation='relu'),
        Dense(32, activation='relu'),
        # Classification을 위한 Softmax 
        Dense(10, activation='softmax'),
    ])
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['acc'])
    checkpoint_path = "my_checkpoint.ckpt"
    checkpoint = ModelCheckpoint(filepath=checkpoint_path, 
                                save_weights_only=True, 
                                save_best_only=True, 
                                monitor='val_loss', 
                                verbose=1)
    
    history = model.fit(x_train, y_train,
                        validation_data=(x_valid, y_valid),
                        epochs=50,
                        callbacks=[checkpoint],
                      )
    model.load_weights(checkpoint_path)

    return model


# Note that you'll need to save your model as a .h5 like this
# This .h5 will be uploaded to the testing infrastructure
# and a score will be returned to you
if __name__ == '__main__':
    model = solution_model()
    model.save("mymodel.h5")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 8192/5148 [===============================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step
# Epoch 1/50
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.5200 - acc: 0.8109 - val_loss: 0.4856 - val_acc: 0.8302
#
# Epoch 00001: val_loss improved from inf to 0.48557, saving model to my_checkpoint.ckpt
# Epoch 2/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3852 - acc: 0.8625 - val_loss: 0.4561 - val_acc: 0.8475
#
# Epoch 00002: val_loss improved from 0.48557 to 0.45606, saving model to my_checkpoint.ckpt
# Epoch 3/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3407 - acc: 0.8775 - val_loss: 0.3761 - val_acc: 0.8694
#
# Epoch 00003: val_loss improved from 0.45606 to 0.37609, saving model to my_checkpoint.ckpt
# Epoch 4/50
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.3214 - acc: 0.8829 - val_loss: 0.3655 - val_acc: 0.8687
#
# Epoch 00004: val_loss improved from 0.37609 to 0.36552, saving model to my_checkpoint.ckpt
# Epoch 5/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3032 - acc: 0.8890 - val_loss: 0.3555 - val_acc: 0.8762
#
# Epoch 00005: val_loss improved from 0.36552 to 0.35551, saving model to my_checkpoint.ckpt
# Epoch 6/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2876 - acc: 0.8949 - val_loss: 0.3645 - val_acc: 0.8784
#
# Epoch 00006: val_loss did not improve from 0.35551
# Epoch 7/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2734 - acc: 0.8989 - val_loss: 0.3569 - val_acc: 0.8701
#
# Epoch 00007: val_loss did not improve from 0.35551
# Epoch 8/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2625 - acc: 0.9017 - val_loss: 0.3657 - val_acc: 0.8691
#
# Epoch 00008: val_loss did not improve from 0.35551
# Epoch 9/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2556 - acc: 0.9053 - val_loss: 0.3533 - val_acc: 0.8808
#
# Epoch 00009: val_loss improved from 0.35551 to 0.35329, saving model to my_checkpoint.ckpt
# Epoch 10/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2451 - acc: 0.9087 - val_loss: 0.4061 - val_acc: 0.8683
#
# Epoch 00010: val_loss did not improve from 0.35329
# Epoch 11/50
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.2363 - acc: 0.9116 - val_loss: 0.4010 - val_acc: 0.8712
#
# Epoch 00011: val_loss did not improve from 0.35329
# Epoch 12/50
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.2309 - acc: 0.9140 - val_loss: 0.3293 - val_acc: 0.8862
#
# Epoch 00012: val_loss improved from 0.35329 to 0.32933, saving model to my_checkpoint.ckpt
# Epoch 13/50
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.2231 - acc: 0.9168 - val_loss: 0.3367 - val_acc: 0.8903
#
# Epoch 00013: val_loss did not improve from 0.32933
# Epoch 14/50
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.2169 - acc: 0.9184 - val_loss: 0.3594 - val_acc: 0.8898
#
# Epoch 00014: val_loss did not improve from 0.32933
# Epoch 15/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2079 - acc: 0.9226 - val_loss: 0.3465 - val_acc: 0.8908
#
# Epoch 00015: val_loss did not improve from 0.32933
# Epoch 16/50
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.2036 - acc: 0.9237 - val_loss: 0.3575 - val_acc: 0.8884
#
# Epoch 00016: val_loss did not improve from 0.32933
# Epoch 17/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1997 - acc: 0.9267 - val_loss: 0.3542 - val_acc: 0.8922
#
# Epoch 00017: val_loss did not improve from 0.32933
# Epoch 18/50
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1964 - acc: 0.9267 - val_loss: 0.3552 - val_acc: 0.8900
#
# Epoch 00018: val_loss did not improve from 0.32933
# Epoch 19/50
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1901 - acc: 0.9301 - val_loss: 0.3497 - val_acc: 0.8905
#
# Epoch 00019: val_loss did not improve from 0.32933
# Epoch 20/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1843 - acc: 0.9305 - val_loss: 0.3719 - val_acc: 0.8904
#
# Epoch 00020: val_loss did not improve from 0.32933
# Epoch 21/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1780 - acc: 0.9336 - val_loss: 0.3401 - val_acc: 0.8939
#
# Epoch 00021: val_loss did not improve from 0.32933
# Epoch 22/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1728 - acc: 0.9354 - val_loss: 0.4326 - val_acc: 0.8903
#
# Epoch 00022: val_loss did not improve from 0.32933
# Epoch 23/50
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1736 - acc: 0.9351 - val_loss: 0.3569 - val_acc: 0.8914
#
# Epoch 00023: val_loss did not improve from 0.32933
# Epoch 24/50
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1682 - acc: 0.9379 - val_loss: 0.3883 - val_acc: 0.8935
#
# Epoch 00024: val_loss did not improve from 0.32933
# Epoch 25/50
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1596 - acc: 0.9394 - val_loss: 0.4424 - val_acc: 0.8895
#
# Epoch 00025: val_loss did not improve from 0.32933
# Epoch 26/50
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1627 - acc: 0.9392 - val_loss: 0.3972 - val_acc: 0.8901
#
# Epoch 00026: val_loss did not improve from 0.32933
# Epoch 27/50
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1564 - acc: 0.9415 - val_loss: 0.4525 - val_acc: 0.8968
#
# Epoch 00027: val_loss did not improve from 0.32933
# Epoch 28/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1550 - acc: 0.9427 - val_loss: 0.3894 - val_acc: 0.8953
#
# Epoch 00028: val_loss did not improve from 0.32933
# Epoch 29/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1525 - acc: 0.9427 - val_loss: 0.4310 - val_acc: 0.8984
#
# Epoch 00029: val_loss did not improve from 0.32933
# Epoch 30/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1482 - acc: 0.9443 - val_loss: 0.4153 - val_acc: 0.8938
#
# Epoch 00030: val_loss did not improve from 0.32933
# Epoch 31/50
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1460 - acc: 0.9465 - val_loss: 0.4656 - val_acc: 0.9006
#
# Epoch 00031: val_loss did not improve from 0.32933
# Epoch 32/50
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1392 - acc: 0.9477 - val_loss: 0.4539 - val_acc: 0.8979
#
# Epoch 00032: val_loss did not improve from 0.32933
# Epoch 33/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1369 - acc: 0.9489 - val_loss: 0.5108 - val_acc: 0.8950
#
# Epoch 00033: val_loss did not improve from 0.32933
# Epoch 34/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1402 - acc: 0.9492 - val_loss: 0.4796 - val_acc: 0.8927
#
# Epoch 00034: val_loss did not improve from 0.32933
# Epoch 35/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1371 - acc: 0.9475 - val_loss: 0.4779 - val_acc: 0.8919
#
# Epoch 00035: val_loss did not improve from 0.32933
# Epoch 36/50
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1321 - acc: 0.9497 - val_loss: 0.4749 - val_acc: 0.8854
#
# Epoch 00036: val_loss did not improve from 0.32933
# Epoch 37/50
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1255 - acc: 0.9531 - val_loss: 0.5145 - val_acc: 0.9001
#
# Epoch 00037: val_loss did not improve from 0.32933
# Epoch 38/50
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1345 - acc: 0.9512 - val_loss: 0.4623 - val_acc: 0.8944
#
# Epoch 00038: val_loss did not improve from 0.32933
# Epoch 39/50
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1212 - acc: 0.9549 - val_loss: 0.5173 - val_acc: 0.8939
#
# Epoch 00039: val_loss did not improve from 0.32933
# Epoch 40/50
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1285 - acc: 0.9540 - val_loss: 0.4551 - val_acc: 0.8942
#
# Epoch 00040: val_loss did not improve from 0.32933
# Epoch 41/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1175 - acc: 0.9553 - val_loss: 0.4882 - val_acc: 0.8958
#
# Epoch 00041: val_loss did not improve from 0.32933
# Epoch 42/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1166 - acc: 0.9564 - val_loss: 0.5410 - val_acc: 0.9035
#
# Epoch 00042: val_loss did not improve from 0.32933
# Epoch 43/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1199 - acc: 0.9566 - val_loss: 0.4873 - val_acc: 0.8951
#
# Epoch 00043: val_loss did not improve from 0.32933
# Epoch 44/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1159 - acc: 0.9575 - val_loss: 0.5547 - val_acc: 0.8966
#
# Epoch 00044: val_loss did not improve from 0.32933
# Epoch 45/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1117 - acc: 0.9587 - val_loss: 0.5726 - val_acc: 0.9019
#
# Epoch 00045: val_loss did not improve from 0.32933
# Epoch 46/50
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1047 - acc: 0.9597 - val_loss: 0.5382 - val_acc: 0.8942
#
# Epoch 00046: val_loss did not improve from 0.32933
# Epoch 47/50
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1133 - acc: 0.9588 - val_loss: 0.5129 - val_acc: 0.8986
#
# Epoch 00047: val_loss did not improve from 0.32933
# Epoch 48/50
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1023 - acc: 0.9624 - val_loss: 0.5482 - val_acc: 0.8995
#
# Epoch 00048: val_loss did not improve from 0.32933
# Epoch 49/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1131 - acc: 0.9599 - val_loss: 0.6823 - val_acc: 0.8992
#
# Epoch 00049: val_loss did not improve from 0.32933
# Epoch 50/50
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1049 - acc: 0.9608 - val_loss: 0.6231 - val_acc: 0.8977
#
# Epoch 00050: val_loss did not improve from 0.32933

# %% [markdown]
# #TF2-fashion-mnist-3-cnn-0.3263

# %%
# ======================================================================
# There are 5 questions in this test with increasing difficulty from 1-5
# Please note that the weight of the grade for the question is relative
# to its difficulty. So your Category 1 question will score much less
# than your Category 5 question.
# ======================================================================
#
# Basic Datasets Question
#
# Create a classifier for the Fashion MNIST dataset
# Note that the test will expect it to classify 10 classes and that the 
# input shape should be the native size of the Fashion MNIST dataset which is 
# 28x28 monochrome. Do not resize the data. YOur input layer should accept
# (28,28) as the input shape only. If you amend this, the tests will fail.
#

# =========== 합격 기준 가이드라인 공유 ============= #
# val_loss 기준에 맞춰 주시는 것이 훨씬 더 중요 #
# val_loss 보다 조금 높아도 상관없음. (언저리까지 OK) #
# =================================================== #
# 문제명: Category 2 - fashion mnist
# val_loss: 0.33
# val_acc: 0.89
# =================================================== #
# =================================================== #



import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import ModelCheckpoint


def solution_model():
    fashion_mnist = tf.keras.datasets.fashion_mnist
    (x_train, y_train), (x_valid, y_valid) = fashion_mnist.load_data()
    x_train = x_train / 255.0
    x_valid = x_valid / 255.0

    model = Sequential([
                        tf.keras.layers.Reshape((28, 28, 1), input_shape=(28, 28)),
                        tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
                        tf.keras.layers.MaxPooling2D(2, 2),
                        tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
                        tf.keras.layers.MaxPooling2D(2, 2),
                        tf.keras.layers.Conv2D(32, (3, 3), activation='relu'),
                        tf.keras.layers.MaxPooling2D(2, 2),
                        tf.keras.layers.Flatten(),
                        tf.keras.layers.Dense(32, activation='relu'),
                        tf.keras.layers.Dense(10, activation='softmax') ,
                        ])
    model.compile(optimizer='RMSprop', loss='sparse_categorical_crossentropy', metrics=['acc'])
    checkpoint_path = "my_checkpoint.ckpt"
    checkpoint = ModelCheckpoint(filepath=checkpoint_path, 
                                save_weights_only=True, 
                                save_best_only=True, 
                                monitor='val_loss', 
                                verbose=1)
    
    history = model.fit(x_train, y_train,
                        validation_data=(x_valid, y_valid),
                        epochs=30,
                        callbacks=[checkpoint],
                      )
    model.load_weights(checkpoint_path)

    return model


# Note that you'll need to save your model as a .h5 like this
# This .h5 will be uploaded to the testing infrastructure
# and a score will be returned to you
if __name__ == '__main__':
    model = solution_model()
    model.save("mymodel.h5")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 8192/5148 [===============================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step
# Epoch 1/30
# 1875/1875 [==============================] - 21s 3ms/step - loss: 0.6137 - acc: 0.7759 - val_loss: 0.4783 - val_acc: 0.8255
#
# Epoch 00001: val_loss improved from inf to 0.47826, saving model to my_checkpoint.ckpt
# Epoch 2/30
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4085 - acc: 0.8508 - val_loss: 0.3891 - val_acc: 0.8586
#
# Epoch 00002: val_loss improved from 0.47826 to 0.38914, saving model to my_checkpoint.ckpt
# Epoch 3/30
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3550 - acc: 0.8710 - val_loss: 0.3652 - val_acc: 0.8680
#
# Epoch 00003: val_loss improved from 0.38914 to 0.36524, saving model to my_checkpoint.ckpt
# Epoch 4/30
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3233 - acc: 0.8797 - val_loss: 0.3554 - val_acc: 0.8728
#
# Epoch 00004: val_loss improved from 0.36524 to 0.35538, saving model to my_checkpoint.ckpt
# Epoch 5/30
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3009 - acc: 0.8888 - val_loss: 0.3765 - val_acc: 0.8685
#
# Epoch 00005: val_loss did not improve from 0.35538
# Epoch 6/30
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2837 - acc: 0.8960 - val_loss: 0.3763 - val_acc: 0.8746
#
# Epoch 00006: val_loss did not improve from 0.35538
# Epoch 7/30
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2698 - acc: 0.9012 - val_loss: 0.3413 - val_acc: 0.8823
#
# Epoch 00007: val_loss improved from 0.35538 to 0.34134, saving model to my_checkpoint.ckpt
# Epoch 8/30
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2591 - acc: 0.9056 - val_loss: 0.3607 - val_acc: 0.8864
#
# Epoch 00008: val_loss did not improve from 0.34134
# Epoch 9/30
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2500 - acc: 0.9097 - val_loss: 0.3634 - val_acc: 0.8768
#
# Epoch 00009: val_loss did not improve from 0.34134
# Epoch 10/30
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2404 - acc: 0.9117 - val_loss: 0.3969 - val_acc: 0.8711
#
# Epoch 00010: val_loss did not improve from 0.34134
# Epoch 11/30
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2345 - acc: 0.9151 - val_loss: 0.3269 - val_acc: 0.8896
#
# Epoch 00011: val_loss improved from 0.34134 to 0.32694, saving model to my_checkpoint.ckpt
# Epoch 12/30
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2289 - acc: 0.9171 - val_loss: 0.3566 - val_acc: 0.8770
#
# Epoch 00012: val_loss did not improve from 0.32694
# Epoch 13/30
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2232 - acc: 0.9200 - val_loss: 0.3523 - val_acc: 0.8869
#
# Epoch 00013: val_loss did not improve from 0.32694
# Epoch 14/30
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2181 - acc: 0.9211 - val_loss: 0.4122 - val_acc: 0.8743
#
# Epoch 00014: val_loss did not improve from 0.32694
# Epoch 15/30
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2143 - acc: 0.9230 - val_loss: 0.3454 - val_acc: 0.8899
#
# Epoch 00015: val_loss did not improve from 0.32694
# Epoch 16/30
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2087 - acc: 0.9251 - val_loss: 0.3660 - val_acc: 0.8889
#
# Epoch 00016: val_loss did not improve from 0.32694
# Epoch 17/30
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2081 - acc: 0.9258 - val_loss: 0.4012 - val_acc: 0.8868
#
# Epoch 00017: val_loss did not improve from 0.32694
# Epoch 18/30
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2057 - acc: 0.9255 - val_loss: 0.4062 - val_acc: 0.8807
#
# Epoch 00018: val_loss did not improve from 0.32694
# Epoch 19/30
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2044 - acc: 0.9278 - val_loss: 0.4514 - val_acc: 0.8897
#
# Epoch 00019: val_loss did not improve from 0.32694
# Epoch 20/30
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2064 - acc: 0.9272 - val_loss: 0.3913 - val_acc: 0.8779
#
# Epoch 00020: val_loss did not improve from 0.32694
# Epoch 21/30
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2026 - acc: 0.9280 - val_loss: 0.4406 - val_acc: 0.8873
#
# Epoch 00021: val_loss did not improve from 0.32694
# Epoch 22/30
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2001 - acc: 0.9296 - val_loss: 0.4233 - val_acc: 0.8790
#
# Epoch 00022: val_loss did not improve from 0.32694
# Epoch 23/30
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2030 - acc: 0.9284 - val_loss: 0.3905 - val_acc: 0.8851
#
# Epoch 00023: val_loss did not improve from 0.32694
# Epoch 24/30
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2019 - acc: 0.9301 - val_loss: 0.4923 - val_acc: 0.8711
#
# Epoch 00024: val_loss did not improve from 0.32694
# Epoch 25/30
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2018 - acc: 0.9289 - val_loss: 0.5683 - val_acc: 0.8685
#
# Epoch 00025: val_loss did not improve from 0.32694
# Epoch 26/30
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2032 - acc: 0.9288 - val_loss: 0.4977 - val_acc: 0.8810
#
# Epoch 00026: val_loss did not improve from 0.32694
# Epoch 27/30
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2041 - acc: 0.9293 - val_loss: 0.5753 - val_acc: 0.8824
#
# Epoch 00027: val_loss did not improve from 0.32694
# Epoch 28/30
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2039 - acc: 0.9287 - val_loss: 0.5500 - val_acc: 0.8853
#
# Epoch 00028: val_loss did not improve from 0.32694
# Epoch 29/30
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2085 - acc: 0.9283 - val_loss: 0.4494 - val_acc: 0.8792
#
# Epoch 00029: val_loss did not improve from 0.32694
# Epoch 30/30
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2055 - acc: 0.9288 - val_loss: 0.6956 - val_acc: 0.8762
#
# Epoch 00030: val_loss did not improve from 0.32694
