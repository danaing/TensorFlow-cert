# %% [markdown]
# <a href="https://colab.research.google.com/github/danaing/TensorFlow-cert/blob/main/TF3_rps.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #TF3-rps-1-val-loss-0.0434

# %%
# ======================================================================
# There are 5 questions in this test with increasing difficulty from 1-5
# Please note that the weight of the grade for the question is relative
# to its difficulty. So your Category 1 question will score much less
# than your Category 5 question.
# ======================================================================
#
# Computer Vision with CNNs
#
# For this task you will build a classifier for Rock-Paper-Scissors 
# based on the rps dataset.
#
# IMPORTANT: Your final layer should be as shown, do not change the
# provided code, or the tests may fail
#
# IMPORTANT: Images will be tested as 150x150 with 3 bytes of color depth
# So ensure that your input layer is designed accordingly, or the tests
# may fail. 
#
# NOTE THAT THIS IS UNLABELLED DATA. 
# You can use the ImageDataGenerator to automatically label it
# and we have provided some starter code.

# =========== 합격 기준 가이드라인 공유 ============= #
# val_loss 기준에 맞춰 주시는 것이 훨씬 더 중요 #
# val_loss 보다 조금 높아도 상관없음. (언저리까지 OK) #
# =================================================== #
# 문제명: Category 3 - rps
# val_loss: 0.0871
# val_acc: 0.97
# =================================================== #
# =================================================== #

import urllib.request
import zipfile
import numpy as np
from IPython.display import Image

import tensorflow as tf
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dropout, Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint

def solution_model():
    url = 'https://storage.googleapis.com/download.tensorflow.org/data/rps.zip'
    urllib.request.urlretrieve(url, 'rps.zip')
    local_zip = 'rps.zip'
    zip_ref = zipfile.ZipFile(local_zip, 'r')
    zip_ref.extractall('tmp/')
    zip_ref.close()


    TRAINING_DIR = "tmp/rps/"
    training_datagen = ImageDataGenerator(
          rescale=1. / 255,
          rotation_range=5,
          width_shift_range=0.05,
          height_shift_range=0.05,
          zoom_range=0.05,
          horizontal_flip=True,
          fill_mode= 'reflect', 
          validation_split=0.2
        )
    
    training_generator = training_datagen.flow_from_directory(TRAINING_DIR, 
                                                          batch_size=128, 
                                                          target_size=(150, 150), 
                                                          class_mode='categorical', 
                                                          subset='training',
                                                         )

    validation_generator = training_datagen.flow_from_directory(TRAINING_DIR, 
                                                              batch_size=128, 
                                                              target_size=(150, 150), 
                                                              class_mode='categorical',
                                                              subset='validation', 
                                                            )

    model = Sequential([
        # Conv2D, MaxPooling2D 조합으로 층을 쌓습니다. 첫번째 입력층의 input_shape은 (150, 150, 3)으로 지정합니다.
        Conv2D(32, (3, 3), activation='relu', input_shape=(150, 150, 3)),
        MaxPooling2D(2, 2), 
        Conv2D(64, (3, 3), activation='relu'),
        MaxPooling2D(2, 2), 
        Conv2D(128, (3, 3), activation='relu'),
        MaxPooling2D(2, 2), 
        Conv2D(128, (3, 3), activation='relu'),
        MaxPooling2D(2, 2), 
        Flatten(), 
        Dropout(0.5),
        Dense(128, activation='relu'),
        Dense(3, activation='softmax'),
    ])

    model.compile(optimizer='RMSprop', loss='categorical_crossentropy', metrics=['acc'])

    checkpoint_path = "tmp_checkpoint.ckpt"
    checkpoint = ModelCheckpoint(filepath=checkpoint_path, 
                                save_weights_only=True, 
                                save_best_only=True, 
                                monitor='val_loss', 
                                verbose=1)
    
    model.fit(training_generator, 
              validation_data=(validation_generator),
              epochs=25,
              callbacks=[checkpoint],
              )
    
    model.load_weights(checkpoint_path)

    return model



# Note that you'll need to save your model as a .h5 like this
# This .h5 will be uploaded to the testing infrastructure
# and a score will be returned to you
if __name__ == '__main__':
    model = solution_model()
    model.save("mymodel.h5")
# Out:
# Found 2016 images belonging to 3 classes.
# Found 504 images belonging to 3 classes.
# Epoch 1/25
# 16/16 [==============================] - 21s 1s/step - loss: 1.2821 - acc: 0.3874 - val_loss: 1.0888 - val_acc: 0.4167
#
# Epoch 00001: val_loss improved from inf to 1.08875, saving model to tmp_checkpoint.ckpt
# Epoch 2/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.7222 - acc: 0.6944 - val_loss: 0.8177 - val_acc: 0.6548
#
# Epoch 00002: val_loss improved from 1.08875 to 0.81767, saving model to tmp_checkpoint.ckpt
# Epoch 3/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.4645 - acc: 0.8194 - val_loss: 0.3521 - val_acc: 0.8730
#
# Epoch 00003: val_loss improved from 0.81767 to 0.35212, saving model to tmp_checkpoint.ckpt
# Epoch 4/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.2166 - acc: 0.9276 - val_loss: 0.2391 - val_acc: 0.9087
#
# Epoch 00004: val_loss improved from 0.35212 to 0.23910, saving model to tmp_checkpoint.ckpt
# Epoch 5/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.0888 - acc: 0.9732 - val_loss: 0.1322 - val_acc: 0.9484
#
# Epoch 00005: val_loss improved from 0.23910 to 0.13222, saving model to tmp_checkpoint.ckpt
# Epoch 6/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.2085 - acc: 0.9320 - val_loss: 0.1257 - val_acc: 0.9683
#
# Epoch 00006: val_loss improved from 0.13222 to 0.12575, saving model to tmp_checkpoint.ckpt
# Epoch 7/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.0252 - acc: 0.9906 - val_loss: 0.1318 - val_acc: 0.9563
#
# Epoch 00007: val_loss did not improve from 0.12575
# Epoch 8/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.2754 - acc: 0.9449 - val_loss: 0.8664 - val_acc: 0.5218
#
# Epoch 00008: val_loss did not improve from 0.12575
# Epoch 9/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.0514 - acc: 0.9782 - val_loss: 0.1203 - val_acc: 0.9504
#
# Epoch 00009: val_loss improved from 0.12575 to 0.12033, saving model to tmp_checkpoint.ckpt
# Epoch 10/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.0271 - acc: 0.9921 - val_loss: 0.6401 - val_acc: 0.8651
#
# Epoch 00010: val_loss did not improve from 0.12033
# Epoch 11/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.0855 - acc: 0.9717 - val_loss: 0.4069 - val_acc: 0.8056
#
# Epoch 00011: val_loss did not improve from 0.12033
# Epoch 12/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.0102 - acc: 0.9970 - val_loss: 0.0924 - val_acc: 0.9683
#
# Epoch 00012: val_loss improved from 0.12033 to 0.09238, saving model to tmp_checkpoint.ckpt
# Epoch 13/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.1619 - acc: 0.9608 - val_loss: 0.1818 - val_acc: 0.9365
#
# Epoch 00013: val_loss did not improve from 0.09238
# Epoch 14/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.0114 - acc: 0.9975 - val_loss: 0.0727 - val_acc: 0.9663
#
# Epoch 00014: val_loss improved from 0.09238 to 0.07268, saving model to tmp_checkpoint.ckpt
# Epoch 15/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.0057 - acc: 0.9975 - val_loss: 0.0434 - val_acc: 0.9881
#
# Epoch 00015: val_loss improved from 0.07268 to 0.04338, saving model to tmp_checkpoint.ckpt
# Epoch 16/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.2873 - acc: 0.9643 - val_loss: 1.5093 - val_acc: 0.5437
#
# Epoch 00016: val_loss did not improve from 0.04338
# Epoch 17/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.0331 - acc: 0.9916 - val_loss: 0.1181 - val_acc: 0.9444
#
# Epoch 00017: val_loss did not improve from 0.04338
# Epoch 18/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.0096 - acc: 0.9965 - val_loss: 0.1203 - val_acc: 0.9385
#
# Epoch 00018: val_loss did not improve from 0.04338
# Epoch 19/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.0034 - acc: 0.9990 - val_loss: 0.1799 - val_acc: 0.9306
#
# Epoch 00019: val_loss did not improve from 0.04338
# Epoch 20/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.2038 - acc: 0.9544 - val_loss: 0.1804 - val_acc: 0.9444
#
# Epoch 00020: val_loss did not improve from 0.04338
# Epoch 21/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.0051 - acc: 0.9985 - val_loss: 0.1532 - val_acc: 0.9504
#
# Epoch 00021: val_loss did not improve from 0.04338
# Epoch 22/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.0033 - acc: 0.9985 - val_loss: 1.6157 - val_acc: 0.7956
#
# Epoch 00022: val_loss did not improve from 0.04338
# Epoch 23/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.0716 - acc: 0.9891 - val_loss: 0.1152 - val_acc: 0.9583
#
# Epoch 00023: val_loss did not improve from 0.04338
# Epoch 24/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.0075 - acc: 0.9980 - val_loss: 0.1255 - val_acc: 0.9643
#
# Epoch 00024: val_loss did not improve from 0.04338
# Epoch 25/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.0852 - acc: 0.9792 - val_loss: 0.1536 - val_acc: 0.9504
#
# Epoch 00025: val_loss did not improve from 0.04338

# %% [markdown]
# #TF3-rps-2-val-loss-0.052

# %%
# ======================================================================
# There are 5 questions in this test with increasing difficulty from 1-5
# Please note that the weight of the grade for the question is relative
# to its difficulty. So your Category 1 question will score much less
# than your Category 5 question.
# ======================================================================
#
# Computer Vision with CNNs
#
# For this task you will build a classifier for Rock-Paper-Scissors 
# based on the rps dataset.
#
# IMPORTANT: Your final layer should be as shown, do not change the
# provided code, or the tests may fail
#
# IMPORTANT: Images will be tested as 150x150 with 3 bytes of color depth
# So ensure that your input layer is designed accordingly, or the tests
# may fail. 
#
# NOTE THAT THIS IS UNLABELLED DATA. 
# You can use the ImageDataGenerator to automatically label it
# and we have provided some starter code.

# =========== 합격 기준 가이드라인 공유 ============= #
# val_loss 기준에 맞춰 주시는 것이 훨씬 더 중요 #
# val_loss 보다 조금 높아도 상관없음. (언저리까지 OK) #
# =================================================== #
# 문제명: Category 3 - rps
# val_loss: 0.0871
# val_acc: 0.97
# =================================================== #
# =================================================== #

import urllib.request
import zipfile
import numpy as np
from IPython.display import Image

import tensorflow as tf
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dropout, Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint

def solution_model():
    url = 'https://storage.googleapis.com/download.tensorflow.org/data/rps.zip'
    urllib.request.urlretrieve(url, 'rps.zip')
    local_zip = 'rps.zip'
    zip_ref = zipfile.ZipFile(local_zip, 'r')
    zip_ref.extractall('tmp/')
    zip_ref.close()


    TRAINING_DIR = "tmp/rps/"
    training_datagen = ImageDataGenerator(
          rescale=1. / 255,
          rotation_range=5,
          width_shift_range=0.05,
          height_shift_range=0.05,
          zoom_range=0.05,
          horizontal_flip=True,
          fill_mode= 'reflect', 
          validation_split=0.2
        )
    
    training_generator = training_datagen.flow_from_directory(TRAINING_DIR, 
                                                          batch_size=128, 
                                                          target_size=(150, 150), 
                                                          class_mode='categorical', 
                                                          subset='training',
                                                         )

    validation_generator = training_datagen.flow_from_directory(TRAINING_DIR, 
                                                              batch_size=128, 
                                                              target_size=(150, 150), 
                                                              class_mode='categorical',
                                                              subset='validation', 
                                                            )

    model = Sequential([
        # Conv2D, MaxPooling2D 조합으로 층을 쌓습니다. 첫번째 입력층의 input_shape은 (150, 150, 3)으로 지정합니다.
        Conv2D(32, (3, 3), activation='relu', input_shape=(150, 150, 3)),
        MaxPooling2D(2, 2), 
        Conv2D(64, (3, 3), activation='relu'),
        MaxPooling2D(2, 2), 
        Conv2D(128, (3, 3), activation='relu'),
        MaxPooling2D(2, 2), 
        Conv2D(128, (3, 3), activation='relu'),
        MaxPooling2D(2, 2), 
        Flatten(), 
        Dropout(0.5),
        Dense(128, activation='relu'),
        Dense(3, activation='softmax'),
    ])

    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['acc'])

    checkpoint_path = "tmp_checkpoint.ckpt"
    checkpoint = ModelCheckpoint(filepath=checkpoint_path, 
                                save_weights_only=True, 
                                save_best_only=True, 
                                monitor='val_loss', 
                                verbose=1)
    
    model.fit(training_generator, 
              validation_data=(validation_generator),
              epochs=25,
              callbacks=[checkpoint],
              )
    
    model.load_weights(checkpoint_path)

    return model



# Note that you'll need to save your model as a .h5 like this
# This .h5 will be uploaded to the testing infrastructure
# and a score will be returned to you
if __name__ == '__main__':
    model = solution_model()
    model.save("mymodel.h5")
# Out:
# Found 2016 images belonging to 3 classes.
# Found 504 images belonging to 3 classes.
# Epoch 1/25
# 16/16 [==============================] - 21s 1s/step - loss: 1.0247 - acc: 0.4792 - val_loss: 0.8218 - val_acc: 0.5397
#
# Epoch 00001: val_loss improved from inf to 0.82182, saving model to tmp_checkpoint.ckpt
# Epoch 2/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.5852 - acc: 0.7545 - val_loss: 0.4060 - val_acc: 0.9087
#
# Epoch 00002: val_loss improved from 0.82182 to 0.40601, saving model to tmp_checkpoint.ckpt
# Epoch 3/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.1726 - acc: 0.9335 - val_loss: 0.2345 - val_acc: 0.8909
#
# Epoch 00003: val_loss improved from 0.40601 to 0.23453, saving model to tmp_checkpoint.ckpt
# Epoch 4/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.0602 - acc: 0.9792 - val_loss: 0.8967 - val_acc: 0.6627
#
# Epoch 00004: val_loss did not improve from 0.23453
# Epoch 5/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.0505 - acc: 0.9787 - val_loss: 0.1153 - val_acc: 0.9623
#
# Epoch 00005: val_loss improved from 0.23453 to 0.11526, saving model to tmp_checkpoint.ckpt
# Epoch 6/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.0317 - acc: 0.9886 - val_loss: 0.2130 - val_acc: 0.9048
#
# Epoch 00006: val_loss did not improve from 0.11526
# Epoch 7/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.0139 - acc: 0.9960 - val_loss: 0.2859 - val_acc: 0.8968
#
# Epoch 00007: val_loss did not improve from 0.11526
# Epoch 8/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.0150 - acc: 0.9945 - val_loss: 0.5166 - val_acc: 0.8611
#
# Epoch 00008: val_loss did not improve from 0.11526
# Epoch 9/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.0173 - acc: 0.9960 - val_loss: 0.1218 - val_acc: 0.9484
#
# Epoch 00009: val_loss did not improve from 0.11526
# Epoch 10/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.0096 - acc: 0.9980 - val_loss: 0.3455 - val_acc: 0.8671
#
# Epoch 00010: val_loss did not improve from 0.11526
# Epoch 11/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.0099 - acc: 0.9970 - val_loss: 0.0916 - val_acc: 0.9603
#
# Epoch 00011: val_loss improved from 0.11526 to 0.09160, saving model to tmp_checkpoint.ckpt
# Epoch 12/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.0099 - acc: 0.9975 - val_loss: 0.2341 - val_acc: 0.9187
#
# Epoch 00012: val_loss did not improve from 0.09160
# Epoch 13/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.0115 - acc: 0.9960 - val_loss: 0.4736 - val_acc: 0.8452
#
# Epoch 00013: val_loss did not improve from 0.09160
# Epoch 14/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.0199 - acc: 0.9931 - val_loss: 0.0884 - val_acc: 0.9702
#
# Epoch 00014: val_loss improved from 0.09160 to 0.08836, saving model to tmp_checkpoint.ckpt
# Epoch 15/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.0123 - acc: 0.9955 - val_loss: 0.3169 - val_acc: 0.8710
#
# Epoch 00015: val_loss did not improve from 0.08836
# Epoch 16/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.0043 - acc: 0.9990 - val_loss: 0.1529 - val_acc: 0.9524
#
# Epoch 00016: val_loss did not improve from 0.08836
# Epoch 17/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.0032 - acc: 0.9990 - val_loss: 0.1825 - val_acc: 0.9405
#
# Epoch 00017: val_loss did not improve from 0.08836
# Epoch 18/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.0036 - acc: 0.9990 - val_loss: 0.2024 - val_acc: 0.9365
#
# Epoch 00018: val_loss did not improve from 0.08836
# Epoch 19/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.0048 - acc: 0.9985 - val_loss: 0.0520 - val_acc: 0.9841
#
# Epoch 00019: val_loss improved from 0.08836 to 0.05196, saving model to tmp_checkpoint.ckpt
# Epoch 20/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.0035 - acc: 0.9985 - val_loss: 0.1137 - val_acc: 0.9623
#
# Epoch 00020: val_loss did not improve from 0.05196
# Epoch 21/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.0036 - acc: 0.9985 - val_loss: 0.0972 - val_acc: 0.9643
#
# Epoch 00021: val_loss did not improve from 0.05196
# Epoch 22/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.0040 - acc: 0.9985 - val_loss: 0.0551 - val_acc: 0.9762
#
# Epoch 00022: val_loss did not improve from 0.05196
# Epoch 23/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.0026 - acc: 0.9995 - val_loss: 0.1722 - val_acc: 0.9484
#
# Epoch 00023: val_loss did not improve from 0.05196
# Epoch 24/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.0030 - acc: 0.9990 - val_loss: 0.7508 - val_acc: 0.8393
#
# Epoch 00024: val_loss did not improve from 0.05196
# Epoch 25/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.0028 - acc: 0.9990 - val_loss: 0.3266 - val_acc: 0.9127
#
# Epoch 00025: val_loss did not improve from 0.05196

# %% [markdown]
# #TF3-rps-3-val-loss-0.0304

# %%
# ======================================================================
# There are 5 questions in this test with increasing difficulty from 1-5
# Please note that the weight of the grade for the question is relative
# to its difficulty. So your Category 1 question will score much less
# than your Category 5 question.
# ======================================================================
#
# Computer Vision with CNNs
#
# For this task you will build a classifier for Rock-Paper-Scissors 
# based on the rps dataset.
#
# IMPORTANT: Your final layer should be as shown, do not change the
# provided code, or the tests may fail
#
# IMPORTANT: Images will be tested as 150x150 with 3 bytes of color depth
# So ensure that your input layer is designed accordingly, or the tests
# may fail. 
#
# NOTE THAT THIS IS UNLABELLED DATA. 
# You can use the ImageDataGenerator to automatically label it
# and we have provided some starter code.

# =========== 합격 기준 가이드라인 공유 ============= #
# val_loss 기준에 맞춰 주시는 것이 훨씬 더 중요 #
# val_loss 보다 조금 높아도 상관없음. (언저리까지 OK) #
# =================================================== #
# 문제명: Category 3 - rps
# val_loss: 0.0871
# val_acc: 0.97
# =================================================== #
# =================================================== #

import urllib.request
import zipfile
import numpy as np
from IPython.display import Image

import tensorflow as tf
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dropout, Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint

def solution_model():
    url = 'https://storage.googleapis.com/download.tensorflow.org/data/rps.zip'
    urllib.request.urlretrieve(url, 'rps.zip')
    local_zip = 'rps.zip'
    zip_ref = zipfile.ZipFile(local_zip, 'r')
    zip_ref.extractall('tmp/')
    zip_ref.close()


    TRAINING_DIR = "tmp/rps/"
    training_datagen = ImageDataGenerator(
          rescale=1. / 255,
          rotation_range=5,
          width_shift_range=0.05,
          height_shift_range=0.05,
          zoom_range=0.05,
          horizontal_flip=True,
          fill_mode='reflect', 
          validation_split=0.2
        )
    
    training_generator = training_datagen.flow_from_directory(TRAINING_DIR, 
                                                          batch_size=128, 
                                                          target_size=(150, 150), 
                                                          class_mode='categorical', 
                                                          subset='training',
                                                         )

    validation_generator = training_datagen.flow_from_directory(TRAINING_DIR, 
                                                              batch_size=128, 
                                                              target_size=(150, 150), 
                                                              class_mode='categorical',
                                                              subset='validation', 
                                                            )

    model = Sequential([
        # Conv2D, MaxPooling2D 조합으로 층을 쌓습니다. 첫번째 입력층의 input_shape은 (150, 150, 3)으로 지정합니다.
        Conv2D(64, (3, 3), activation='relu', input_shape=(150, 150, 3)),
        MaxPooling2D(2, 2), 
        Conv2D(64, (3, 3), activation='relu'),
        MaxPooling2D(2, 2), 
        Conv2D(128, (3, 3), activation='relu'),
        MaxPooling2D(2, 2), 
        Conv2D(128, (3, 3), activation='relu'),
        MaxPooling2D(2, 2), 
        Flatten(), 
        Dropout(0.5),
        Dense(256, activation='relu'),
        Dense(32, activation='relu'),        
        Dense(3, activation='softmax'),
    ])

    model.compile(optimizer='RMSprop', loss='categorical_crossentropy', metrics=['acc'])

    checkpoint_path = "tmp_checkpoint.ckpt"
    checkpoint = ModelCheckpoint(filepath=checkpoint_path, 
                                save_weights_only=True, 
                                save_best_only=True, 
                                monitor='val_loss', 
                                verbose=1)
    
    model.fit(training_generator, 
              validation_data=(validation_generator),
              epochs=25,
              callbacks=[checkpoint],
              )
    
    model.load_weights(checkpoint_path)

    return model



# Note that you'll need to save your model as a .h5 like this
# This .h5 will be uploaded to the testing infrastructure
# and a score will be returned to you
if __name__ == '__main__':
    model = solution_model()
    model.save("TF3-rps-3.h5")
# Out:
# Found 2016 images belonging to 3 classes.
# Found 504 images belonging to 3 classes.
# Epoch 1/25
# 16/16 [==============================] - 22s 1s/step - loss: 1.1457 - acc: 0.3800 - val_loss: 1.0230 - val_acc: 0.4504
#
# Epoch 00001: val_loss improved from inf to 1.02305, saving model to tmp_checkpoint.ckpt
# Epoch 2/25
# 16/16 [==============================] - 19s 1s/step - loss: 1.0998 - acc: 0.5441 - val_loss: 2.3304 - val_acc: 0.3333
#
# Epoch 00002: val_loss did not improve from 1.02305
# Epoch 3/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.7304 - acc: 0.7416 - val_loss: 0.6397 - val_acc: 0.6746
#
# Epoch 00003: val_loss improved from 1.02305 to 0.63971, saving model to tmp_checkpoint.ckpt
# Epoch 4/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.5304 - acc: 0.8140 - val_loss: 0.5162 - val_acc: 0.8194
#
# Epoch 00004: val_loss improved from 0.63971 to 0.51622, saving model to tmp_checkpoint.ckpt
# Epoch 5/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.2183 - acc: 0.9187 - val_loss: 0.1338 - val_acc: 0.9702
#
# Epoch 00005: val_loss improved from 0.51622 to 0.13384, saving model to tmp_checkpoint.ckpt
# Epoch 6/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.4264 - acc: 0.9023 - val_loss: 0.2271 - val_acc: 0.9107
#
# Epoch 00006: val_loss did not improve from 0.13384
# Epoch 7/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.1572 - acc: 0.9519 - val_loss: 0.3741 - val_acc: 0.8651
#
# Epoch 00007: val_loss did not improve from 0.13384
# Epoch 8/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.0506 - acc: 0.9846 - val_loss: 0.0561 - val_acc: 0.9841
#
# Epoch 00008: val_loss improved from 0.13384 to 0.05607, saving model to tmp_checkpoint.ckpt
# Epoch 9/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.8836 - acc: 0.8795 - val_loss: 0.4315 - val_acc: 0.7004
#
# Epoch 00009: val_loss did not improve from 0.05607
# Epoch 10/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.0252 - acc: 0.9945 - val_loss: 0.0477 - val_acc: 0.9881
#
# Epoch 00010: val_loss improved from 0.05607 to 0.04774, saving model to tmp_checkpoint.ckpt
# Epoch 11/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.0672 - acc: 0.9747 - val_loss: 0.1389 - val_acc: 0.9405
#
# Epoch 00011: val_loss did not improve from 0.04774
# Epoch 12/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.0125 - acc: 0.9960 - val_loss: 0.0371 - val_acc: 0.9901
#
# Epoch 00012: val_loss improved from 0.04774 to 0.03709, saving model to tmp_checkpoint.ckpt
# Epoch 13/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.2380 - acc: 0.9385 - val_loss: 0.4556 - val_acc: 0.8532
#
# Epoch 00013: val_loss did not improve from 0.03709
# Epoch 14/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.0562 - acc: 0.9861 - val_loss: 0.2302 - val_acc: 0.8909
#
# Epoch 00014: val_loss did not improve from 0.03709
# Epoch 15/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.0073 - acc: 0.9985 - val_loss: 0.0521 - val_acc: 0.9821
#
# Epoch 00015: val_loss did not improve from 0.03709
# Epoch 16/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.3409 - acc: 0.9315 - val_loss: 0.2137 - val_acc: 0.8968
#
# Epoch 00016: val_loss did not improve from 0.03709
# Epoch 17/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.0086 - acc: 0.9970 - val_loss: 0.1274 - val_acc: 0.9504
#
# Epoch 00017: val_loss did not improve from 0.03709
# Epoch 18/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.0042 - acc: 0.9990 - val_loss: 0.1552 - val_acc: 0.9643
#
# Epoch 00018: val_loss did not improve from 0.03709
# Epoch 19/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.4607 - acc: 0.9216 - val_loss: 0.2038 - val_acc: 0.9107
#
# Epoch 00019: val_loss did not improve from 0.03709
# Epoch 20/25
# 16/16 [==============================] - 18s 1s/step - loss: 0.0073 - acc: 0.9980 - val_loss: 0.2033 - val_acc: 0.9167
#
# Epoch 00020: val_loss did not improve from 0.03709
# Epoch 21/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.0020 - acc: 0.9995 - val_loss: 0.2166 - val_acc: 0.8929
#
# Epoch 00021: val_loss did not improve from 0.03709
# Epoch 22/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.1420 - acc: 0.9633 - val_loss: 0.0478 - val_acc: 0.9901
#
# Epoch 00022: val_loss did not improve from 0.03709
# Epoch 23/25
# 16/16 [==============================] - 18s 1s/step - loss: 0.0076 - acc: 0.9970 - val_loss: 0.0304 - val_acc: 0.9940
#
# Epoch 00023: val_loss improved from 0.03709 to 0.03045, saving model to tmp_checkpoint.ckpt
# Epoch 24/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.9873 - acc: 0.9246 - val_loss: 0.0333 - val_acc: 0.9901
#
# Epoch 00024: val_loss did not improve from 0.03045
# Epoch 25/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.0090 - acc: 0.9970 - val_loss: 0.0310 - val_acc: 0.9901
#
# Epoch 00025: val_loss did not improve from 0.03045

# %% [markdown]
# #TF3-rps-4-val-loss-0.068

# %%
# ======================================================================
# There are 5 questions in this test with increasing difficulty from 1-5
# Please note that the weight of the grade for the question is relative
# to its difficulty. So your Category 1 question will score much less
# than your Category 5 question.
# ======================================================================
#
# Computer Vision with CNNs
#
# For this task you will build a classifier for Rock-Paper-Scissors 
# based on the rps dataset.
#
# IMPORTANT: Your final layer should be as shown, do not change the
# provided code, or the tests may fail
#
# IMPORTANT: Images will be tested as 150x150 with 3 bytes of color depth
# So ensure that your input layer is designed accordingly, or the tests
# may fail. 
#
# NOTE THAT THIS IS UNLABELLED DATA. 
# You can use the ImageDataGenerator to automatically label it
# and we have provided some starter code.

# =========== 합격 기준 가이드라인 공유 ============= #
# val_loss 기준에 맞춰 주시는 것이 훨씬 더 중요 #
# val_loss 보다 조금 높아도 상관없음. (언저리까지 OK) #
# =================================================== #
# 문제명: Category 3 - rps
# val_loss: 0.0871
# val_acc: 0.97
# =================================================== #
# =================================================== #

import urllib.request
import zipfile
import numpy as np
from IPython.display import Image

import tensorflow as tf
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dropout, Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint

def solution_model():
    url = 'https://storage.googleapis.com/download.tensorflow.org/data/rps.zip'
    urllib.request.urlretrieve(url, 'rps.zip')
    local_zip = 'rps.zip'
    zip_ref = zipfile.ZipFile(local_zip, 'r')
    zip_ref.extractall('tmp/')
    zip_ref.close()


    TRAINING_DIR = "tmp/rps/"
    training_datagen = ImageDataGenerator(
          rescale=1. / 255,
          rotation_range=5,
          width_shift_range=0.05,
          height_shift_range=0.05,
          zoom_range=0.05,
          horizontal_flip=True,
          fill_mode='reflect', 
          validation_split=0.2
        )
    
    training_generator = training_datagen.flow_from_directory(TRAINING_DIR, 
                                                          batch_size=128, 
                                                          target_size=(150, 150), 
                                                          class_mode='categorical', 
                                                          subset='training',
                                                         )

    validation_generator = training_datagen.flow_from_directory(TRAINING_DIR, 
                                                              batch_size=128, 
                                                              target_size=(150, 150), 
                                                              class_mode='categorical',
                                                              subset='validation', 
                                                            )

    model = Sequential([
        # Conv2D, MaxPooling2D 조합으로 층을 쌓습니다. 첫번째 입력층의 input_shape은 (150, 150, 3)으로 지정합니다.
        Conv2D(64, (3, 3), activation='relu', input_shape=(150, 150, 3)),
        MaxPooling2D(2, 2), 
        Conv2D(64, (3, 3), activation='relu'),
        MaxPooling2D(2, 2), 
        Conv2D(128, (3, 3), activation='relu'),
        MaxPooling2D(2, 2), 
        Conv2D(128, (3, 3), activation='relu'),
        MaxPooling2D(2, 2), 
        Flatten(), 
        Dropout(0.5),
        Dense(128, activation='relu'),
        Dense(64, activation='relu'),        
        Dense(3, activation='softmax'),
    ])

    model.compile(optimizer='RMSprop', loss='categorical_crossentropy', metrics=['acc'])

    checkpoint_path = "tmp_checkpoint.ckpt"
    checkpoint = ModelCheckpoint(filepath=checkpoint_path, 
                                save_weights_only=True, 
                                save_best_only=True, 
                                monitor='val_loss', 
                                verbose=1)
    
    model.fit(training_generator, 
              validation_data=(validation_generator),
              epochs=25,
              callbacks=[checkpoint],
              )
    
    model.load_weights(checkpoint_path)

    return model



# Note that you'll need to save your model as a .h5 like this
# This .h5 will be uploaded to the testing infrastructure
# and a score will be returned to you
if __name__ == '__main__':
    model = solution_model()
    model.save("TF3-rps-4.h5")
# Out:
# Found 2016 images belonging to 3 classes.
# Found 504 images belonging to 3 classes.
# Epoch 1/25
# 16/16 [==============================] - 21s 1s/step - loss: 1.1288 - acc: 0.3775 - val_loss: 1.0705 - val_acc: 0.5417
#
# Epoch 00001: val_loss improved from inf to 1.07055, saving model to tmp_checkpoint.ckpt
# Epoch 2/25
# 16/16 [==============================] - 19s 1s/step - loss: 1.1089 - acc: 0.5660 - val_loss: 0.9016 - val_acc: 0.5972
#
# Epoch 00002: val_loss improved from 1.07055 to 0.90158, saving model to tmp_checkpoint.ckpt
# Epoch 3/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.6765 - acc: 0.7391 - val_loss: 0.8034 - val_acc: 0.5258
#
# Epoch 00003: val_loss improved from 0.90158 to 0.80341, saving model to tmp_checkpoint.ckpt
# Epoch 4/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.3997 - acc: 0.8819 - val_loss: 2.8945 - val_acc: 0.3353
#
# Epoch 00004: val_loss did not improve from 0.80341
# Epoch 5/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.3765 - acc: 0.8938 - val_loss: 0.7303 - val_acc: 0.7579
#
# Epoch 00005: val_loss improved from 0.80341 to 0.73034, saving model to tmp_checkpoint.ckpt
# Epoch 6/25
# 16/16 [==============================] - 18s 1s/step - loss: 0.1551 - acc: 0.9439 - val_loss: 0.5458 - val_acc: 0.7857
#
# Epoch 00006: val_loss improved from 0.73034 to 0.54579, saving model to tmp_checkpoint.ckpt
# Epoch 7/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.1778 - acc: 0.9573 - val_loss: 0.7921 - val_acc: 0.6984
#
# Epoch 00007: val_loss did not improve from 0.54579
# Epoch 8/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.0816 - acc: 0.9727 - val_loss: 0.2564 - val_acc: 0.9187
#
# Epoch 00008: val_loss improved from 0.54579 to 0.25637, saving model to tmp_checkpoint.ckpt
# Epoch 9/25
# 16/16 [==============================] - 18s 1s/step - loss: 0.4427 - acc: 0.8700 - val_loss: 0.1437 - val_acc: 0.9544
#
# Epoch 00009: val_loss improved from 0.25637 to 0.14372, saving model to tmp_checkpoint.ckpt
# Epoch 10/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.2403 - acc: 0.9514 - val_loss: 3.4775 - val_acc: 0.5456
#
# Epoch 00010: val_loss did not improve from 0.14372
# Epoch 11/25
# 16/16 [==============================] - 18s 1s/step - loss: 0.2415 - acc: 0.9544 - val_loss: 0.3104 - val_acc: 0.8651
#
# Epoch 00011: val_loss did not improve from 0.14372
# Epoch 12/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.1208 - acc: 0.9613 - val_loss: 0.1886 - val_acc: 0.9206
#
# Epoch 00012: val_loss did not improve from 0.14372
# Epoch 13/25
# 16/16 [==============================] - 18s 1s/step - loss: 0.0147 - acc: 0.9950 - val_loss: 0.4351 - val_acc: 0.8492
#
# Epoch 00013: val_loss did not improve from 0.14372
# Epoch 14/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.0482 - acc: 0.9861 - val_loss: 0.1503 - val_acc: 0.9325
#
# Epoch 00014: val_loss did not improve from 0.14372
# Epoch 15/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.3217 - acc: 0.9415 - val_loss: 0.2846 - val_acc: 0.8532
#
# Epoch 00015: val_loss did not improve from 0.14372
# Epoch 16/25
# 16/16 [==============================] - 18s 1s/step - loss: 0.0118 - acc: 0.9970 - val_loss: 0.1669 - val_acc: 0.9246
#
# Epoch 00016: val_loss did not improve from 0.14372
# Epoch 17/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.0059 - acc: 0.9975 - val_loss: 0.1060 - val_acc: 0.9603
#
# Epoch 00017: val_loss improved from 0.14372 to 0.10602, saving model to tmp_checkpoint.ckpt
# Epoch 18/25
# 16/16 [==============================] - 18s 1s/step - loss: 0.1640 - acc: 0.9573 - val_loss: 0.2277 - val_acc: 0.8948
#
# Epoch 00018: val_loss did not improve from 0.10602
# Epoch 19/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.0102 - acc: 0.9980 - val_loss: 0.1202 - val_acc: 0.9425
#
# Epoch 00019: val_loss did not improve from 0.10602
# Epoch 20/25
# 16/16 [==============================] - 18s 1s/step - loss: 0.0539 - acc: 0.9816 - val_loss: 0.3427 - val_acc: 0.8373
#
# Epoch 00020: val_loss did not improve from 0.10602
# Epoch 21/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.0021 - acc: 0.9995 - val_loss: 0.1722 - val_acc: 0.9345
#
# Epoch 00021: val_loss did not improve from 0.10602
# Epoch 22/25
# 16/16 [==============================] - 18s 1s/step - loss: 0.3130 - acc: 0.9519 - val_loss: 0.1498 - val_acc: 0.9167
#
# Epoch 00022: val_loss did not improve from 0.10602
# Epoch 23/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.0042 - acc: 0.9985 - val_loss: 0.1297 - val_acc: 0.9563
#
# Epoch 00023: val_loss did not improve from 0.10602
# Epoch 24/25
# 16/16 [==============================] - 18s 1s/step - loss: 0.0153 - acc: 0.9970 - val_loss: 0.0764 - val_acc: 0.9663
#
# Epoch 00024: val_loss improved from 0.10602 to 0.07644, saving model to tmp_checkpoint.ckpt
# Epoch 25/25
# 16/16 [==============================] - 18s 1s/step - loss: 0.0109 - acc: 0.9975 - val_loss: 0.0680 - val_acc: 0.9782
#
# Epoch 00025: val_loss improved from 0.07644 to 0.06804, saving model to tmp_checkpoint.ckpt

# %% [markdown]
# #TF3-rps-5-val-loss-0.0773

# %%
# ======================================================================
# There are 5 questions in this test with increasing difficulty from 1-5
# Please note that the weight of the grade for the question is relative
# to its difficulty. So your Category 1 question will score much less
# than your Category 5 question.
# ======================================================================
#
# Computer Vision with CNNs
#
# For this task you will build a classifier for Rock-Paper-Scissors 
# based on the rps dataset.
#
# IMPORTANT: Your final layer should be as shown, do not change the
# provided code, or the tests may fail
#
# IMPORTANT: Images will be tested as 150x150 with 3 bytes of color depth
# So ensure that your input layer is designed accordingly, or the tests
# may fail. 
#
# NOTE THAT THIS IS UNLABELLED DATA. 
# You can use the ImageDataGenerator to automatically label it
# and we have provided some starter code.

# =========== 합격 기준 가이드라인 공유 ============= #
# val_loss 기준에 맞춰 주시는 것이 훨씬 더 중요 #
# val_loss 보다 조금 높아도 상관없음. (언저리까지 OK) #
# =================================================== #
# 문제명: Category 3 - rps
# val_loss: 0.0871
# val_acc: 0.97
# =================================================== #
# =================================================== #

import urllib.request
import zipfile
import numpy as np
from IPython.display import Image

import tensorflow as tf
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dropout, Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint

def solution_model():
    url = 'https://storage.googleapis.com/download.tensorflow.org/data/rps.zip'
    urllib.request.urlretrieve(url, 'rps.zip')
    local_zip = 'rps.zip'
    zip_ref = zipfile.ZipFile(local_zip, 'r')
    zip_ref.extractall('tmp/')
    zip_ref.close()


    TRAINING_DIR = "tmp/rps/"
    training_datagen = ImageDataGenerator(
          rescale=1. / 255,
          rotation_range=5,
          width_shift_range=0.05,
          height_shift_range=0.05,
          zoom_range=0.05,
          horizontal_flip=True,
          fill_mode='reflect', 
          validation_split=0.2
        )
    
    training_generator = training_datagen.flow_from_directory(TRAINING_DIR, 
                                                          batch_size=128, 
                                                          target_size=(150, 150), 
                                                          class_mode='categorical', 
                                                          subset='training',
                                                         )

    validation_generator = training_datagen.flow_from_directory(TRAINING_DIR, 
                                                              batch_size=128, 
                                                              target_size=(150, 150), 
                                                              class_mode='categorical',
                                                              subset='validation', 
                                                            )

    model = Sequential([
        # Conv2D, MaxPooling2D 조합으로 층을 쌓습니다. 첫번째 입력층의 input_shape은 (150, 150, 3)으로 지정합니다.
        Conv2D(64, (3, 3), activation='relu', input_shape=(150, 150, 3)),
        MaxPooling2D(2, 2), 
        Conv2D(64, (3, 3), activation='relu'),
        MaxPooling2D(2, 2), 
        Conv2D(128, (3, 3), activation='relu'),
        MaxPooling2D(2, 2), 
        Conv2D(128, (3, 3), activation='relu'),
        MaxPooling2D(2, 2), 
        Flatten(), 
        Dropout(0.5),
        Dense(512, activation='relu'),    
        Dense(3, activation='softmax'),
    ])

    model.compile(optimizer='RMSprop', loss='categorical_crossentropy', metrics=['acc'])

    checkpoint_path = "tmp_checkpoint.ckpt"
    checkpoint = ModelCheckpoint(filepath=checkpoint_path, 
                                save_weights_only=True, 
                                save_best_only=True, 
                                monitor='val_loss', 
                                verbose=1)
    
    model.fit(training_generator, 
              validation_data=(validation_generator),
              epochs=25,
              callbacks=[checkpoint],
              )
    
    model.load_weights(checkpoint_path)

    return model



# Note that you'll need to save your model as a .h5 like this
# This .h5 will be uploaded to the testing infrastructure
# and a score will be returned to you
if __name__ == '__main__':
    model = solution_model()
    model.save("TF3-rps-5.h5")
# Out:
# Found 2016 images belonging to 3 classes.
# Found 504 images belonging to 3 classes.
# Epoch 1/25
# 16/16 [==============================] - 21s 1s/step - loss: 1.4248 - acc: 0.3686 - val_loss: 1.1075 - val_acc: 0.4147
#
# Epoch 00001: val_loss improved from inf to 1.10749, saving model to tmp_checkpoint.ckpt
# Epoch 2/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.8896 - acc: 0.5878 - val_loss: 1.0318 - val_acc: 0.5893
#
# Epoch 00002: val_loss improved from 1.10749 to 1.03181, saving model to tmp_checkpoint.ckpt
# Epoch 3/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.6194 - acc: 0.8011 - val_loss: 1.1600 - val_acc: 0.3988
#
# Epoch 00003: val_loss did not improve from 1.03181
# Epoch 4/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.5172 - acc: 0.7986 - val_loss: 0.6625 - val_acc: 0.5635
#
# Epoch 00004: val_loss improved from 1.03181 to 0.66246, saving model to tmp_checkpoint.ckpt
# Epoch 5/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.2620 - acc: 0.9157 - val_loss: 0.5544 - val_acc: 0.8313
#
# Epoch 00005: val_loss improved from 0.66246 to 0.55440, saving model to tmp_checkpoint.ckpt
# Epoch 6/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.2022 - acc: 0.9286 - val_loss: 0.4374 - val_acc: 0.8730
#
# Epoch 00006: val_loss improved from 0.55440 to 0.43739, saving model to tmp_checkpoint.ckpt
# Epoch 7/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.2227 - acc: 0.9350 - val_loss: 0.1619 - val_acc: 0.9226
#
# Epoch 00007: val_loss improved from 0.43739 to 0.16191, saving model to tmp_checkpoint.ckpt
# Epoch 8/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.0369 - acc: 0.9871 - val_loss: 0.1413 - val_acc: 0.9345
#
# Epoch 00008: val_loss improved from 0.16191 to 0.14125, saving model to tmp_checkpoint.ckpt
# Epoch 9/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.4346 - acc: 0.9142 - val_loss: 0.3574 - val_acc: 0.8810
#
# Epoch 00009: val_loss did not improve from 0.14125
# Epoch 10/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.0686 - acc: 0.9802 - val_loss: 0.6124 - val_acc: 0.7500
#
# Epoch 00010: val_loss did not improve from 0.14125
# Epoch 11/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.0383 - acc: 0.9876 - val_loss: 0.5243 - val_acc: 0.7897
#
# Epoch 00011: val_loss did not improve from 0.14125
# Epoch 12/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.1704 - acc: 0.9499 - val_loss: 0.1032 - val_acc: 0.9563
#
# Epoch 00012: val_loss improved from 0.14125 to 0.10319, saving model to tmp_checkpoint.ckpt
# Epoch 13/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.0535 - acc: 0.9856 - val_loss: 2.5205 - val_acc: 0.6151
#
# Epoch 00013: val_loss did not improve from 0.10319
# Epoch 14/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.4873 - acc: 0.9311 - val_loss: 0.2311 - val_acc: 0.8948
#
# Epoch 00014: val_loss did not improve from 0.10319
# Epoch 15/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.0136 - acc: 0.9955 - val_loss: 0.2553 - val_acc: 0.8810
#
# Epoch 00015: val_loss did not improve from 0.10319
# Epoch 16/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.3204 - acc: 0.9459 - val_loss: 0.4344 - val_acc: 0.7897
#
# Epoch 00016: val_loss did not improve from 0.10319
# Epoch 17/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.0663 - acc: 0.9816 - val_loss: 0.1900 - val_acc: 0.9107
#
# Epoch 00017: val_loss did not improve from 0.10319
# Epoch 18/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.0126 - acc: 0.9955 - val_loss: 0.2772 - val_acc: 0.9008
#
# Epoch 00018: val_loss did not improve from 0.10319
# Epoch 19/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.0020 - acc: 0.9990 - val_loss: 0.6650 - val_acc: 0.7758
#
# Epoch 00019: val_loss did not improve from 0.10319
# Epoch 20/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.2664 - acc: 0.9554 - val_loss: 0.2390 - val_acc: 0.9067
#
# Epoch 00020: val_loss did not improve from 0.10319
# Epoch 21/25
# 16/16 [==============================] - 18s 1s/step - loss: 0.0107 - acc: 0.9975 - val_loss: 0.1473 - val_acc: 0.9444
#
# Epoch 00021: val_loss did not improve from 0.10319
# Epoch 22/25
# 16/16 [==============================] - 18s 1s/step - loss: 0.0067 - acc: 0.9975 - val_loss: 0.1127 - val_acc: 0.9524
#
# Epoch 00022: val_loss did not improve from 0.10319
# Epoch 23/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.1283 - acc: 0.9633 - val_loss: 0.0773 - val_acc: 0.9821
#
# Epoch 00023: val_loss improved from 0.10319 to 0.07735, saving model to tmp_checkpoint.ckpt
# Epoch 24/25
# 16/16 [==============================] - 19s 1s/step - loss: 0.0061 - acc: 0.9995 - val_loss: 0.1038 - val_acc: 0.9563
#
# Epoch 00024: val_loss did not improve from 0.07735
# Epoch 25/25
# 16/16 [==============================] - 18s 1s/step - loss: 9.9467e-04 - acc: 1.0000 - val_loss: 0.1044 - val_acc: 0.9722
#
# Epoch 00025: val_loss did not improve from 0.07735
