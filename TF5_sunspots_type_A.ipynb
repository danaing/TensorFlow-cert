# %% [markdown]
# <a href="https://colab.research.google.com/github/danaing/TensorFlow-cert/blob/main/TF5_sunspots_type_A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ======================================================================
# There are 5 questions in this test with increasing difficulty from 1-5
# Please note that the weight of the grade for the question is relative
# to its difficulty. So your Category 1 question will score much less
# than your Category 5 question.
# ======================================================================
#
# Sequence Modelling Question.
#
# For this task you will need to train a neural network
# to predict sunspot activity using the Sunspots.csv
# provided. Your neural network is expected to have an MAE
# of at least 20, with top marks going to one with an MAE
# of around 15. At the bottom is provided some testing
# code should you want to check before uploading which measures
# the MAE for you. Strongly recommend you test your model with
# this to be able to see how it performs.

# =========== 합격 기준 가이드라인 공유 ============= #
# val_loss 기준에 맞춰 주시는 것이 훨씬 더 중요 #
# val_loss 보다 조금 높아도 상관없음. (언저리까지 OK) #
# =================================================== #
# 문제명: Category 5 - sunspots type A (with Lambda)
# val_loss: 상관없음
# val_mae: 13.50
# =================================================== #
# =================================================== #


import csv
import tensorflow as tf
import numpy as np
import urllib

from tensorflow.keras.layers import Dense, LSTM, Lambda, Conv1D
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.losses import Huber


# DO NOT CHANGE THIS CODE
def windowed_dataset(series, window_size, batch_size, shuffle_buffer):
    series = tf.expand_dims(series, axis=-1)
    ds = tf.data.Dataset.from_tensor_slices(series)
    ds = ds.window(window_size + 1, shift=1, drop_remainder=True)
    ds = ds.flat_map(lambda w: w.batch(window_size + 1))
    ds = ds.shuffle(shuffle_buffer)
    ds = ds.map(lambda w: (w[:-1], w[1:]))
    return ds.batch(batch_size).prefetch(1)


def solution_model():
    url = 'https://storage.googleapis.com/download.tensorflow.org/data/Sunspots.csv'
    urllib.request.urlretrieve(url, 'sunspots.csv')

	# Your data should be loaded into 2 Python lists called time_step
	# and sunspots. They are decleared here.
    time_step = []
    sunspots = []

    with open('sunspots.csv') as csvfile:
      reader = csv.reader(csvfile, delimiter=',')
      next(reader)
      for row in reader:
        sunspots.append(float(row[2]))
        time_step.append(int(row[0]))

	# You should use numpy to create 
	# - your series from the list of sunspots
	# - your time details from the list of time steps
    series = np.array(sunspots)
    time = np.array(time_step)

	# You should split the dataset into training and validation splits
	# At time 3000. So everything up to 3000 is training, and everything
	# after 3000 is validation. Write the code below to achieve that.
    split_time = 3000
    time_train = time[:split_time]
    time_valid = time[split_time:]

    x_train = series[:split_time]
    x_valid = series[split_time:]

    # DO NOT CHANGE THIS CODE
    window_size = 30
    batch_size = 32
    shuffle_buffer_size = 1000


    tf.keras.backend.clear_session()
    # You can use any random seed you want. We use 51. :)
    tf.random.set_seed(51)
    np.random.seed(51)

    train_set = windowed_dataset(x_train, 
                             window_size=window_size, 
                             batch_size=batch_size,
                             shuffle_buffer=shuffle_buffer_size)

    validation_set = windowed_dataset(x_valid, 
                                      window_size=window_size,
                                      batch_size=batch_size,
                                      shuffle_buffer=shuffle_buffer_size)


    model = Sequential([
        tf.keras.layers.Conv1D(60, kernel_size=5,
                            padding="causal",
                            activation="relu",
                            input_shape=[None, 1]),
        tf.keras.layers.LSTM(60, return_sequences=True),
        tf.keras.layers.LSTM(60, return_sequences=True),
        tf.keras.layers.Dense(30, activation="relu"),
        tf.keras.layers.Dense(10, activation="relu"),
        tf.keras.layers.Dense(1),
      # The data is not normalized, so this lambda layer helps
      # keep the MAE in line with expectations. Do not modify.
        tf.keras.layers.Lambda(lambda x: x * 400)
    ])

    optimizer = SGD(learning_rate=1e-5, momentum=0.9)
    loss= Huber()
    model.compile(loss=loss,
                  optimizer=optimizer,
                  metrics=["mae"])
    
    checkpoint_path = 'tmp_checkpoint.ckpt'
    checkpoint = ModelCheckpoint(checkpoint_path, 
                                save_weights_only=True, 
                                save_best_only=True, 
                                monitor='val_mae',
                                verbose=1)
    epochs=100
    history = model.fit(train_set, 
                        validation_data=(validation_set), 
                        epochs=epochs, 
                        callbacks=[checkpoint],
                      )
    model.load_weights(checkpoint_path)

    # YOUR CODE HERE TO COMPILE AND TRAIN THE MODEL
    return model


# Note that you'll need to save your model as a .h5 like this
# This .h5 will be uploaded to the testing infrastructure
# and a score will be returned to you
if __name__ == '__main__':
    model = solution_model()
    model.save("TF5-sunspots-type-A.h5")



# THIS CODE IS USED IN THE TESTER FOR FORECASTING. IF YOU WANT TO TEST YOUR MODEL
# BEFORE UPLOADING YOU CAN DO IT WITH THIS
#def model_forecast(model, series, window_size):
#    ds = tf.data.Dataset.from_tensor_slices(series)
#    ds = ds.window(window_size, shift=1, drop_remainder=True)
#    ds = ds.flat_map(lambda w: w.batch(window_size))
#    ds = ds.batch(32).prefetch(1)
#    forecast = model.predict(ds)
#    return forecast


#window_size = # YOUR CODE HERE
#rnn_forecast = model_forecast(model, series[..., np.newaxis], window_size)
#rnn_forecast = rnn_forecast[split_time - window_size:-1, -1, 0]

#result = tf.keras.metrics.mean_absolute_error(x_valid, rnn_forecast).numpy()

## WE EXPECT AN MAE OF 15 or less for the maximum score
#score = ceil(20 - result)
#if score > 5:
#    score = 5

#print(score)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# Epoch 1/100
# 93/93 [==============================] - 19s 16ms/step - loss: 30.2859 - mae: 30.7811 - val_loss: 20.7062 - val_mae: 21.1999
#
# Epoch 00001: val_mae improved from inf to 21.19993, saving model to tmp_checkpoint.ckpt
# Epoch 2/100
# 93/93 [==============================] - 1s 7ms/step - loss: 22.1984 - mae: 22.6923 - val_loss: 18.7214 - val_mae: 19.2160
#
# Epoch 00002: val_mae improved from 21.19993 to 19.21603, saving model to tmp_checkpoint.ckpt
# Epoch 3/100
# 93/93 [==============================] - 1s 7ms/step - loss: 20.0045 - mae: 20.4975 - val_loss: 16.4243 - val_mae: 16.9148
#
# Epoch 00003: val_mae improved from 19.21603 to 16.91478, saving model to tmp_checkpoint.ckpt
# Epoch 4/100
# 93/93 [==============================] - 1s 7ms/step - loss: 19.6805 - mae: 20.1732 - val_loss: 16.5965 - val_mae: 17.0899
#
# Epoch 00004: val_mae did not improve from 16.91478
# Epoch 5/100
# 93/93 [==============================] - 1s 7ms/step - loss: 19.0272 - mae: 19.5196 - val_loss: 14.2244 - val_mae: 14.7144
#
# Epoch 00005: val_mae improved from 16.91478 to 14.71436, saving model to tmp_checkpoint.ckpt
# Epoch 6/100
# 93/93 [==============================] - 1s 7ms/step - loss: 18.3701 - mae: 18.8622 - val_loss: 13.9460 - val_mae: 14.4369
#
# Epoch 00006: val_mae improved from 14.71436 to 14.43688, saving model to tmp_checkpoint.ckpt
# Epoch 7/100
# 93/93 [==============================] - 1s 7ms/step - loss: 18.5887 - mae: 19.0809 - val_loss: 15.0762 - val_mae: 15.5659
#
# Epoch 00007: val_mae did not improve from 14.43688
# Epoch 8/100
# 93/93 [==============================] - 1s 7ms/step - loss: 18.5110 - mae: 19.0031 - val_loss: 14.1058 - val_mae: 14.5968
#
# Epoch 00008: val_mae did not improve from 14.43688
# Epoch 9/100
# 93/93 [==============================] - 1s 7ms/step - loss: 18.0659 - mae: 18.5577 - val_loss: 13.8953 - val_mae: 14.3867
#
# Epoch 00009: val_mae improved from 14.43688 to 14.38673, saving model to tmp_checkpoint.ckpt
# Epoch 10/100
# 93/93 [==============================] - 1s 7ms/step - loss: 17.8619 - mae: 18.3537 - val_loss: 13.7248 - val_mae: 14.2128
#
# Epoch 00010: val_mae improved from 14.38673 to 14.21276, saving model to tmp_checkpoint.ckpt
# Epoch 11/100
# 93/93 [==============================] - 1s 7ms/step - loss: 17.8999 - mae: 18.3913 - val_loss: 13.6044 - val_mae: 14.0920
#
# Epoch 00011: val_mae improved from 14.21276 to 14.09196, saving model to tmp_checkpoint.ckpt
# Epoch 12/100
# 93/93 [==============================] - 1s 7ms/step - loss: 17.7940 - mae: 18.2857 - val_loss: 13.9641 - val_mae: 14.4535
#
# Epoch 00012: val_mae did not improve from 14.09196
# Epoch 13/100
# 93/93 [==============================] - 1s 7ms/step - loss: 17.8621 - mae: 18.3538 - val_loss: 14.4207 - val_mae: 14.9115
#
# Epoch 00013: val_mae did not improve from 14.09196
# Epoch 14/100
# 93/93 [==============================] - 1s 7ms/step - loss: 17.8692 - mae: 18.3607 - val_loss: 13.7072 - val_mae: 14.1965
#
# Epoch 00014: val_mae did not improve from 14.09196
# Epoch 15/100
# 93/93 [==============================] - 1s 7ms/step - loss: 17.5688 - mae: 18.0603 - val_loss: 13.4684 - val_mae: 13.9577
#
# Epoch 00015: val_mae improved from 14.09196 to 13.95771, saving model to tmp_checkpoint.ckpt
# Epoch 16/100
# 93/93 [==============================] - 1s 7ms/step - loss: 17.5936 - mae: 18.0850 - val_loss: 13.4910 - val_mae: 13.9805
#
# Epoch 00016: val_mae did not improve from 13.95771
# Epoch 17/100
# 93/93 [==============================] - 1s 7ms/step - loss: 17.5042 - mae: 17.9956 - val_loss: 13.7913 - val_mae: 14.2817
#
# Epoch 00017: val_mae did not improve from 13.95771
# Epoch 18/100
# 93/93 [==============================] - 1s 7ms/step - loss: 17.4067 - mae: 17.8978 - val_loss: 15.9842 - val_mae: 16.4754
#
# Epoch 00018: val_mae did not improve from 13.95771
# Epoch 19/100
# 93/93 [==============================] - 1s 7ms/step - loss: 17.2154 - mae: 17.7062 - val_loss: 13.4289 - val_mae: 13.9168
#
# Epoch 00019: val_mae improved from 13.95771 to 13.91682, saving model to tmp_checkpoint.ckpt
# Epoch 20/100
# 93/93 [==============================] - 1s 7ms/step - loss: 17.5413 - mae: 18.0321 - val_loss: 13.6670 - val_mae: 14.1564
#
# Epoch 00020: val_mae did not improve from 13.91682
# Epoch 21/100
# 93/93 [==============================] - 1s 7ms/step - loss: 17.2550 - mae: 17.7457 - val_loss: 13.5182 - val_mae: 14.0080
#
# Epoch 00021: val_mae did not improve from 13.91682
# Epoch 22/100
# 93/93 [==============================] - 1s 7ms/step - loss: 17.3360 - mae: 17.8266 - val_loss: 15.1947 - val_mae: 15.6848
#
# Epoch 00022: val_mae did not improve from 13.91682
# Epoch 23/100
# 93/93 [==============================] - 1s 7ms/step - loss: 17.1293 - mae: 17.6199 - val_loss: 14.1201 - val_mae: 14.6106
#
# Epoch 00023: val_mae did not improve from 13.91682
# Epoch 24/100
# 93/93 [==============================] - 1s 7ms/step - loss: 17.2055 - mae: 17.6961 - val_loss: 13.7465 - val_mae: 14.2360
#
# Epoch 00024: val_mae did not improve from 13.91682
# Epoch 25/100
# 93/93 [==============================] - 1s 7ms/step - loss: 17.3048 - mae: 17.7955 - val_loss: 14.5229 - val_mae: 15.0132
#
# Epoch 00025: val_mae did not improve from 13.91682
# Epoch 26/100
# 93/93 [==============================] - 1s 7ms/step - loss: 17.1261 - mae: 17.6169 - val_loss: 13.3777 - val_mae: 13.8672
#
# Epoch 00026: val_mae improved from 13.91682 to 13.86718, saving model to tmp_checkpoint.ckpt
# Epoch 27/100
# 93/93 [==============================] - 1s 7ms/step - loss: 17.6189 - mae: 18.1101 - val_loss: 13.3247 - val_mae: 13.8159
#
# Epoch 00027: val_mae improved from 13.86718 to 13.81590, saving model to tmp_checkpoint.ckpt
# Epoch 28/100
# 93/93 [==============================] - 1s 7ms/step - loss: 16.9911 - mae: 17.4817 - val_loss: 13.3087 - val_mae: 13.7980
#
# Epoch 00028: val_mae improved from 13.81590 to 13.79803, saving model to tmp_checkpoint.ckpt
# Epoch 29/100
# 93/93 [==============================] - 1s 7ms/step - loss: 17.0630 - mae: 17.5538 - val_loss: 13.5152 - val_mae: 14.0023
#
# Epoch 00029: val_mae did not improve from 13.79803
# Epoch 30/100
# 93/93 [==============================] - 1s 7ms/step - loss: 16.8819 - mae: 17.3720 - val_loss: 13.4539 - val_mae: 13.9427
#
# Epoch 00030: val_mae did not improve from 13.79803
# Epoch 31/100
# 93/93 [==============================] - 1s 7ms/step - loss: 16.9214 - mae: 17.4114 - val_loss: 13.8390 - val_mae: 14.3283
#
# Epoch 00031: val_mae did not improve from 13.79803
# Epoch 32/100
# 93/93 [==============================] - 1s 7ms/step - loss: 17.1428 - mae: 17.6336 - val_loss: 13.5012 - val_mae: 13.9896
#
# Epoch 00032: val_mae did not improve from 13.79803
# Epoch 33/100
# 93/93 [==============================] - 1s 7ms/step - loss: 16.9799 - mae: 17.4706 - val_loss: 14.0350 - val_mae: 14.5244
#
# Epoch 00033: val_mae did not improve from 13.79803
# Epoch 34/100
# 93/93 [==============================] - 1s 7ms/step - loss: 16.9111 - mae: 17.4016 - val_loss: 13.4007 - val_mae: 13.8903
#
# Epoch 00034: val_mae did not improve from 13.79803
# Epoch 35/100
# 93/93 [==============================] - 1s 7ms/step - loss: 16.8676 - mae: 17.3577 - val_loss: 13.5300 - val_mae: 14.0190
#
# Epoch 00035: val_mae did not improve from 13.79803
# Epoch 36/100
# 93/93 [==============================] - 1s 7ms/step - loss: 17.0274 - mae: 17.5180 - val_loss: 13.2958 - val_mae: 13.7872
#
# Epoch 00036: val_mae improved from 13.79803 to 13.78723, saving model to tmp_checkpoint.ckpt
# Epoch 37/100
# 93/93 [==============================] - 1s 7ms/step - loss: 16.7234 - mae: 17.2135 - val_loss: 13.3305 - val_mae: 13.8194
#
# Epoch 00037: val_mae did not improve from 13.78723
# Epoch 38/100
# 93/93 [==============================] - 1s 7ms/step - loss: 16.8778 - mae: 17.3681 - val_loss: 13.5804 - val_mae: 14.0713
#
# Epoch 00038: val_mae did not improve from 13.78723
# Epoch 39/100
# 93/93 [==============================] - 1s 7ms/step - loss: 16.9100 - mae: 17.4006 - val_loss: 13.6451 - val_mae: 14.1358
#
# Epoch 00039: val_mae did not improve from 13.78723
# Epoch 40/100
# 93/93 [==============================] - 1s 7ms/step - loss: 16.8136 - mae: 17.3038 - val_loss: 13.2969 - val_mae: 13.7848
#
# Epoch 00040: val_mae improved from 13.78723 to 13.78479, saving model to tmp_checkpoint.ckpt
# Epoch 41/100
# 93/93 [==============================] - 1s 7ms/step - loss: 16.6875 - mae: 17.1775 - val_loss: 13.4533 - val_mae: 13.9432
#
# Epoch 00041: val_mae did not improve from 13.78479
# Epoch 42/100
# 93/93 [==============================] - 1s 7ms/step - loss: 16.7487 - mae: 17.2390 - val_loss: 13.3743 - val_mae: 13.8636
#
# Epoch 00042: val_mae did not improve from 13.78479
# Epoch 43/100
# 93/93 [==============================] - 1s 7ms/step - loss: 16.9159 - mae: 17.4065 - val_loss: 14.8776 - val_mae: 15.3691
#
# Epoch 00043: val_mae did not improve from 13.78479
# Epoch 44/100
# 93/93 [==============================] - 1s 7ms/step - loss: 16.7624 - mae: 17.2525 - val_loss: 13.3543 - val_mae: 13.8456
#
# Epoch 00044: val_mae did not improve from 13.78479
# Epoch 45/100
# 93/93 [==============================] - 1s 7ms/step - loss: 16.6440 - mae: 17.1338 - val_loss: 13.2920 - val_mae: 13.7822
#
# Epoch 00045: val_mae improved from 13.78479 to 13.78222, saving model to tmp_checkpoint.ckpt
# Epoch 46/100
# 93/93 [==============================] - 1s 7ms/step - loss: 16.8151 - mae: 17.3053 - val_loss: 13.4613 - val_mae: 13.9496
#
# Epoch 00046: val_mae did not improve from 13.78222
# Epoch 47/100
# 93/93 [==============================] - 1s 7ms/step - loss: 16.7556 - mae: 17.2459 - val_loss: 13.7130 - val_mae: 14.2016
#
# Epoch 00047: val_mae did not improve from 13.78222
# Epoch 48/100
# 93/93 [==============================] - 1s 7ms/step - loss: 16.7049 - mae: 17.1949 - val_loss: 13.5517 - val_mae: 14.0403
#
# Epoch 00048: val_mae did not improve from 13.78222
# Epoch 49/100
# 93/93 [==============================] - 1s 7ms/step - loss: 16.5384 - mae: 17.0286 - val_loss: 13.5044 - val_mae: 13.9959
#
# Epoch 00049: val_mae did not improve from 13.78222
# Epoch 50/100
# 93/93 [==============================] - 1s 7ms/step - loss: 16.5418 - mae: 17.0315 - val_loss: 13.4624 - val_mae: 13.9504
#
# Epoch 00050: val_mae did not improve from 13.78222
# Epoch 51/100
# 93/93 [==============================] - 1s 7ms/step - loss: 16.6568 - mae: 17.1468 - val_loss: 13.7846 - val_mae: 14.2726
#
# Epoch 00051: val_mae did not improve from 13.78222
# Epoch 52/100
# 93/93 [==============================] - 1s 7ms/step - loss: 16.8051 - mae: 17.2950 - val_loss: 13.8569 - val_mae: 14.3442
#
# Epoch 00052: val_mae did not improve from 13.78222
# Epoch 53/100
# 93/93 [==============================] - 1s 7ms/step - loss: 16.8232 - mae: 17.3138 - val_loss: 13.6898 - val_mae: 14.1812
#
# Epoch 00053: val_mae did not improve from 13.78222
# Epoch 54/100
# 93/93 [==============================] - 1s 7ms/step - loss: 16.4818 - mae: 16.9713 - val_loss: 13.7241 - val_mae: 14.2134
#
# Epoch 00054: val_mae did not improve from 13.78222
# Epoch 55/100
# 93/93 [==============================] - 1s 7ms/step - loss: 16.5363 - mae: 17.0260 - val_loss: 13.6643 - val_mae: 14.1530
#
# Epoch 00055: val_mae did not improve from 13.78222
# Epoch 56/100
# 93/93 [==============================] - 1s 7ms/step - loss: 16.5715 - mae: 17.0614 - val_loss: 13.7594 - val_mae: 14.2500
#
# Epoch 00056: val_mae did not improve from 13.78222
# Epoch 57/100
# 93/93 [==============================] - 1s 7ms/step - loss: 16.4407 - mae: 16.9303 - val_loss: 13.7628 - val_mae: 14.2516
#
# Epoch 00057: val_mae did not improve from 13.78222
# Epoch 58/100
# 93/93 [==============================] - 1s 7ms/step - loss: 16.7643 - mae: 17.2546 - val_loss: 13.5402 - val_mae: 14.0307
#
# Epoch 00058: val_mae did not improve from 13.78222
# Epoch 59/100
# 93/93 [==============================] - 1s 7ms/step - loss: 16.5271 - mae: 17.0177 - val_loss: 13.7529 - val_mae: 14.2435
#
# Epoch 00059: val_mae did not improve from 13.78222
# Epoch 60/100
# 93/93 [==============================] - 1s 7ms/step - loss: 16.4342 - mae: 16.9240 - val_loss: 13.8894 - val_mae: 14.3795
#
# Epoch 00060: val_mae did not improve from 13.78222
# Epoch 61/100
# 93/93 [==============================] - 1s 7ms/step - loss: 16.4256 - mae: 16.9156 - val_loss: 14.3592 - val_mae: 14.8503
#
# Epoch 00061: val_mae did not improve from 13.78222
# Epoch 62/100
# 93/93 [==============================] - 1s 7ms/step - loss: 16.4336 - mae: 16.9238 - val_loss: 13.5975 - val_mae: 14.0883
#
# Epoch 00062: val_mae did not improve from 13.78222
# Epoch 63/100
# 93/93 [==============================] - 1s 7ms/step - loss: 16.3870 - mae: 16.8770 - val_loss: 13.6662 - val_mae: 14.1582
#
# Epoch 00063: val_mae did not improve from 13.78222
# Epoch 64/100
# 93/93 [==============================] - 1s 7ms/step - loss: 16.3769 - mae: 16.8668 - val_loss: 13.9025 - val_mae: 14.3926
#
# Epoch 00064: val_mae did not improve from 13.78222
# Epoch 65/100
# 93/93 [==============================] - 1s 7ms/step - loss: 16.4593 - mae: 16.9494 - val_loss: 14.2027 - val_mae: 14.6935
#
# Epoch 00065: val_mae did not improve from 13.78222
# Epoch 66/100
# 93/93 [==============================] - 1s 7ms/step - loss: 16.6034 - mae: 17.0937 - val_loss: 13.4925 - val_mae: 13.9819
#
# Epoch 00066: val_mae did not improve from 13.78222
# Epoch 67/100
# 93/93 [==============================] - 1s 7ms/step - loss: 16.6647 - mae: 17.1552 - val_loss: 13.7922 - val_mae: 14.2819
#
# Epoch 00067: val_mae did not improve from 13.78222
# Epoch 68/100
# 93/93 [==============================] - 1s 7ms/step - loss: 16.6322 - mae: 17.1223 - val_loss: 14.4575 - val_mae: 14.9460
#
# Epoch 00068: val_mae did not improve from 13.78222
# Epoch 69/100
# 93/93 [==============================] - 1s 7ms/step - loss: 16.3434 - mae: 16.8335 - val_loss: 14.1049 - val_mae: 14.5961
#
# Epoch 00069: val_mae did not improve from 13.78222
# Epoch 70/100
# 93/93 [==============================] - 1s 7ms/step - loss: 16.3323 - mae: 16.8225 - val_loss: 13.4916 - val_mae: 13.9808
#
# Epoch 00070: val_mae did not improve from 13.78222
# Epoch 71/100
# 93/93 [==============================] - 1s 7ms/step - loss: 16.2519 - mae: 16.7420 - val_loss: 13.8371 - val_mae: 14.3265
#
# Epoch 00071: val_mae did not improve from 13.78222
# Epoch 72/100
# 93/93 [==============================] - 1s 7ms/step - loss: 16.4252 - mae: 16.9154 - val_loss: 13.6747 - val_mae: 14.1656
#
# Epoch 00072: val_mae did not improve from 13.78222
# Epoch 73/100
# 93/93 [==============================] - 1s 7ms/step - loss: 16.2360 - mae: 16.7257 - val_loss: 14.4463 - val_mae: 14.9367
#
# Epoch 00073: val_mae did not improve from 13.78222
# Epoch 74/100
# 93/93 [==============================] - 1s 7ms/step - loss: 16.2958 - mae: 16.7855 - val_loss: 13.6791 - val_mae: 14.1711
#
# Epoch 00074: val_mae did not improve from 13.78222
# Epoch 75/100
# 93/93 [==============================] - 1s 7ms/step - loss: 16.2234 - mae: 16.7131 - val_loss: 13.7593 - val_mae: 14.2500
#
# Epoch 00075: val_mae did not improve from 13.78222
# Epoch 76/100
# 93/93 [==============================] - 1s 7ms/step - loss: 16.1176 - mae: 16.6069 - val_loss: 14.0009 - val_mae: 14.4910
#
# Epoch 00076: val_mae did not improve from 13.78222
# Epoch 77/100
# 93/93 [==============================] - 1s 7ms/step - loss: 16.2560 - mae: 16.7460 - val_loss: 13.7402 - val_mae: 14.2303
#
# Epoch 00077: val_mae did not improve from 13.78222
# Epoch 78/100
# 93/93 [==============================] - 1s 7ms/step - loss: 16.4407 - mae: 16.9311 - val_loss: 13.8868 - val_mae: 14.3781
#
# Epoch 00078: val_mae did not improve from 13.78222
# Epoch 79/100
# 93/93 [==============================] - 1s 7ms/step - loss: 16.2258 - mae: 16.7157 - val_loss: 13.9392 - val_mae: 14.4295
#
# Epoch 00079: val_mae did not improve from 13.78222
# Epoch 80/100
# 93/93 [==============================] - 1s 7ms/step - loss: 16.1149 - mae: 16.6046 - val_loss: 14.5425 - val_mae: 15.0321
#
# Epoch 00080: val_mae did not improve from 13.78222
# Epoch 81/100
# 93/93 [==============================] - 1s 7ms/step - loss: 16.1691 - mae: 16.6586 - val_loss: 13.6988 - val_mae: 14.1883
#
# Epoch 00081: val_mae did not improve from 13.78222
# Epoch 82/100
# 93/93 [==============================] - 1s 7ms/step - loss: 16.0437 - mae: 16.5330 - val_loss: 15.2478 - val_mae: 15.7389
#
# Epoch 00082: val_mae did not improve from 13.78222
# Epoch 83/100
# 93/93 [==============================] - 1s 7ms/step - loss: 16.4159 - mae: 16.9062 - val_loss: 14.2413 - val_mae: 14.7326
#
# Epoch 00083: val_mae did not improve from 13.78222
# Epoch 84/100
# 93/93 [==============================] - 1s 7ms/step - loss: 16.2505 - mae: 16.7406 - val_loss: 13.9623 - val_mae: 14.4521
#
# Epoch 00084: val_mae did not improve from 13.78222
# Epoch 85/100
# 93/93 [==============================] - 1s 7ms/step - loss: 16.0525 - mae: 16.5418 - val_loss: 14.0269 - val_mae: 14.5187
#
# Epoch 00085: val_mae did not improve from 13.78222
# Epoch 86/100
# 93/93 [==============================] - 1s 7ms/step - loss: 16.1373 - mae: 16.6266 - val_loss: 15.3781 - val_mae: 15.8691
#
# Epoch 00086: val_mae did not improve from 13.78222
# Epoch 87/100
# 93/93 [==============================] - 1s 7ms/step - loss: 16.0769 - mae: 16.5667 - val_loss: 14.4633 - val_mae: 14.9546
#
# Epoch 00087: val_mae did not improve from 13.78222
# Epoch 88/100
# 93/93 [==============================] - 1s 7ms/step - loss: 16.0725 - mae: 16.5618 - val_loss: 14.1165 - val_mae: 14.6086
#
# Epoch 00088: val_mae did not improve from 13.78222
# Epoch 89/100
# 93/93 [==============================] - 1s 7ms/step - loss: 16.1704 - mae: 16.6604 - val_loss: 14.0944 - val_mae: 14.5839
#
# Epoch 00089: val_mae did not improve from 13.78222
# Epoch 90/100
# 93/93 [==============================] - 1s 7ms/step - loss: 16.0639 - mae: 16.5539 - val_loss: 15.3202 - val_mae: 15.8130
#
# Epoch 00090: val_mae did not improve from 13.78222
# Epoch 91/100
# 93/93 [==============================] - 1s 7ms/step - loss: 16.0445 - mae: 16.5340 - val_loss: 14.1065 - val_mae: 14.5971
#
# Epoch 00091: val_mae did not improve from 13.78222
# Epoch 92/100
# 93/93 [==============================] - 1s 7ms/step - loss: 15.9669 - mae: 16.4564 - val_loss: 13.7303 - val_mae: 14.2215
#
# Epoch 00092: val_mae did not improve from 13.78222
# Epoch 93/100
# 93/93 [==============================] - 1s 7ms/step - loss: 15.7962 - mae: 16.2855 - val_loss: 13.8688 - val_mae: 14.3603
#
# Epoch 00093: val_mae did not improve from 13.78222
# Epoch 94/100
# 93/93 [==============================] - 1s 7ms/step - loss: 15.9091 - mae: 16.3984 - val_loss: 13.8112 - val_mae: 14.3004
#
# Epoch 00094: val_mae did not improve from 13.78222
# Epoch 95/100
# 93/93 [==============================] - 1s 7ms/step - loss: 15.9557 - mae: 16.4450 - val_loss: 14.0951 - val_mae: 14.5856
#
# Epoch 00095: val_mae did not improve from 13.78222
# Epoch 96/100
# 93/93 [==============================] - 1s 7ms/step - loss: 15.8253 - mae: 16.3145 - val_loss: 13.6950 - val_mae: 14.1842
#
# Epoch 00096: val_mae did not improve from 13.78222
# Epoch 97/100
# 93/93 [==============================] - 1s 7ms/step - loss: 16.0901 - mae: 16.5800 - val_loss: 13.9797 - val_mae: 14.4705
#
# Epoch 00097: val_mae did not improve from 13.78222
# Epoch 98/100
# 93/93 [==============================] - 1s 7ms/step - loss: 15.8431 - mae: 16.3326 - val_loss: 13.8050 - val_mae: 14.2962
#
# Epoch 00098: val_mae did not improve from 13.78222
# Epoch 99/100
# 93/93 [==============================] - 1s 7ms/step - loss: 15.9180 - mae: 16.4072 - val_loss: 14.0498 - val_mae: 14.5414
#
# Epoch 00099: val_mae did not improve from 13.78222
# Epoch 100/100
# 93/93 [==============================] - 1s 7ms/step - loss: 16.1874 - mae: 16.6773 - val_loss: 14.8138 - val_mae: 15.3051
#
# Epoch 00100: val_mae did not improve from 13.78222
